# %% [markdown]
# # Compare Runs of GEODYN with diff Density Models
#  - single arc length (36 hours)
#  - no Cd Adjustment

# %%
models_list = [ 'tiegcm_oc' ] #,'jaachia71']   # 'msis86','msis00',

# %%
# %load_ext autoreload
# %autoreload 2

# import sys  
# import pickle 
# sys.path.insert(0, '/data/geodyn_proj/pygeodyn/pygeodyn_develop/')
# from PYGEODYN import Pygeodyn

# for i,val in enumerate( ['msis2','msis86','msis00', 'dtm87', 'jaachia71' ]):
#     template     = '/data/geodyn_proj/validation/NoCD_Arc24_AllDensModels_settings/NoCdArc24_msis2.yaml'
# #     run_settings = '/data/geodyn_proj/validation/NoCD_Arc36_AllDensModels_settings/NoCdArc36_'+val+'.yaml'
#     run_settings = '/data/geodyn_proj/validation/NoCD_Arc24_AllDensModels_settings/NoCdArc24_'+val+'.yaml'
    
#     ##### MODIFY THE SETTINGS FILE
#     #### Read the file.
#     with open(template, "r") as f:
#         lines_all = f.readlines()
#     ### Re-write the file line-by-line with your changes
#     with open(run_settings, "w") as f:
#         for line_num, line in enumerate(lines_all):
#             if 'den_model' in line:
#                 f.write("    den_model        : '"+val+"'  ,"+'\n')
#             else:
#                 f.write(line)

# %% [markdown]
# ### Run GEODYN if needed

# %%
# %load_ext autoreload
# %autoreload 2

import sys  
import pickle 
sys.path.insert(0, '/data/geodyn_proj/pygeodyn/pygeodyn_develop/')
from PYGEODYN import Pygeodyn


run = {}
for i,val in enumerate( models_list ): #,'jaachia71']):# 'msis86','msis00',
#     run_settings = '/data/geodyn_proj/validation/NoCD_Arc24_AllDensModels_settings/NoCdArc24_TESTOrbStep_'+val+'.yaml'
    run_settings = '/data/geodyn_proj/validation/NoCD_Arc24_AllDensModels_settings/NoCdArc24_'+val+'.yaml'

    ### Load the data into an object
    run[val] = Pygeodyn(run_settings)
    run[val].RUN_GEODYN()
# Out:
#      Loading ... icesat2_2018313_24hr.msis2.NoCD_Arc24
# Run # 1     Current Time =      14:57:27  GMT-7
# Run # 1
# Epoch Start:  2018-11-09 00:00:00
# Epoch End:    2018-11-10 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 1     IISSET Cleaned      tmp/.../cleaned_setup_2018313
# |  Run # 1     Density Model:      msis2
# |  Run # 1     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 1     ARC run:            icesat2_2018313_24hr.msis2.NoCD_Arc24
# |  Run # 1     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 1     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.313.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 1          Running IIS
# Run # 1          No errors in IIS
# Run # 1 ---------End of IIS
#
# Run # 1          Running IIE
# Run # 1          Current Time = 14:58:51 GMT-7
# Run # 1          No errors in IIE
# Run # 1 ---------End of IIE
# Run # 1          Time of IIE:  481.5668408870697 secs ( 8.026114014784495  mins)
# Run # 1          Current Time = 22:06:53
# Run # 1                Finished renaming files
# Run # 1                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018314_24hr.msis2.NoCD_Arc24
# Run # 2     Current Time =      15:06:59  GMT-7
# Run # 2
# Epoch Start:  2018-11-10 00:00:00
# Epoch End:    2018-11-11 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 2     IISSET Cleaned      tmp/.../cleaned_setup_2018314
# |  Run # 2     Density Model:      msis2
# |  Run # 2     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 2     ARC run:            icesat2_2018314_24hr.msis2.NoCD_Arc24
# |  Run # 2     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 2     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.314.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 2          Running IIS
# Run # 2          No errors in IIS
# Run # 2 ---------End of IIS
#
# Run # 2          Running IIE
# Run # 2          Current Time = 15:09:08 GMT-7
# Run # 2          No errors in IIE
# Run # 2 ---------End of IIE
# Run # 2          Time of IIE:  659.6263275146484 secs ( 10.99377212524414  mins)
# Run # 2          Current Time = 22:20:08
# Run # 2                Finished renaming files
# Run # 2                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018315_24hr.msis2.NoCD_Arc24
# Run # 3     Current Time =      15:20:11  GMT-7
# Run # 3
# Epoch Start:  2018-11-11 00:00:00
# Epoch End:    2018-11-12 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 3     IISSET Cleaned      tmp/.../cleaned_setup_2018315
# |  Run # 3     Density Model:      msis2
# |  Run # 3     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 3     ARC run:            icesat2_2018315_24hr.msis2.NoCD_Arc24
# |  Run # 3     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 3     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.315.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 3          Running IIS
# Run # 3          No errors in IIS
# Run # 3 ---------End of IIS
#
# Run # 3          Running IIE
# Run # 3          Current Time = 15:21:36 GMT-7
# Run # 3          No errors in IIE
# Run # 3 ---------End of IIE
# Run # 3          Time of IIE:  595.4269595146179 secs ( 9.923782658576965  mins)
# Run # 3          Current Time = 22:31:32
# Run # 3                Finished renaming files
# Run # 3                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018316_24hr.msis2.NoCD_Arc24
# Run # 4     Current Time =      15:31:38  GMT-7
# Run # 4
# Epoch Start:  2018-11-12 00:00:00
# Epoch End:    2018-11-13 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 4     IISSET Cleaned      tmp/.../cleaned_setup_2018316
# |  Run # 4     Density Model:      msis2
# |  Run # 4     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 4     ARC run:            icesat2_2018316_24hr.msis2.NoCD_Arc24
# |  Run # 4     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 4     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.316.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 4          Running IIS
# Run # 4          No errors in IIS
# Run # 4 ---------End of IIS
#
# Run # 4          Running IIE
# Run # 4          Current Time = 15:33:49 GMT-7
# Run # 4          No errors in IIE
# Run # 4 ---------End of IIE
# Run # 4          Time of IIE:  992.190687417984 secs ( 16.5365114569664  mins)
# Run # 4          Current Time = 22:50:21
# Run # 4                Finished renaming files
# Run # 4                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018317_24hr.msis2.NoCD_Arc24
# Run # 5     Current Time =      15:50:24  GMT-7
# Run # 5
# Epoch Start:  2018-11-13 00:00:00
# Epoch End:    2018-11-14 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 5     IISSET Cleaned      tmp/.../cleaned_setup_2018317
# |  Run # 5     Density Model:      msis2
# |  Run # 5     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 5     ARC run:            icesat2_2018317_24hr.msis2.NoCD_Arc24
# |  Run # 5     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 5     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.317.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 5          Running IIS
# Run # 5          No errors in IIS
# Run # 5 ---------End of IIS
#
# Run # 5          Running IIE
# Run # 5          Current Time = 15:56:22 GMT-7
# Run # 5          No errors in IIE
# Run # 5 ---------End of IIE
# Run # 5          Time of IIE:  1042.7092723846436 secs ( 17.378487873077393  mins)
# Run # 5          Current Time = 23:13:45
# Run # 5                Finished renaming files
# Run # 5                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018318_24hr.msis2.NoCD_Arc24
# Run # 6     Current Time =      16:13:56  GMT-7
# Run # 6
# Epoch Start:  2018-11-14 00:00:00
# Epoch End:    2018-11-15 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 6     IISSET Cleaned      tmp/.../cleaned_setup_2018318
# |  Run # 6     Density Model:      msis2
# |  Run # 6     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 6     ARC run:            icesat2_2018318_24hr.msis2.NoCD_Arc24
# |  Run # 6     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 6     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.318.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# Run # 6          Running IIS
# Run # 6          No errors in IIS
# Run # 6 ---------End of IIS
#
# Run # 6          Running IIE
# Run # 6          Current Time = 16:15:56 GMT-7
# Run # 6          No errors in IIE
# Run # 6 ---------End of IIE
# Run # 6          Time of IIE:  867.045243024826 secs ( 14.450754050413767  mins)
# Run # 6          Current Time = 23:30:23
# Run # 6                Finished renaming files
# Run # 6                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018319_24hr.msis2.NoCD_Arc24
# Run # 7     Current Time =      16:30:26  GMT-7
# Run # 7
# Epoch Start:  2018-11-15 00:00:00
# Epoch End:    2018-11-16 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 7     IISSET Cleaned      tmp/.../cleaned_setup_2018319
# |  Run # 7     Density Model:      msis2
# |  Run # 7     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 7     ARC run:            icesat2_2018319_24hr.msis2.NoCD_Arc24
# |  Run # 7     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 7     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.319.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 7          Running IIS
# Run # 7          No errors in IIS
# Run # 7 ---------End of IIS
#
# Run # 7          Running IIE
# Run # 7          Current Time = 16:31:57 GMT-7
# Run # 7          No errors in IIE
# Run # 7 ---------End of IIE
# Run # 7          Time of IIE:  632.2395215034485 secs ( 10.537325358390808  mins)
# Run # 7          Current Time = 23:42:29
# Run # 7                Finished renaming files
# Run # 7                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018320_24hr.msis2.NoCD_Arc24
# Run # 8     Current Time =      16:42:36  GMT-7
# Run # 8
# Epoch Start:  2018-11-16 00:00:00
# Epoch End:    2018-11-17 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 8     IISSET Cleaned      tmp/.../cleaned_setup_2018320
# |  Run # 8     Density Model:      msis2
# |  Run # 8     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 8     ARC run:            icesat2_2018320_24hr.msis2.NoCD_Arc24
# |  Run # 8     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 8     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.320.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 8          Running IIS
# Run # 8          No errors in IIS
# Run # 8 ---------End of IIS
#
# Run # 8          Running IIE
# Run # 8          Current Time = 16:44:54 GMT-7
# Run # 8          No errors in IIE
# Run # 8 ---------End of IIE
# Run # 8          Time of IIE:  647.9002799987793 secs ( 10.798337999979655  mins)
# Run # 8          Current Time = 23:55:42
# Run # 8                Finished renaming files
# Run # 8                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018321_24hr.msis2.NoCD_Arc24
# Run # 9     Current Time =      16:55:45  GMT-7
# Run # 9
# Epoch Start:  2018-11-17 00:00:00
# Epoch End:    2018-11-18 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 9     IISSET Cleaned      tmp/.../cleaned_setup_2018321
# |  Run # 9     Density Model:      msis2
# |  Run # 9     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 9     ARC run:            icesat2_2018321_24hr.msis2.NoCD_Arc24
# |  Run # 9     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 9     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.321.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 9          Running IIS
# Run # 9          No errors in IIS
# Run # 9 ---------End of IIS
#
# Run # 9          Running IIE
# Run # 9          Current Time = 16:57:28 GMT-7
# Run # 9          No errors in IIE
# Run # 9 ---------End of IIE
# Run # 9          Time of IIE:  660.9437901973724 secs ( 11.015729836622874  mins)
# Run # 9          Current Time = 00:08:29
# Run # 9                Finished renaming files
# Run # 9                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018322_24hr.msis2.NoCD_Arc24
# Run # 10     Current Time =      17:08:35  GMT-7
# Run # 10
# Epoch Start:  2018-11-18 00:00:00
# Epoch End:    2018-11-19 00:00:00
# Running without DRAG time dependence
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 10     IISSET Cleaned      tmp/.../cleaned_setup_2018322
# |  Run # 10     Density Model:      msis2
# |  Run # 10     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 10     ARC run:            icesat2_2018322_24hr.msis2.NoCD_Arc24
# |  Run # 10     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 10     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.322.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 10          Running IIS
# Run # 10          No errors in IIS
# Run # 10 ---------End of IIS
#
# Run # 10          Running IIE
# Run # 10          Current Time = 17:10:41 GMT-7
# Run # 10          No errors in IIE
# Run # 10 ---------End of IIE
# Run # 10          Time of IIE:  653.9253568649292 secs ( 10.89875594774882  mins)
# Run # 10          Current Time = 00:21:36
# Run # 10                Finished renaming files
# Run # 10                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018323_24hr.msis2.NoCD_Arc24
# Run # 11     Current Time =      17:21:42  GMT-7
# Run # 11
# Epoch Start:  2018-11-19 00:00:00
# Epoch End:    2018-11-20 00:00:00
# Running without DRAG time dependence
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 11     IISSET Cleaned      tmp/.../cleaned_setup_2018323
# |  Run # 11     Density Model:      msis2
# |  Run # 11     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 11     ARC run:            icesat2_2018323_24hr.msis2.NoCD_Arc24
# |  Run # 11     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 11     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.323.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 11          Running IIS
# Run # 11          No errors in IIS
# Run # 11 ---------End of IIS
#
# Run # 11          Running IIE
# Run # 11          Current Time = 17:24:08 GMT-7
# Run # 11          No errors in IIE
# Run # 11 ---------End of IIE
# Run # 11          Time of IIE:  672.9771137237549 secs ( 11.216285228729248  mins)
# Run # 11          Current Time = 00:35:21
# Run # 11                Finished renaming files
# Run # 11                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018324_24hr.msis2.NoCD_Arc24
# Run # 12     Current Time =      17:35:24  GMT-7
# Run # 12
# Epoch Start:  2018-11-20 00:00:00
# Epoch End:    2018-11-21 00:00:00
# Running without DRAG time dependence
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 12     IISSET Cleaned      tmp/.../cleaned_setup_2018324
# |  Run # 12     Density Model:      msis2
# |  Run # 12     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 12     ARC run:            icesat2_2018324_24hr.msis2.NoCD_Arc24
# |  Run # 12     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 12     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.324.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# Run # 12          Running IIS
# Run # 12          No errors in IIS
# Run # 12 ---------End of IIS
#
# Run # 12          Running IIE
# Run # 12          Current Time = 17:37:00 GMT-7
# Run # 12          No errors in IIE
# Run # 12 ---------End of IIE
# Run # 12          Time of IIE:  768.8181455135345 secs ( 12.81363575855891  mins)
# Run # 12          Current Time = 00:49:49
# Run # 12                Finished renaming files
# Run # 12                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018325_24hr.msis2.NoCD_Arc24
# Run # 13     Current Time =      17:49:56  GMT-7
# Run # 13
# Epoch Start:  2018-11-21 00:00:00
# Epoch End:    2018-11-22 00:00:00
# Running without DRAG time dependence
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 13     IISSET Cleaned      tmp/.../cleaned_setup_2018325
# |  Run # 13     Density Model:      msis2
# |  Run # 13     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 13     ARC run:            icesat2_2018325_24hr.msis2.NoCD_Arc24
# |  Run # 13     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 13     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.325.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 13          Running IIS
# Run # 13          No errors in IIS
# Run # 13 ---------End of IIS
#
# Run # 13          Running IIE
# Run # 13          Current Time = 17:51:42 GMT-7
# Run # 13          No errors in IIE
# Run # 13 ---------End of IIE
# Run # 13          Time of IIE:  604.7361979484558 secs ( 10.078936632474264  mins)
# Run # 13          Current Time = 01:01:47
# Run # 13                Finished renaming files
# Run # 13                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018326_24hr.msis2.NoCD_Arc24
# Run # 14     Current Time =      18:01:54  GMT-7
# Run # 14
# Epoch Start:  2018-11-22 00:00:00
# Epoch End:    2018-11-23 00:00:00
# Running without DRAG time dependence
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 14     IISSET Cleaned      tmp/.../cleaned_setup_2018326
# |  Run # 14     Density Model:      msis2
# |  Run # 14     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 14     ARC run:            icesat2_2018326_24hr.msis2.NoCD_Arc24
# |  Run # 14     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 14     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.326.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 14          Running IIS
# Run # 14          No errors in IIS
# Run # 14 ---------End of IIS
#
# Run # 14          Running IIE
# Run # 14          Current Time = 18:04:31 GMT-7
# Run # 14          No errors in IIE
# Run # 14 ---------End of IIE
# Run # 14          Time of IIE:  641.5533215999603 secs ( 10.69255535999934  mins)
# Run # 14          Current Time = 01:15:13
# Run # 14                Finished renaming files
# Run # 14                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun
#      Loading ... icesat2_2018327_24hr.msis2.NoCD_Arc24
# Run # 15     Current Time =      18:15:16  GMT-7
# Run # 15
# Epoch Start:  2018-11-23 00:00:00
# Epoch End:    2018-11-24 00:00:00
# Running without DRAG time dependence
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 15     IISSET Cleaned      tmp/.../cleaned_setup_2018327
# |  Run # 15     Density Model:      msis2
# |  Run # 15     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 15     ARC run:            icesat2_2018327_24hr.msis2.NoCD_Arc24
# |  Run # 15     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun
# |  Run # 15     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.327.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 15          Running IIS
# Run # 15          No errors in IIS
# Run # 15 ---------End of IIS
#
# Run # 15          Running IIE
# Run # 15          Current Time = 18:16:56 GMT-7
# Run # 15          No errors in IIE
# Run # 15 ---------End of IIE
# Run # 15          Time of IIE:  646.7151780128479 secs ( 10.778586300214132  mins)
# Run # 15          Current Time = 01:27:43
# Run # 15                Finished renaming files
# Run # 15                Finished copying files to outputdir
#         Deleting:  msis2_acceloff_valid_ctrlrun

# %%
print('End of Notebook')
# Out:
# End of Notebook

# %% [markdown]
# #####
