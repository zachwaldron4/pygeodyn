# %%
import copy
import sys

# %%
# %load_ext autoreload
# %autoreload 2

# import sys
# sys.path.insert(0,'/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/util_preprocessing/')
# from PYGEODYN_Preprocess import PygeodynPreprocessing

# path_to_prep_directory = '/data/data_geodyn/inputs/icesat2/pre_processing'
# path_to_binaryrvg     = '/data/data_geodyn/inputs/icesat2/pre_processing/traj_files_rvg'

# arc1_files = [
#               'orbit.1807001.2018.312',
#               'orbit.1807001.2018.313',
#               'orbit.1807001.2018.314',
#               'orbit.1807001.2018.315',
#               'orbit.1807001.2018.316',
#               'orbit.1807001.2018.317',
#               'orbit.1807001.2018.318',
# #               'orbit.1807001.2018.319',
# #               'orbit.1807001.2018.320',
# #               'orbit.1807001.2018.321',
# #               'orbit.1807001.2018.322',
#              ]

# ##### Uncomment the below call to overwrite the G2B data by re-running the pre-processing code
# Obj = PygeodynPreprocessing(path_to_binaryrvg, path_to_prep_directory,  arc1_files)
# Obj.run_preprocess_PCE()

# %% [markdown]
# ## Step 1: Run GEODYN using Pygeodyn with the ICESat2 configuration
#
# As a reminder, PYGEODYN is called with the `PYGEODYN` class, but modifications to the ICESAT2 configuration are largely controlled through the `Satellite_ICESat2` class in the `PYGEODYN_Satellites.py` file.   Please refer to this file first for file structure setups and modifications to the Pygeodyn structure.
#
# ### Step 1.1:  Run with MSIS2

# %%
### Identify which arcs you want to run:
arcs_files = [ 
            '2018.313', # 1
#             '2018.314', # 2
#             '2018.315', # 3
#             '2018.316', # 4
#             '2018.317', # 5
#             '2018.318', # 6
#             '2018.319', # 7
#             '2018.320', # 8
#             '2018.321', # 9
#             '2018.322', # 10
             ]

#------ A dictionary containing the run parameters ------  
run_params = {} 
run_params['arc']              =   arcs_files
run_params['satellite']        =  'icesat2'  
run_params['den_model']        =  'msis2'  
run_params['SpecialRun_name']  =  'develop_test'  
run_params['verbose']          =  False
run_params['action']           =  'run'

# %%
# %load_ext autoreload
# %autoreload 2

sys.path.insert(0, '/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/')
from PYGEODYN import Pygeodyn


#### ---------------------------------------------
####
#### ----------------- RUN MSIS2.0 --------------- 
####
#### ---------------------------------------------

##### Use copy.deepcopy to copy all levels of dictionary and 
###       allow modification of new variable
run_params1 = copy.deepcopy(run_params)
run_params1['den_model'] =  'msis2'  

### Run pyeodyn for the arcs in the above set.
Obj_Geodyn = Pygeodyn(run_params1)
Obj_Geodyn.RUN_GEODYN()
# Out:
# =================================================================
#    Initializing PYGEODYN to ...
#                             ... RUN GEODYN
# =================================================================
# Run # 1     Current Time =      20:37:31
# Run # 1
# Run # 1     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.313.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 1     IISSET Cleaned      tmp/cleaned_setup_2018313
# |  Run # 1     Density Model:      msis2
# |  Run # 1     GEODYN Version:     pygeodyn_MODS
# |  Run # 1     ARC run:            icesat2_2018313_54hr.msis2
# |  Run # 1     Output directory:   /data/data_geodyn/results/icesat2/msis2/msis2_acceloffdevelop_test
# |  Run # 1     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.313.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 1          Running IIS
# Run # 1          No errors in IIS
# Run # 1 ---------End of IIS
#
# Run # 1          Running IIE
# Run # 1          Current Time = 20:39:07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-2d25c05a24d0> in <module>
#      19 ### Run pyeodyn for the arcs in the above set.
#      20 Obj_Geodyn = Pygeodyn(run_params1)
# ---> 21 Obj_Geodyn.RUN_GEODYN()
#
# /data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/PYGEODYN_Control.py in RUN_GEODYN(self)
#     672             self.print_runparameters_to_notebook()
#     673             self.prepare_tmpdir_for_geodyn_run()
# --> 674             self.run_geodyn_in_tmpdir()
#     675             self.post_geodynrun_savefiles_and_cleanup()
#     676
#
# /data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/PYGEODYN_Control.py in run_geodyn_in_tmpdir(self)
#     483         command_IIE = self.G2EDIR+'/giie2002_gfortran > '+'iieout 2> '+'iieerr'
#     484         time.sleep(0.5)
# --> 485         subprocess.run(command_IIE, shell = True)
#     486         time.sleep(0.5)
#     487
#
# /data/miniconda3/envs/pygeodyn/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493     with Popen(*popenargs, **kwargs) as process:
#     494         try:
# --> 495             stdout, stderr = process.communicate(input, timeout=timeout)
#     496         except TimeoutExpired as exc:
#     497             process.kill()
#
# /data/miniconda3/envs/pygeodyn/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1018                 stderr = self.stderr.read()
#    1019                 self.stderr.close()
# -> 1020             self.wait()
#    1021         else:
#    1022             if timeout is not None:
#
# /data/miniconda3/envs/pygeodyn/lib/python3.8/subprocess.py in wait(self, timeout)
#    1081             endtime = _time() + timeout
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#    1085             # https://bugs.python.org/issue25942
#
# /data/miniconda3/envs/pygeodyn/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1806                         if self.returncode is not None:
#    1807                             break  # Another thread waited.
# -> 1808                         (pid, sts) = self._try_wait(0)
#    1809                         # Check the pid and loop as waitpid has been known to
#    1810                         # return 0 even without WNOHANG in odd situations.
#
# /data/miniconda3/envs/pygeodyn/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1764             """All callers to this function MUST hold self._waitpid_lock."""
#    1765             try:
# -> 1766                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1767             except ChildProcessError:
#    1768                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# ### Step  1.2: Run with DTM87 for comparison

# %%
# %load_ext autoreload
# %autoreload 2

# sys.path.insert(0, '/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/')
# from PYGEODYN import Pygeodyn

# #### ---------------------------------------------
# ####
# #### ------------------- RUN DTM ----------------- 
# ####
# #### ---------------------------------------------


# ##### Use copy.deepcopy to copy all levels of dictionary and 
# ###       allow modification of new variable
# run_params2 = copy.deepcopy(run_params)
# run_params2['den_model']         =  'dtm87'  

# ### Run pyeodyn for the arcs in the above set.
# Obj_Geodyn = Pygeodyn(run_params2)
# Obj_Geodyn.RUN_GEODYN()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# =================================================================
#    Initializing PYGEODYN to ...
#                             ... RUN GEODYN
# =================================================================
# Run # 1     Current Time =      22:21:34
# Run # 1
# Run # 1     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.313.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 1     IISSET Cleaned      tmp/cleaned_setup_2018313
# |  Run # 1     Density Model:      dtm87
# |  Run # 1     GEODYN Version:     pygeodyn_MODS
# |  Run # 1     ARC run:            icesat2_2018313_54hr.dtm87
# |  Run # 1     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis_1
# |  Run # 1     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.313.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 1          Running IIS
# Run # 1          No errors in IIS
# Run # 1 ---------End of IIS
#
# Run # 1          Running IIE
# Run # 1          Current Time = 22:23:05
# Run # 1          No errors in IIE
# Run # 1 ---------End of IIE
# Run # 1          Time of IIE:  514.8692960739136 secs ( 8.581154934565227  mins)
# Run # 1          Current Time = 22:31:40
# Run # 1                Finished renaming files
# Run # 1                Finished copying files to outputdir
#         Deleting:  dtm87_acceloff_TrajAnalysis_1
# Run # 2     Current Time =      22:31:45
# Run # 2
# Run # 2     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.314.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 2     IISSET Cleaned      tmp/cleaned_setup_2018314
# |  Run # 2     Density Model:      dtm87
# |  Run # 2     GEODYN Version:     pygeodyn_MODS
# |  Run # 2     ARC run:            icesat2_2018314_54hr.dtm87
# |  Run # 2     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis_1
# |  Run # 2     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.314.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 2          Running IIS
# Run # 2          No errors in IIS
# Run # 2 ---------End of IIS
#
# Run # 2          Running IIE
# Run # 2          Current Time = 22:33:15
# Run # 2          No errors in IIE
# Run # 2 ---------End of IIE
# Run # 2          Time of IIE:  487.66112184524536 secs ( 8.127685364087423  mins)
# Run # 2          Current Time = 22:41:23
# Run # 2                Finished renaming files
# Run # 2                Finished copying files to outputdir
#         Deleting:  dtm87_acceloff_TrajAnalysis_1
# Run # 3     Current Time =      22:41:27
# Run # 3
# Run # 3     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.315.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 3     IISSET Cleaned      tmp/cleaned_setup_2018315
# |  Run # 3     Density Model:      dtm87
# |  Run # 3     GEODYN Version:     pygeodyn_MODS
# |  Run # 3     ARC run:            icesat2_2018315_54hr.dtm87
# |  Run # 3     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis_1
# |  Run # 3     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.315.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 3          Running IIS
# Run # 3          No errors in IIS
# Run # 3 ---------End of IIS
#
# Run # 3          Running IIE
# Run # 3          Current Time = 22:42:58
# Run # 3          No errors in IIE
# Run # 3 ---------End of IIE
# Run # 3          Time of IIE:  443.53073239326477 secs ( 7.39217887322108  mins)
# Run # 3          Current Time = 22:50:22
# Run # 3                Finished renaming files
# Run # 3                Finished copying files to outputdir
#         Deleting:  dtm87_acceloff_TrajAnalysis_1
# Run # 4     Current Time =      22:50:26
# Run # 4
# Run # 4     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.316.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 4     IISSET Cleaned      tmp/cleaned_setup_2018316
# |  Run # 4     Density Model:      dtm87
# |  Run # 4     GEODYN Version:     pygeodyn_MODS
# |  Run # 4     ARC run:            icesat2_2018316_54hr.dtm87
# |  Run # 4     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis_1
# |  Run # 4     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.316.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 4          Running IIS
# Run # 4          No errors in IIS
# Run # 4 ---------End of IIS
#
# Run # 4          Running IIE
# Run # 4          Current Time = 22:52:02
# Run # 4          No errors in IIE
# Run # 4 ---------End of IIE
# Run # 4          Time of IIE:  451.1960120201111 secs ( 7.519933533668518  mins)
# Run # 4          Current Time = 22:59:34
# Run # 4                Finished renaming files
# Run # 4                Finished copying files to outputdir
#         Deleting:  dtm87_acceloff_TrajAnalysis_1
# Run # 5     Current Time =      22:59:42
# Run # 5
# Run # 5     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.317.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 5     IISSET Cleaned      tmp/cleaned_setup_2018317
# |  Run # 5     Density Model:      dtm87
# |  Run # 5     GEODYN Version:     pygeodyn_MODS
# |  Run # 5     ARC run:            icesat2_2018317_54hr.dtm87
# |  Run # 5     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis_1
# |  Run # 5     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.317.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 5          Running IIS
# Run # 5          No errors in IIS
# Run # 5 ---------End of IIS
#
# Run # 5          Running IIE
# Run # 5          Current Time = 23:01:12
# Run # 5          No errors in IIE
# Run # 5 ---------End of IIE
# Run # 5          Time of IIE:  582.8888199329376 secs ( 9.714813665548961  mins)
# Run # 5          Current Time = 23:10:55
# Run # 5                Finished renaming files
# Run # 5                Finished copying files to outputdir
#         Deleting:  dtm87_acceloff_TrajAnalysis_1

# %% [markdown]
# ### Step  1.2: Run with Jaachia 71 Model for comparison

# %%
# %load_ext autoreload
# %autoreload 2

# sys.path.insert(0, '/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/')
# from PYGEODYN import Pygeodyn


# #### ----------------------------------------------
# ####
# #### ----------------- RUN JAACHIA ----------------- 
# ####
# #### ----------------------------------------------

# ##### Use copy.deepcopy to copy all levels of dictionary and 
# ###       allow modification of new variable
# run_params3 = copy.deepcopy(run_params)
# run_params3['den_model']         =  'jaachia71'  


# #### Run pyeodyn for the arcs in the above set.
# Obj_Geodyn = Pygeodyn(run_params3)
# Obj_Geodyn.RUN_GEODYN()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# =================================================================
#    Initializing PYGEODYN to ...
#                             ... RUN GEODYN
# =================================================================
# Run # 1     Current Time =      23:11:00
# Run # 1
# Run # 1     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.313.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 1     IISSET Cleaned      tmp/cleaned_setup_2018313
# |  Run # 1     Density Model:      jaachia71
# |  Run # 1     GEODYN Version:     pygeodyn_MODS
# |  Run # 1     ARC run:            icesat2_2018313_54hr.jaachia71
# |  Run # 1     Output directory:   /data/data_geodyn/results/icesat2/jaachia71/jaachia71_acceloff_TrajAnalysis_1
# |  Run # 1     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.313.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 1          Running IIS
# Run # 1          No errors in IIS
# Run # 1 ---------End of IIS
#
# Run # 1          Running IIE
# Run # 1          Current Time = 23:12:19
# Run # 1          No errors in IIE
# Run # 1 ---------End of IIE
# Run # 1          Time of IIE:  509.5972669124603 secs ( 8.493287781874338  mins)
# Run # 1          Current Time = 23:20:49
# Run # 1                Finished renaming files
# Run # 1                Finished copying files to outputdir
#         Deleting:  jaachia71_acceloff_TrajAnalysis_1
# Run # 2     Current Time =      23:20:53
# Run # 2
# Run # 2     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.314.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 2     IISSET Cleaned      tmp/cleaned_setup_2018314
# |  Run # 2     Density Model:      jaachia71
# |  Run # 2     GEODYN Version:     pygeodyn_MODS
# |  Run # 2     ARC run:            icesat2_2018314_54hr.jaachia71
# |  Run # 2     Output directory:   /data/data_geodyn/results/icesat2/jaachia71/jaachia71_acceloff_TrajAnalysis_1
# |  Run # 2     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.314.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 2          Running IIS
# Run # 2          No errors in IIS
# Run # 2 ---------End of IIS
#
# Run # 2          Running IIE
# Run # 2          Current Time = 23:22:11
# Run # 2          No errors in IIE
# Run # 2 ---------End of IIE
# Run # 2          Time of IIE:  431.45134353637695 secs ( 7.190855725606283  mins)
# Run # 2          Current Time = 23:29:23
# Run # 2                Finished renaming files
# Run # 2                Finished copying files to outputdir
#         Deleting:  jaachia71_acceloff_TrajAnalysis_1
# Run # 3     Current Time =      23:29:27
# Run # 3
# Run # 3     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.315.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 3     IISSET Cleaned      tmp/cleaned_setup_2018315
# |  Run # 3     Density Model:      jaachia71
# |  Run # 3     GEODYN Version:     pygeodyn_MODS
# |  Run # 3     ARC run:            icesat2_2018315_54hr.jaachia71
# |  Run # 3     Output directory:   /data/data_geodyn/results/icesat2/jaachia71/jaachia71_acceloff_TrajAnalysis_1
# |  Run # 3     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.315.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 3          Running IIS
# Run # 3          No errors in IIS
# Run # 3 ---------End of IIS
#
# Run # 3          Running IIE
# Run # 3          Current Time = 23:30:45
# Run # 3          No errors in IIE
# Run # 3 ---------End of IIE
# Run # 3          Time of IIE:  506.4229018688202 secs ( 8.44038169781367  mins)
# Run # 3          Current Time = 23:39:11
# Run # 3                Finished renaming files
# Run # 3                Finished copying files to outputdir
#         Deleting:  jaachia71_acceloff_TrajAnalysis_1
# Run # 4     Current Time =      23:39:15
# Run # 4
# Run # 4     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.316.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 4     IISSET Cleaned      tmp/cleaned_setup_2018316
# |  Run # 4     Density Model:      jaachia71
# |  Run # 4     GEODYN Version:     pygeodyn_MODS
# |  Run # 4     ARC run:            icesat2_2018316_54hr.jaachia71
# |  Run # 4     Output directory:   /data/data_geodyn/results/icesat2/jaachia71/jaachia71_acceloff_TrajAnalysis_1
# |  Run # 4     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.316.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 4          Running IIS
# Run # 4          No errors in IIS
# Run # 4 ---------End of IIS
#
# Run # 4          Running IIE
# Run # 4          Current Time = 23:40:34
# Run # 4          No errors in IIE
# Run # 4 ---------End of IIE
# Run # 4          Time of IIE:  581.1950364112854 secs ( 9.68658394018809  mins)
# Run # 4          Current Time = 23:50:15
# Run # 4                Finished renaming files
# Run # 4                Finished copying files to outputdir
#         Deleting:  jaachia71_acceloff_TrajAnalysis_1
# Run # 5     Current Time =      23:50:20
# Run # 5
# Run # 5     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.317.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 5     IISSET Cleaned      tmp/cleaned_setup_2018317
# |  Run # 5     Density Model:      jaachia71
# |  Run # 5     GEODYN Version:     pygeodyn_MODS
# |  Run # 5     ARC run:            icesat2_2018317_54hr.jaachia71
# |  Run # 5     Output directory:   /data/data_geodyn/results/icesat2/jaachia71/jaachia71_acceloff_TrajAnalysis_1
# |  Run # 5     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.317.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 5          Running IIS
# Run # 5          No errors in IIS
# Run # 5 ---------End of IIS
#
# Run # 5          Running IIE
# Run # 5          Current Time = 23:51:37
# Run # 5          No errors in IIE
# Run # 5 ---------End of IIE
# Run # 5          Time of IIE:  579.4811520576477 secs ( 9.658019200960796  mins)
# Run # 5          Current Time = 00:01:17
# Run # 5                Finished renaming files
# Run # 5                Finished copying files to outputdir
#         Deleting:  jaachia71_acceloff_TrajAnalysis_1

# %% [markdown]
# ## Read GEODYN Output using PygeodynRead functionality
#
# ### Get MSIS2 Data

# %%
# Clear the memory of the notebook because the saved variables get so large:
# %reset -f out

# %%
# %load_ext autoreload
# %autoreload 2

# import sys  
# sys.path.insert(0, '/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/')
# from PYGEODYN import Pygeodyn

# #------ A dictionary containing the run parameters ------  
# run_params1 = {} 
# run_params1['arc']               =  ['2018.313',
#                                      '2018.314',
#                                      '2018.315',
#                                      '2018.316',
#                                      '2018.317',
#                                     ] 
# run_params1['satellite']         =  'icesat2'  
# run_params1['den_model']         =  'msis2'  
# run_params1['SpecialRun_name']   =  '_TrajAnalysis'  
# run_params1['verbose']           =  False
# run_params1['action']            =  'read'

# Obj_Geodyn1 = Pygeodyn(run_params1)
# Obj_Geodyn1.getData()

# %% [markdown]
# ### Get DTM87 Data

# %%
# %load_ext autoreload
# %autoreload 2

# from PYGEODYN import Pygeodyn
# import copy


# run_params2 = copy.deepcopy(run_params1)

# run_params2['den_model']         =  'dtm87'  

# Obj_Geodyn2 = Pygeodyn(run_params2)
# Obj_Geodyn2.getData()

# %% [markdown]
# ### Get Jaachia 71 Data

# %%
# %load_ext autoreload
# %autoreload 2

# from PYGEODYN import Pygeodyn
# # import copy


# run_params3 = copy.deepcopy(run_params1)
# run_params3['den_model']         =  'jaachia71'  

# Obj_Geodyn3 = Pygeodyn(run_params3)
# Obj_Geodyn3.getData()
