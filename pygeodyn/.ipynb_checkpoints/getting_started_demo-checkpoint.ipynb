# %% [markdown]
# # Using Pygeodyn: ICESat2 Example
#
#
#
# This notebook describes the high level details of how to use `Pygeodyn`.

# %% [markdown]
# ## Some notes for Preparing/Making a run:
#
# 1. All satellite specific files should be dealt with independently. For some satellite named `SATNAME`, one should have:
#      - A file, ``PYGEODYN_SATNAME.py``, with a ``Satellite_SATNAME`` class that overwrites necessary functions from `PygeodynController` and `PygeodynReader`.
#
# 2. Identify the files that are needed in your run:
#     - be sure the `Satellite_SATNAME` class has the correct filenames in the `__init__` method.  Any additional Sat/Run peculiarities can be dealt with here
#
# 3.  If you need to construct your own G2B file (for instance, as we did for the ICESat2-PCE Run), be sure you have done so and placed the G2b file in the correct directory
#
# 4. Edit a  `clean_iisset_file(self):` in the `Satellite_SATNAME` class to prepare the setup file to have the wanted parameters and options.
#     - Most errors one gets from IIS are due to either a file error or some random error in the setup file.
#
# 5. If you have compressed the input files (likely using ``gzip`` (for speed) or ``bzip2`` (for better compression), be sure those files have been properly dealt with.

# %% [markdown]
# ## Run GEODYN
# Import the necessary packages and direct the path to include the Pygeodyn Classes and Functions

# %%
import sys  
import copy


sys.path.insert(0, '/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/')
from PYGEODYN import Pygeodyn

# %% [markdown]
# Create a dictionary that contains the desired inputs.
#
# They are described here:
# ```text
# #------ A dictionary containing the run parameters ------
# run_params = {}
# run_params['arc']              =  a list of what arcs you want to include
# run_params['satellite']        =  a string with satellite of choice
# run_params['den_model']        =  a string with density model of choice
# run_params['SpecialRun_name']  =  a string to be appended to the output directory
#                                         (so data is not overwritten at each run)
# run_params['verbose']          =  False
# run_params['action']           =  'run' or 'read'
# ```

# %%
### Identify which arcs you want to run:
arcs_files = [ 
            '2018.313', # Arc 1
#             '2018.314', # Arc 2
#             '2018.315', # Arc 3
             ]

#------ A dictionary containing the run parameters ------  
run_params = {} 
run_params['arc']              =   arcs_files
run_params['satellite']        =  'icesat2'  
run_params['den_model']        =  'msis2'  
run_params['SpecialRun_name']  =  'example'  
run_params['verbose']          =  False
run_params['action']           =  'run'

# %% [markdown]
# Run Geodyn using the Pygeodyn function: ``Object.RUN_GEODYN()``

# %%
####### Run pyeodyn for the arcs in the above set.

### Uncomment to run it
# Obj_Geodyn = Pygeodyn(run_params)
# Obj_Geodyn.RUN_GEODYN()

# %% [markdown]
# ## Reading GEODYN output
#
# Use the ``copy.deepcopy()`` function to create a new dictionary with the same keys/inputs as the run dictionary, but add the necessary inputs for reading:

# %%
read_params = copy.deepcopy(run_params)

#------ A dictionary containing the run parameters ------  
read_params['action']            =  'read'
read_params['request_data'] = ['AdjustedParams',
            #                    'Trajectory_xyz',
                               'Trajectory_orbfil',
                               'Density',
                               'Residuals_obs',
                               'Residuals_summary',
                               'Statistics',
                                ]

# %%
Obj_Geodyn = Pygeodyn(read_params)
Obj_Geodyn.getData()
# Out:
#                       ......... READING GEODYN output
#      Loading ... icesat2_2018313_54hr.msis2

# %% [markdown]
# ### Look at output object
#
# Find the data sets that were requested by looking at the keys.

# %%
Obj_Geodyn.__dict__.keys()
# Out:
# dict_keys(['AdjustedParams', 'Trajectory_orbfil', 'Density', 'Residuals_obs', 'Residuals_summary', 'Statistics', 'run_parameters2018.313', 'global_params'])

# %% [markdown]
# The global parameters that are common across all arcs are saved in the `global_params` dictionary.

# %%
Obj_Geodyn.__dict__['global_params']
# Out:
# {'satellite': 'icesat2',
#  'den_model': 'msis2',
#  'SpecialRun_name': 'example',
#  'verbose': False,
#  'arc_input': ['2018.313'],
#  'DEN_DIR': 'msis2',
#  'SETUP_DEN_DIR': 'msis',
#  'iisset_den': '86',
#  'SATELLITE_dir': 'icesat2',
#  'SATID': '1807001',
#  'DATA_TYPE': 'PCE',
#  'grav_id': '',
#  'empirical_accels': False,
#  'ACCELS': 'acceloff',
#  'options_in': {'DRHODZ_update': True},
#  'g2b_file': 'icesat2g2b_pce_312_328.gz',
#  'atgrav_file': 'ATGRAV.glo-3HR_20160101-PRESENT_9999_AOD1B_0006.0090.gz',
#  'ephem_file': 'ephem1430.data_2025.gz',
#  'gravfield_file': 'eigen-6c.gfc_20080101_do_200_fix.grv.gz',
#  'arc_length': '54hr',
#  'YR': '2018',
#  'path_to_model': '/data/data_geodyn/results/icesat2/msis2/msis2_acceloffexample/'}

# %% [markdown]
# The arc specific parameters are saved in a `run_parametersARCNAME` dictionary.

# %%
Obj_Geodyn.__dict__['run_parameters2018.313']
# Out:
# {'action': 'read',
#  'tab': '  ',
#  'tabtab': '       ',
#  'request_data': ['AdjustedParams',
#   'Trajectory_orbfil',
#   'Density',
#   'Residuals_obs',
#   'Residuals_summary',
#   'Statistics',
#   'run_parameters2018.313',
#   'global_params'],
#  'StateVector_epochs_datafile': '/data/data_geodyn/inputs/icesat2/setups/StateVector_epochs.txt',
#  'Trajectory_xyz': {},
#  'run_ID': 'Run # 1',
#  'arc_name_id': '2018.313',
#  'arcdate_for_files': '2018313',
#  'setup_file_arc': 'iisset.2018.313',
#  'external_attitude': 'EXAT01.2018.313.gz',
#  'ARC': 'icesat2_2018313_54hr.msis2',
#  '_asciixyz_filename': '/data/data_geodyn/results/icesat2/msis2/msis2_acceloffexample/XYZ_TRAJ/icesat2_2018313_54hr.msis2',
#  '_orbfil_filename': '/data/data_geodyn/results/icesat2/msis2/msis2_acceloffexample/ORBITS/icesat2_2018313_54hr.msis2_orb1',
#  '_iieout_filename': '/data/data_geodyn/results/icesat2/msis2/msis2_acceloffexample/IIEOUT/icesat2_2018313_54hr.msis2',
#  '_density_filename': '/data/data_geodyn/results/icesat2/msis2/msis2_acceloffexample/DENSITY/icesat2_2018313_54hr.msis2',
#  'convergence_flag': True,
#  'total_iterations': 4,
#  'str_iteration': ' 4',
#  'orbfil_dict': {'header': {'Number of alphanumeric data buffers to follow (NA)': 533.0,
#    'Number of card images in the GEODYN II input control deck (NC)': 106557.0,
#    'Arc Number.': 1.0,
#    'Global Iteration Number': 1.0,
#    'Inner Iteration Number': 5.0,
#    'Number of satellites on this file': 1.0,
#    'Actual number of words per satellite per time point': 24.0,
#    'Number of words of data per time point (NWDATA=NSATS*NWDSAT)': 24.0,
#    'Number of time points per Data Buffer (NTIMBF)': 78.0,
#    'Trajectory Start Date & Time in form YYMMDDHHMMSS .0D0 UTC': 1181108210000.0,
#    'Fractional seconds of Start Time. UTC': 0.0,
#    'Trajectory Stop Date & Time in form YYMMDDHHMMSS .0D0 UTC': 1181111024200.0,
#    'Fractional seconds of Stop Time. UTC': 0.0,
#    'Trajectory Start Date & Time in MJDS': 2456427669.0,
#    'Fractional seconds of Start Time': 0.1839999999999975,
#    'Trajectory Stop Date & Time in MJDS': 2456620989.0,
#    'Fractional seconds of Stop Time. ET': 0.1839999999999975,
#    'Nominal interval between trajectory times in seconds. ET ': 6.0,
#    'Nominal number of trajectory times.': 32221.0,
#    'Output S/C ephem ref sys(0 = TOD, 1 = TOR, 2 =  J2000)': 2.0,
#    'Speed of Light.': 299792458.0,
#    'GM for Earth.': 398600441500000.0,
#    'Semi -major axis of Earth reference ellipsoid.': 6378136.3,
#    'Equatorial Flattening of Earth reference ellipsoid.': 0.0033528199227242064,
#    'Gravitational Potential Checksum.': 0.0,
#    'Maximum Degree of Gravitational Expansion.': 0.0,
#    'Maximum Order of Gravitational Expansion.': 0.0,
#    'Presence of right ascension of Greenwich for each time point in each Buffer': 1.0,
#    'Presence per Sat. of inertial X coordinate for each time point': 1.0,
#    'Presence per Sat. of inertial Y coordinate for each time point': 1.0,
#    'Presence per Sat. of inertial Z coordinate for each time point': 1.0,
#    'Presence per Sat. of inertial Xdot coordinate for each time point': 1.0,
#    'Presence per Sat. of inertial Ydot coordinate for each time point': 1.0,
#    'Presence per Sat. of inertial Zdot coordinate for each time point': 1.0,
#    'Presence per Sat. of geodetic latitude for each time point': 1.0,
#    'Presence per Sat. of east longitude for each time point': 1.0,
#    'Presence per Sat. of ECF X coordinate for each time point': 1.0,
#    'Presence per Sat. of ECF Y coordinate for each time point': 1.0,
#    'Presence per Sat. of ECF Z coordinate for each time point': 1.0,
#    'Presence per Sat. of ECF Xdot for each time point': 1.0,
#    'Presence per Sat. of ECF Ydot for each time point': 1.0,
#    'Presence per Sat. of ECF Zdot for each time point': 1.0,
#    'Presence per Sat. of polar motion X for each time point': 1.0,
#    'Presence per Sat. of polar motion Y for each time point': 1.0,
#    'Presence per Sat. of beta prime angle for each time point': 1.0,
#    'Presence per Sat. of yaw angle for each time point': 1.0,
#    'Presence per Sat. of orbit angle for each time point': 1.0,
#    'Satellite 1 ID': 1.0},
#   'data_record':             MJDSEC ET  Satellite Inertial X coordinate  \
#   0      2456427669.184                   -746390.950660
#   1      2456427675.184                   -743635.231410
#   2      2456427681.184                   -740846.441155
#   3      2456427687.184                   -738024.704539
#   4      2456427693.184                   -735170.147672
#   ...               ...                              ...
#   32216  2456620965.184                    -33506.394076
#   32217  2456620971.184                    -28286.022807
#   32218  2456620977.184                    -23064.393978
#   32219  2456620983.184                    -17841.739420
#   32220  2456620989.184                    -12618.291012
#
#          Satellite Inertial Y coordinate  Satellite Inertial Z coordinate  \
#   0                        -4.870283e+06                     4.764487e+06
#   1                        -4.838397e+06                     4.797198e+06
#   2                        -4.806296e+06                     4.829694e+06
#   3                        -4.773980e+06                     4.861975e+06
#   4                        -4.741453e+06                     4.894039e+06
#   ...                                ...                              ...
#   32216                     1.710445e+06                     6.633114e+06
#   32217                     1.754441e+06                     6.621667e+06
#   32218                     1.798359e+06                     6.609925e+06
#   32219                     1.842197e+06                     6.597888e+06
#   32220                     1.885954e+06                     6.585558e+06
#
#          Satellite Inertial X velocity  Satellite Inertial Y velocity  \
#   0                         456.523761                    5296.367378
#   1                         462.045901                    5332.352326
#   2                         467.547389                    5368.099464
#   3                         473.027980                    5403.607204
#   4                         478.487432                    5438.873969
#   ...                              ...                            ...
#   32216                     869.944205                    7339.070880
#   32217                     870.173114                    7326.248006
#   32218                     870.363389                    7313.099605
#   32219                     870.515022                    7299.626252
#   32220                     870.628005                    7285.828530
#
#          Satellite Inertial Z velocity  Satellite Geodetic Latitude  \
#   0                        5469.462882                    44.202885
#   1                        5433.923059                    44.585049
#   2                        5398.141491                    44.967179
#   3                        5362.119789                    45.349275
#   4                        5325.859573                    45.731336
#   ...                              ...                          ...
#   32216                   -1883.279204                    75.620015
#   32217                   -1932.473085                    75.243009
#   32218                   -1981.581435                    74.865810
#   32219                   -2030.602077                    74.488430
#   32220                   -2079.532836                    74.110882
#
#          Satellite East Longitude  Satellite Height            Date_UTC  \
#   0                    258.431818     486200.546986 2018-11-08 21:00:00
#   1                    258.380776     486276.420141 2018-11-08 21:00:06
#   2                    258.329392     486352.622851 2018-11-08 21:00:12
#   3                    258.277656     486429.135484 2018-11-08 21:00:18
#   4                    258.225560     486505.938402 2018-11-08 21:00:24
#   ...                         ...               ...                 ...
#   32216                  1.160097     492098.520762 2018-11-11 02:41:36
#   32217                  0.925856     492057.816861 2018-11-11 02:41:42
#   32218                  0.701806     492016.105486 2018-11-11 02:41:48
#   32219                  0.487210     491973.396339 2018-11-11 02:41:54
#   32220                  0.281396     491929.699353 2018-11-11 02:42:00
#
#              MJDS_UTC
#   0      2.456428e+09
#   1      2.456428e+09
#   2      2.456428e+09
#   3      2.456428e+09
#   4      2.456428e+09
#   ...             ...
#   32216  2.456621e+09
#   32217  2.456621e+09
#   32218  2.456621e+09
#   32219  2.456621e+09
#   32220  2.456621e+09
#
#   [32221 rows x 12 columns]}}

# %% [markdown]
# We can then look at the requested datasets by indexing them and their arc name

# %%
Obj_Geodyn.__dict__['Residuals_obs']['2018.313']
# Out:
#                       Date StatSatConfig  Sat_main   track_1   track_2  Note  \
# 0      2018-11-08 21:18:00     PCE X      1807001                        NaN
# 1      2018-11-08 21:18:01     PCE X      1807001                        NaN
# 2      2018-11-08 21:18:02     PCE X      1807001                        NaN
# 3      2018-11-08 21:18:03     PCE X      1807001                        NaN
# 4      2018-11-08 21:18:04     PCE X      1807001                        NaN
# ...                    ...           ...       ...       ...       ...   ...
# 317524 2018-11-10 02:41:56     PCE Z      1807001                        NaN
# 317525 2018-11-10 02:41:57     PCE Z      1807001                        NaN
# 317526 2018-11-10 02:41:58     PCE Z      1807001                        NaN
# 317527 2018-11-10 02:41:59     PCE Z      1807001                        NaN
# 317528 2018-11-10 02:42:00     PCE Z      1807001                        NaN
#
#         Observation  Residual  RatiotoSigma  Elev1  Elev2
# 0        112.441291  0.078443        0.0784    NaN    NaN
# 1        113.379497  0.078371        0.0784    NaN    NaN
# 2        114.317563  0.078299        0.0783    NaN    NaN
# 3        115.255489  0.078227        0.0782    NaN    NaN
# 4        116.193272  0.078155        0.0782    NaN    NaN
# ...             ...       ...           ...    ...    ...
# 317524   890.863474 -0.092598       -0.0926    NaN    NaN
# 317525   898.417483 -0.092298       -0.0923    NaN    NaN
# 317526   905.970379 -0.091997       -0.0920    NaN    NaN
# 317527   913.522151 -0.091697       -0.0917    NaN    NaN
# 317528   921.072792 -0.091396       -0.0914    NaN    NaN
#
# [317529 rows x 11 columns]
