# %%
# Kamodo_help/kamodo/readers/tiegcm_lr.py


# import sys  
# sys.path.insert(0, '/data/geodyn_proj/interface_kamodo_geodyn/Kamodo-master/')
# !pip install sympy --upgrade
# !pip list
# from kamodo import Kamodo


# from kamodo.readers.ctipe_faster_wrapped import CTIPe, ctipe_varnames
# Out:
# Package                       Version
# ----------------------------- -------------------
# aniso8601                     9.0.1
# antlr4-python3-runtime        4.7
# argon2-cffi                   20.1.0
# async-generator               1.10
# attrs                         21.2.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# bleach                        3.3.0
# brotlipy                      0.7.0
# certifi                       2021.5.30
# cffi                          1.14.5
# cftime                        1.5.0
# chardet                       4.0.0
# click                         8.0.1
# cryptography                  3.2.1
# decorator                     4.4.2
# defusedxml                    0.7.1
# entrypoints                   0.3
# Flask                         1.1.2
# Flask-Cors                    3.0.10
# Flask-RESTful                 0.3.8
# gmpy2                         2.1.0b1
# hydra-core                    0.11.3
# idna                          2.10
# importlib-metadata            4.4.0
# iniconfig                     1.1.1
# ipykernel                     5.3.4
# ipython                       7.24.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.3
# itsdangerous                  2.0.1
# jedi                          0.18.0
# Jinja2                        3.0.1
# jsonschema                    3.2.0
# jupyter                       1.0.0
# jupyter-client                6.1.12
# jupyter-console               6.4.0
# jupyter-core                  4.7.1
# jupyterlab-pygments           0.1.2
# jupyterlab-widgets            1.0.0
# kamodo                        0.0.4
# MarkupSafe                    2.0.1
# matplotlib-inline             0.1.2
# mistune                       0.8.4
# more-itertools                8.8.0
# mpmath                        1.2.1
# nbclient                      0.5.3
# nbconvert                     6.0.7
# nbformat                      5.1.3
# nest-asyncio                  1.5.1
# netCDF4                       1.5.6
# notebook                      6.4.0
# numpy                         1.19.4
# omegaconf                     1.4.1
# packaging                     20.9
# pandas                        1.1.4
# pandocfilters                 1.4.3
# parso                         0.8.2
# pexpect                       4.8.0
# pickleshare                   0.7.5
# pip                           21.1.1
# plotly                        4.14.3
# pluggy                        0.13.1
# prometheus-client             0.10.1
# prompt-toolkit                3.0.17
# ptyprocess                    0.7.0
# py                            1.10.0
# pycparser                     2.20
# Pygments                      2.9.0
# pyOpenSSL                     20.0.1
# pyparsing                     2.4.7
# pyrsistent                    0.17.3
# PySocks                       1.7.1
# pytest                        6.2.4
# python-dateutil               2.8.1
# python-forge                  18.6.0
# pytz                          2021.1
# PyYAML                        5.3.1
# pyzmq                         20.0.0
# qtconsole                     5.0.3
# QtPy                          1.9.0
# requests                      2.25.1
# retrying                      1.3.3
# scipy                         1.5.3
# Send2Trash                    1.5.0
# setuptools                    52.0.0.post20210125
# six                           1.16.0
# sympy                         1.8
# terminado                     0.9.4
# testpath                      0.4.4
# toml                          0.10.2
# tornado                       6.1
# traitlets                     5.0.5
# typing-extensions             3.7.4.3
# urllib3                       1.26.5
# wcwidth                       0.2.5
# webencodings                  0.5.1
# Werkzeug                      2.0.1
# wheel                         0.36.2
# widgetsnbextension            3.5.1
# zipp                          3.4.1

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-dbc2ce7caf89> in <module>
#       1 from sympy.physics.units import UnitSystem
#       2
# ----> 3 UnitSystem.get_unit_system
#
# AttributeError: type object 'UnitSystem' has no attribute 'get_unit_system'
