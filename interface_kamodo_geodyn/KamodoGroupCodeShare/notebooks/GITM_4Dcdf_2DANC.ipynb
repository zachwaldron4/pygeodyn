# %% [markdown]
# # GITM
#
#
# The kamodofied GITM requires `netCDF4` (and numpy, scipy, and pandas, but those are required by kamodo)
#
#     pip install netCDF4

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from kamodo.readers.gitm_4Dcdf import GITM, gitm_varnames
from plotly.offline import init_notebook_mode, iplot, plot
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# GITM data is allocated in one file per timestamp
file_prefix = 'C:/Users/rringuet/Kamodo_WinDev1/GITM/Data/2DANC_t061213'
run_name = "Emine_Kalafatoglu_040521_IT_6_20061213_outputs"

# %% [markdown]
# By default, the kamodofied IRI reader will load all 3d and 4d variables from the model. For performance reasons, you may want to only include certain variables for analysis. To do so, pass a list of variables in addition to the filename:

# %%
import time as ti
tic = ti.perf_counter()
gitm = GITM(file_prefix, runname=run_name, gridded_int=False, printfiles=False)  #load all variables
#gitm = GITM(file_prefix, variables_requested=['T_n','rho_e'], runname=run_name)  #correctly produces error if 'test' included in list
print(ti.perf_counter()-tic, 's')
# Out:
# Converting 144 files to netCDF4 for faster access time.
# Files of pattern C:/Users/rringuet/Kamodo_WinDev1/GITM/Data/2DANC_t061213*.bin converted to C:/Users/rringuet/Kamodo_WinDev1/GITM/Data/2DANC_t061213.nc in 0.92444s
# 1.6687445999999997 s

# %%
gitm
# Out:
# {SolarLocalTime(xvec): <function define_3d_interpolator.<locals>.interpolator at 0x000002829BB43E58>, SolarLocalTime: <function define_3d_interpolator.<locals>.interpolator at 0x000002829BB43E58>, SolarZenithAngle(xvec): <function define_3d_interpolator.<locals>.interpolator at 0x000002829BB50558>, SolarZenithAngle: <function define_3d_interpolator.<locals>.interpolator at 0x000002829BB50558>, TEC(xvec): <function define_3d_interpolator.<locals>.interpolator at 0x000002829BB50798>, TEC: <function define_3d_interpolator.<locals>.interpolator at 0x000002829BB50798>, phi_qJoule(xvec): <function define_3d_interpolator.<locals>.interpolator at 0x000002829BB50828>, phi_qJoule: <function define_3d_interpolator.<locals>.interpolator at 0x000002829BB50828>, phi_q(xvec): <function define_3d_interpolator.<locals>.interpolator at 0x000002829BB50C18>, phi_q: <function define_3d_interpolator.<locals>.interpolator at 0x000002829BB50C18>, phi_qEUV(xvec): <function define_3d_interpolator.<locals>.interpolator at 0x000002829BB50EE8>, phi_qEUV: <function define_3d_interpolator.<locals>.interpolator at 0x000002829BB50EE8>, phi_qNOCooling(xvec): <function define_3d_interpolator.<locals>.interpolator at 0x000002829CB8A048>, phi_qNOCooling: <function define_3d_interpolator.<locals>.interpolator at 0x000002829CB8A048>}

# %%
for key in gitm.variables.keys(): 
    print(key, gitm.variables[key]['xvec'], type(key))
# Out:
# SolarLocalTime {'time': 's', 'lat': 'deg', 'lon': 'deg'} <class 'str'>
# SolarZenithAngle {'time': 's', 'lat': 'deg', 'lon': 'deg'} <class 'str'>
# TEC {'time': 's', 'lat': 'deg', 'lon': 'deg'} <class 'str'>
# phi_qJoule {'time': 's', 'lat': 'deg', 'lon': 'deg'} <class 'str'>
# phi_q {'time': 's', 'lat': 'deg', 'lon': 'deg'} <class 'str'>
# phi_qEUV {'time': 's', 'lat': 'deg', 'lon': 'deg'} <class 'str'>
# phi_qNOCooling {'time': 's', 'lat': 'deg', 'lon': 'deg'} <class 'str'>

# %%
np.array([key for key in gitm.variables.keys() if len(gitm.variables[key]['xvec'].keys())==3])
# Out:
# array(['SolarLocalTime', 'SolarZenithAngle', 'TEC', 'phi_qJoule', 'phi_q',
#        'phi_qEUV', 'phi_qNOCooling'], dtype='<U16')

# %%
help(gitm.make_plot)
# Out:
# Help on method make_plot in module kamodo.readers.gitm_4Dcdf:
#
# make_plot(var, plottype, cutV=0, cutL=0, timerange={}, lonrange={}, latrange={}, htrange={}, colorscale='Viridis', datascale='linear', ellipse=False) method of kamodo.readers.gitm_4Dcdf.GITM instance
#     Simplified call for plots. Execute with iplot(self.make_plot(....))
#     Possible plottypes: LonLat, LonH, LatH, TimeLon, TimeLat, TimeH

# %%
#automatically determines height dependency of variable 
#and chooses correct version of plot with proper default cuts and variable ranges.
iplot(gitm.make_plot('phi_qJoule','LonLat'))
# Out:
# Variable has no height dependence.
# cutV outside of data range (659.8886108398438 km, 659.8886108398438 km). Using average: 659.8886108398438 km.
# Time resetting plot and precomputing interpolations: 0.0014 seconds
# set_plot::colorscale=Viridis, datascale=linear
# Run: Emine_Kalafatoglu_040521_IT_6_20061213_outputs
# <div>                            <div id="da7df278-e501-4432-a04e-7cd3a501e68f" class="plotly-graph-div" style="height:390px; width:780.0px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da7df278-e501-4432-a04e-7cd3a501e68f")) {                    Plotly.newPlot(                        "da7df278-e501-4432-a04e-7cd3a501e68f",                        [{"colorbar": {"tickformat": ".4g", "title": {"text": "phi_qJoule [W/m**2]"}}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "contours": {"coloring": "fill", "showlines": false}, "hovertemplate": "X: %{x:.2f}<br>Y: %{y:.2f}<br><b> %{z:.4g}</b><extra></extra>", "meta": "2d-grid", "ncontours": 201, "type": "contour", "x": [0.0, 3.364485981308411, 6.728971962616822, 10.093457943925234, 13.457943925233645, 16.822429906542055, 20.186915887850468, 23.551401869158877, 26.91588785046729, 30.2803738317757, 33.64485981308411, 37.00934579439252, 40.373831775700936, 43.73831775700935, 47.10280373831775, 50.467289719626166, 53.83177570093458, 57.19626168224299, 60.5607476635514, 63.92523364485981, 67.28971962616822, 70.65420560747664, 74.01869158878505, 77.38317757009345, 80.74766355140187, 84.11214953271028, 87.4766355140187, 90.8411214953271, 94.2056074766355, 97.57009345794393, 100.93457943925233, 104.29906542056075, 107.66355140186916, 111.02803738317756, 114.39252336448598, 117.75700934579439, 121.1214953271028, 124.48598130841121, 127.85046728971962, 131.21495327102804, 134.57943925233644, 137.94392523364485, 141.30841121495328, 144.6728971962617, 148.0373831775701, 151.4018691588785, 154.7663551401869, 158.13084112149534, 161.49532710280
0.0, 6.0, 12.0, 18.0, 24.0, 30.0, 36.0, 42.0, 48.0, 54.0, 60.0, 66.0, 72.0, 78.0, ...

# %%
#If empty dictionary given, total range for variable is used
iplot(gitm.make_plot('phi_qNOCooling','TimeLat',cutV=200,cutL=50,latrange={},timerange={}))
# Out:
# Variable has no height dependence.
# cutV outside of data range (659.8886108398438 km, 659.8886108398438 km). Using average: 659.8886108398438 km.
# Time resetting plot and precomputing interpolations: 0.0016 seconds
# set_plot::colorscale=Viridis, datascale=linear
# Run: Emine_Kalafatoglu_040521_IT_6_20061213_outputs
# <div>                            <div id="528ae235-68f8-4a32-adb4-235a9add95a7" class="plotly-graph-div" style="height:390px; width:630.0px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("528ae235-68f8-4a32-adb4-235a9add95a7")) {                    Plotly.newPlot(                        "528ae235-68f8-4a32-adb4-235a9add95a7",                        [{"colorbar": {"tickformat": ".4g", "title": {"text": "phi_qNOCooling [W/m**2]"}}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "contours": {"coloring": "fill", "showlines": false}, "hovertemplate": "X: %{x:.2f}<br>Y: %{y:.2f}<br><b> %{z:.4g}</b><extra></extra>", "meta": "2d-grid", "ncontours": 201, "type": "contour", "x": [0.0, 0.1666686013986014, 0.3333372027972028, 0.5000058041958042, 0.6666744055944056, 0.833343006993007, 1.0000116083916084, 1.1666802097902098, 1.3333488111888112, 1.5000174125874126, 1.666686013986014, 1.8333546153846154, 2.000023216783217, 2.1666918181818184, 2.3333604195804196, 2.500029020979021, 2.6666976223776224, 2.833366223776224, 3.0000348251748252, 3.1667034265734264, 3.333372027972028, 3.5000406293706297, 3.666709230769231, 3.833377832167832, 4.000046433566434, 4.166715034965035, 4.333383636363637, 4.500052237762238, 4.666720839160839, 4.833389440559441, 5.000058041958042, 5.166726643356643, 5.333395244755245, 5.5000638461538465, 5.666732447552448, 5.833401048951049, 6.0000696503496505, 6.166738251748252, 6.333406853146853, 6.500075454545454, 6.666744055944056, 6.833412657342658, 7.000081258741259, 7.16674986013986, 7.333418461538462, 7.500087062937063, 7.666755664335664, 7.833424265734266, 8.000092867132867, 8.166761468531469, 8.33343006993007, 8.500098671328672, 8.666767272727274, 8.833435874125874, 9.000104475524475, 9.166773076923077, 9.333441678321678, 9.50011027972028, 9.666778881118882, 9.833447482517483, 10.000116083916083, 10.166784685314685, 10.333453286713286, 10.500121888111888, 10.66679048951049, 10.833459090909091, 11.000127692307693, 11.166796293706295, 11.333464895104896, 11.500133496503496, 11.666802097902098, 11.8334706993007, 12.000139300699301, 12.166807902097903, 12.333476503496504, 12.500145104895106, 12.666813706293706, 12.833482307692307, 13.000150909090909, 13.16681951048951, 13.333488111888112, 13.500156713286714, 13.666825314685315, 13.833493916083917, 14.000162517482519, 14.166831118881118, 14.33349972027972, 14.500168321678322, 14.666836923076923, 14.833505524475525, 15.000174125874127, 15.166842727272728, 15.333511328671328, 15.50017993006993, 15.666848531468531, 15.833517132867133, 16.000185734265735, 16.166854335664336, 16.333522937062938, 16.50019153846154, 16.66686013986014, 16.833528741258743, 17.000197342657344, 17.166865944055946, 17.333534545454548, 17.500203146853146, 17.666871748251747, 17.83354034965035, 18.00020895104895, 18.166877552447552, 18.333546153846154, 18.500214755244755, 18.666883356643357, 18.83355195804196, 19.00022055944056, 19.166889160839162, 19.333557762237763, 19.500226363636365, 19.666894965034967, 19.83356356643357, 20.000232167832166, 20.166900769230768, 20.33356937062937, 20.50023797202797, 20.666906573426573, 20.833575174825175, 21.000243776223776, 21.166912377622378, 21.33358097902098, 21.50024958041958, 21.666918181818183, 21.833586783216784, 22.000255384615386, 22.166923986013988, 22.33359258741259, 22.50026118881119, 22.666929790209792, 22.83359839160839, 23.000266993006992, 23.166935594405594, 23.333604195804195, 23.500272797202797, 23.6669413986014, 23.83361], "y": [-90.0, -86.60377358490567, -83.20754716981132, -79.81132075471697, -76.4150 ...

# %%
#can default to entire time range in file and choose sampling
iplot(gitm.make_plot('phi_qNOCooling','TimeH',cutL=15,cutV=20, timerange={'n':1000}, datascale='log'))
# Out:
# Variable has no height dependence.
# Choose a different plot type.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-b8587f40eca3> in <module>
#       1 #can default to entire time range in file and choose sampling
# ----> 2 iplot(gitm.make_plot('phi_qNOCooling','TimeH',cutL=15,cutV=20, timerange={'n':1000}, datascale='log'))
#
# c:\users\rringuet\kamodo_windev1\kamodo-master\kamodo\readers\gitm_4Dcdf.py in make_plot(self, var, plottype, cutV, cutL, timerange, lonrange, latrange, htrange, colorscale, datascale, ellipse)
#     316
#     317         test = self.set_plot(var, plottype, cutV=cutV, cutL=cutL, timerange=timerange,
# --> 318                  lonrange=lonrange, latrange=latrange, htrange=htrange)
#     319         if test==1: return {} #if plottype requested invalid for variable, do nothing
#     320         fig = self.get_plot(var, colorscale=colorscale, datascale=datascale, ellipse=ellipse)
#
# c:\users\rringuet\kamodo_windev1\kamodo-master\kamodo\readers\gitm_4Dcdf.py in set_plot(self, var, plottype, cutV, cutL, timerange, lonrange, latrange, htrange)
#     273         if test==0: return
#     274         else: self=test
# --> 275         self = RU.setup_interpolating_grids(self,var)
#     276         toc = ti.perf_counter()  #end timer
#     277         print(f"Time resetting plot and precomputing interpolations: {toc - tic:0.4f} seconds")
#
# c:\users\rringuet\kamodo_windev1\kamodo-master\kamodo\readers\reader_utilities.py in setup_interpolating_grids(kamodo_object, var)
#     120     '''setup the grid for interpolation with or without height dependence'''
#     121
# --> 122     if len(kamodo_object.variables[var]['xvec'].keys())==4: #with height dependence
#     123         tt, xx, yy, zz = np.meshgrid(kamodo_object.newt,kamodo_object.newx,kamodo_object.newy,kamodo_object.newz, indexing = 'xy')
#     124         kamodo_object.newgrid = np.array([np.ravel(tt), np.ravel(xx), np.ravel(yy), np.ravel(zz)]).T
#
# AttributeError: 'int' object has no attribute 'variables'
