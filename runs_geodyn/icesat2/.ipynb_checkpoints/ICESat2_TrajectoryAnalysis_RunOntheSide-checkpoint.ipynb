# %%
import copy
import sys
import os.path
import numpy as np

# %%
# path_to_binaryrvg   = '/data/data_geodyn/inputs/icesat2/pre_processing/traj_files_rvg'
path_to_binaryrvg   = '/data/data_geodyn/inputs/icesat2/setups'


# iisset.2018.287.bz2
years = [2018]     #,2019]
days = np.arange(0, 367)

files_list = []
count_noletter = 0
countA = 0
countB = 0

for iyear,year in enumerate(years):
    for iday,day in enumerate(days):
#         filename = 'orbit.1807001.%d.%03d' % (year, day)
        filename = 'iisset.%d.%03d' % (year, day)

#         filename = '%d.%03d' % (year, day)
        __filename = path_to_binaryrvg+ '/'+filename
        arc = '%d.%03d' % (year, day)
        if os.path.exists(__filename):
            count_noletter+=1
            files_list.append(arc)
        if os.path.exists(__filename + 'A'):
            countA += 1
            pass
        if os.path.exists(__filename + 'B'):
            countB += 1
            pass
        if os.path.exists(__filename + '.gz'):
            count_noletter+=1
            files_list.append(arc + '')
        if os.path.exists(__filename + 'A.gz'):
            countA += 1
            pass
        if os.path.exists(__filename + 'B.gz'):
            countB += 1
            pass
        if os.path.exists(__filename + '.bz2'):
            count_noletter+=1
            files_list.append(arc + '')
        if os.path.exists(__filename + 'A.bz2'):
            countA += 1
            pass
        if os.path.exists(__filename + 'B.bz2'):
            countB += 1
            pass

# %%
# files_list #[48:]

# %%
# %load_ext autoreload
# %autoreload 2

# import sys
# sys.path.insert(0,'/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/util_preprocessing/')
# from PYGEODYN_Preprocess import PygeodynPreprocessing

# path_to_prep_directory = '/data/data_geodyn/inputs/icesat2/pre_processing'
# path_to_binaryrvg     = '/data/data_geodyn/inputs/icesat2/pre_processing/traj_files_rvg'

# # ##### Uncomment the below call to overwrite the G2B data by re-running the pre-processing code
# Obj = PygeodynPreprocessing(path_to_binaryrvg, path_to_prep_directory,  files_list)
# Obj.run_preprocess_PCE()

# %% [markdown]
# ## Step 1: Run GEODYN using Pygeodyn with the ICESat2 configuration
#
# As a reminder, PYGEODYN is called with the `PYGEODYN` class, but modifications to the ICESAT2 configuration are largely controlled through the `Satellite_ICESat2` class in the `PYGEODYN_Satellites.py` file.   Please refer to this file first for file structure setups and modifications to the Pygeodyn structure.
#
# ### Step 1.1:  Run with MSIS2

# %%
arc_list = files_list[1:]
len(arc_list)
# Out:
# 57

# %%
### Identify which arcs you want to run:


sys.path.insert(0, '/data/geodyn_proj/pygeodyn/pygeodyn_develop/')

#------ A dictionary containing the run parameters ------  
run_params = {} 
run_params['arc']              =   arc_list
run_params['satellite']        =  'icesat2'  
run_params['SpecialRun_name']  =  '_TrajAnalysis'  
run_params['verbose']          =  False
run_params['action']           =  'run'

# %%
# %load_ext autoreload
# %autoreload 2

# sys.path.insert(0, '/data/geodyn_proj/pygeodyn/pygeodyn_develop/')
# from PYGEODYN import Pygeodyn


# #### ---------------------------------------------
# ####
# #### ----------------- RUN MSIS2.0 --------------- 
# ####
# #### ---------------------------------------------

# ##### Use copy.deepcopy to copy all levels of dictionary and 
# ###       allow modification of new variable
# run_params1 = copy.deepcopy(run_params)
# run_params1['den_model'] =  'msis2'  

# ### Run pyeodyn for the arcs in the above set.
# Obj_Geodyn = Pygeodyn(run_params1)
# Obj_Geodyn.RUN_GEODYN()

# %%
# %load_ext autoreload
# %autoreload 2

# from PYGEODYN import Pygeodyn


# #### ---------------------------------------------
# ####
# #### ----------------- RUN MSIS00 --------------- 
# ####
# #### ---------------------------------------------

# ##### Use copy.deepcopy to copy all levels of dictionary and 
# ###       allow modification of new variable
# run_params2 = copy.deepcopy(run_params)
# run_params2['den_model'] =  'msis00'  

# ### Run pyeodyn for the arcs in the above set.
# Obj_Geodyn = Pygeodyn(run_params2)
# Obj_Geodyn.RUN_GEODYN()

# %%
arc_msis86 = arc_list[-4:]
arc_msis86
# Out:
# ['2018.358', '2018.359', '2018.364', '2018.365']

# %%
# %load_ext autoreload
# %autoreload 2

from PYGEODYN import Pygeodyn


#### ---------------------------------------------
####
#### ----------------- RUN MSIS86 --------------- 
####
#### ---------------------------------------------

##### Use copy.deepcopy to copy all levels of dictionary and 
###       allow modification of new variable
run_params3 = copy.deepcopy(run_params)
run_params3['den_model'] =  'msis86'  
run_params3['arc'] =  arc_msis86  

### Run pyeodyn for the arcs in the above set.
Obj_Geodyn = Pygeodyn(run_params3)
Obj_Geodyn.RUN_GEODYN()
# Out:
#                       ......... RUNNING GEODYN
# Run # 1     Current Time =      22:48:06
# Run # 1
# Run # 1     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.358.bz2
# Epoch Start:  2018-12-23 21:00:00
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 1     IISSET Cleaned      tmp/.../cleaned_setup_2018358
# |  Run # 1     Density Model:      msis86
# |  Run # 1     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 1     ARC run:            icesat2_2018358_54hr.msis86
# |  Run # 1     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 1     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.358.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 1          Running IIS
# Run # 1          No errors in IIS
# Run # 1 ---------End of IIS
#
# Run # 1          Running IIE
# Run # 1          Current Time = 22:49:55
# Run # 1          No errors in IIE
# Run # 1 ---------End of IIE
# Run # 1          Time of IIE:  442.832270860672 secs ( 7.380537847677867  mins)
# Run # 1          Current Time = 22:57:18
# Run # 1                Finished renaming files
# Run # 1                Finished copying files to outputdir
# Run # 2     Current Time =      22:57:22
# Run # 2
# Run # 2     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.359.bz2
# Epoch Start:  2018-12-24 21:00:00
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 2     IISSET Cleaned      tmp/.../cleaned_setup_2018359
# |  Run # 2     Density Model:      msis86
# |  Run # 2     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 2     ARC run:            icesat2_2018359_54hr.msis86
# |  Run # 2     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 2     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.359.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 2          Running IIS
# Run # 2          No errors in IIS
# Run # 2 ---------End of IIS
#
# Run # 2          Running IIE
# Run # 2          Current Time = 22:59:00
# Run # 2          No errors in IIE
# Run # 2 ---------End of IIE
# Run # 2          Time of IIE:  416.3193094730377 secs ( 6.938655157883962  mins)
# Run # 2          Current Time = 23:05:57
# Run # 2                Finished renaming files
# Run # 2                Finished copying files to outputdir
# Run # 3     Current Time =      23:06:00
# Run # 3
# Run # 3     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.364.bz2
# Epoch Start:  2018-12-29 21:00:00
# 2018-12-29 21:00:00 not found in file.  Leaving ELEMS as is.
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 3     IISSET Cleaned      tmp/.../cleaned_setup_2018364
# |  Run # 3     Density Model:      msis86
# |  Run # 3     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 3     ARC run:            icesat2_2018364_54hr.msis86
# |  Run # 3     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 3     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.364.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 3          Running IIS
# Run # 3          No errors in IIS
# Run # 3 ---------End of IIS
#
# Run # 3          Running IIE
# Run # 3          Current Time = 23:07:37
# Run # 3          No errors in IIE
# Run # 3 ---------End of IIE
# Run # 3          Time of IIE:  668.5440828800201 secs ( 11.142401381333668  mins)
# Run # 3          Current Time = 23:18:46
# Run # 3                Finished renaming files
# Run # 3                Finished copying files to outputdir
# Run # 4     Current Time =      23:18:49
# Run # 4
# Run # 4     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.365.bz2
# Epoch Start:  2018-12-30 21:00:00
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 4     IISSET Cleaned      tmp/.../cleaned_setup_2018365
# |  Run # 4     Density Model:      msis86
# |  Run # 4     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 4     ARC run:            icesat2_2018365_54hr.msis86
# |  Run # 4     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 4     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.365.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 4          Running IIS
# Run # 4          No errors in IIS
# Run # 4 ---------End of IIS
#
# Run # 4          Running IIE
# Run # 4          Current Time = 23:20:28
# Run # 4          No errors in IIE
# Run # 4 ---------End of IIE
# Run # 4          Time of IIE:  444.9086000919342 secs ( 7.41514333486557  mins)
# Run # 4          Current Time = 23:27:53
# Run # 4                Finished renaming files
# Run # 4                Finished copying files to outputdir

# %%
# %load_ext autoreload
# %autoreload 2

from PYGEODYN import Pygeodyn

#### ---------------------------------------------
####
#### ------------------- RUN DTM ----------------- 
####
#### ---------------------------------------------


##### Use copy.deepcopy to copy all levels of dictionary and 
###       allow modification of new variable
run_params2 = copy.deepcopy(run_params)
run_params2['den_model']         =  'dtm87'  

### Run pyeodyn for the arcs in the above set.
Obj_Geodyn = Pygeodyn(run_params2)
Obj_Geodyn.RUN_GEODYN()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#                       ......... RUNNING GEODYN
# Run # 1     Current Time =      23:27:58
# Run # 1
# Run # 1     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.288.bz2
# Epoch Start:  2018-10-14 21:00:00
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 1     IISSET Cleaned      tmp/.../cleaned_setup_2018288
# |  Run # 1     Density Model:      dtm87
# |  Run # 1     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 1     ARC run:            icesat2_2018288_54hr.dtm87
# |  Run # 1     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 1     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.288.gz
# |
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 1          Running IIS
# Run # 1          No errors in IIS
# Run # 1 ---------End of IIS
#
# Run # 1          Running IIE
# Run # 1          Current Time = 23:29:11
# Run # 1          No errors in IIE
# Run # 1 ---------End of IIE
# Run # 1          Time of IIE:  414.93110394477844 secs ( 6.915518399079641  mins)
# Run # 1          Current Time = 23:36:06
# Run # 1                Finished renaming files
# Run # 1                Finished copying files to outputdir
# Run # 2     Current Time =      23:36:10
# Run # 2
# Run # 2     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.291.bz2
# Epoch Start:  2018-10-17 21:00:00
# 2018-10-17 21:00:00 not found in file.  Leaving ELEMS as is.
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 2     IISSET Cleaned      tmp/.../cleaned_setup_2018291
# |  Run # 2     Density Model:      dtm87
# |  Run # 2     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 2     ARC run:            icesat2_2018291_54hr.dtm87
# |  Run # 2     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 2     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.291.gz
# |
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 2          Running IIS
# Run # 2          No errors in IIS
# Run # 2 ---------End of IIS
#
# Run # 2          Running IIE
# Run # 2          Current Time = 23:37:32
# Run # 2          No errors in IIE
# Run # 2 ---------End of IIE
# Run # 2          Time of IIE:  594.2428810596466 secs ( 9.904048017660777  mins)
# Run # 2          Current Time = 23:47:26
# Run # 2                Finished renaming files
# Run # 2                Finished copying files to outputdir
# Run # 3     Current Time =      23:47:30
# Run # 3
# Run # 3     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.292.bz2
# Epoch Start:  2018-10-18 21:00:00
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 3     IISSET Cleaned      tmp/.../cleaned_setup_2018292
# |  Run # 3     Density Model:      dtm87
# |  Run # 3     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 3     ARC run:            icesat2_2018292_54hr.dtm87
# |  Run # 3     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 3     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.292.gz
# |
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 3          Running IIS
# Run # 3          No errors in IIS
# Run # 3 ---------End of IIS
#
# Run # 3          Running IIE
# Run # 3          Current Time = 23:48:44
# Run # 3          No errors in IIE
# Run # 3 ---------End of IIE
# Run # 3          Time of IIE:  520.8876147270203 secs ( 8.681460245450337  mins)
# Run # 3          Current Time = 23:57:25
# Run # 3                Finished renaming files
# Run # 3                Finished copying files to outputdir
# Run # 4     Current Time =      23:57:29
# Run # 4
# Run # 4     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.293.bz2
# Epoch Start:  2018-10-19 21:00:00
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 4     IISSET Cleaned      tmp/.../cleaned_setup_2018293
# |  Run # 4     Density Model:      dtm87
# |  Run # 4     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 4     ARC run:            icesat2_2018293_54hr.dtm87
# |  Run # 4     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 4     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.293.gz
# |
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 4          Running IIS
# Run # 4          No errors in IIS
# Run # 4 ---------End of IIS
#
# Run # 4          Running IIE
# Run # 4          Current Time = 23:58:43
# Run # 4          No errors in IIE
# Run # 4 ---------End of IIE
# Run # 4          Time of IIE:  597.7117781639099 secs ( 9.9618629693985  mins)
# Run # 4          Current Time = 00:08:41
# Run # 4                Finished renaming files
# Run # 4                Finished copying files to outputdir
# Run # 5     Current Time =      00:08:45
# Run # 5
# Run # 5     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.294.bz2
# Epoch Start:  2018-10-20 21:00:00
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 5     IISSET Cleaned      tmp/.../cleaned_setup_2018294
# |  Run # 5     Density Model:      dtm87
# |  Run # 5     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 5     ARC run:            icesat2_2018294_54hr.dtm87
# |  Run # 5     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 5     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.294.gz
# |
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 5          Running IIS
# Run # 5          No errors in IIS
# Run # 5 ---------End of IIS
#
# Run # 5          Running IIE
# Run # 5          Current Time = 00:10:00
# Run # 5          No errors in IIE
# Run # 5 ---------End of IIE
# Run # 5          Time of IIE:  518.849928855896 secs ( 8.647498814264933  mins)
# Run # 5          Current Time = 00:18:39
# Run # 5                Finished renaming files
# Run # 5                Finished copying files to outputdir
# Run # 6     Current Time =      00:18:44
# Run # 6
# Run # 6     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.295.bz2
# Epoch Start:  2018-10-21 21:00:00
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 6     IISSET Cleaned      tmp/.../cleaned_setup_2018295
# |  Run # 6     Density Model:      dtm87
# |  Run # 6     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 6     ARC run:            icesat2_2018295_54hr.dtm87
# |  Run # 6     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 6     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.295.gz
# |
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 6          Running IIS
# Run # 6          No errors in IIS
# Run # 6 ---------End of IIS
#
# Run # 6          Running IIE
# Run # 6          Current Time = 00:19:59
# Run # 6          No errors in IIE
# Run # 6 ---------End of IIE
# Run # 6          Time of IIE:  669.4716475009918 secs ( 11.157860791683197  mins)
# Run # 6          Current Time = 00:31:09
# Run # 6                Finished renaming files
# Run # 6                Finished copying files to outputdir
# Run # 7     Current Time =      00:31:13
# Run # 7
# Run # 7     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.296.bz2
# Epoch Start:  2018-10-22 21:00:00
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 7     IISSET Cleaned      tmp/.../cleaned_setup_2018296
# |  Run # 7     Density Model:      dtm87
# |  Run # 7     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 7     ARC run:            icesat2_2018296_54hr.dtm87
# |  Run # 7     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 7     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.296.gz
# |
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 7          Running IIS
# Run # 7          No errors in IIS
# Run # 7 ---------End of IIS
#
# Run # 7          Running IIE
# Run # 7          Current Time = 00:32:29
# Run # 7          No errors in IIE
# Run # 7 ---------End of IIE
# Run # 7          Time of IIE:  445.61136293411255 secs ( 7.426856048901876  mins)
# Run # 7          Current Time = 00:39:55
# Run # 7                Finished renaming files
# Run # 7                Finished copying files to outputdir
# Run # 8     Current Time =      00:39:59
# Run # 8
# Run # 8     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.297.bz2
# Epoch Start:  2018-10-23 21:00:00
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 8     IISSET Cleaned      tmp/.../cleaned_setup_2018297
# |  Run # 8     Density Model:      dtm87
# |  Run # 8     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 8     ARC run:            icesat2_2018297_54hr.dtm87
# |  Run # 8     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 8     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.297.gz
# |
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 8          Running IIS
# Run # 8          No errors in IIS
# Run # 8 ---------End of IIS
#
# Run # 8          Running IIE
# Run # 8          Current Time = 00:41:16
# Run # 8          No errors in IIE
# Run # 8 ---------End of IIE
# Run # 8          Time of IIE:  520.4198606014252 secs ( 8.673664343357085  mins)
# Run # 8          Current Time = 00:49:57
# Run # 8                Finished renaming files
# Run # 8                Finished copying files to outputdir
# Run # 9     Current Time =      00:50:01
# Run # 9
# Run # 9     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.298.bz2
# Epoch Start:  2018-10-24 21:00:00
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 9     IISSET Cleaned      tmp/.../cleaned_setup_2018298
# |  Run # 9     Density Model:      dtm87
# |  Run # 9     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 9     ARC run:            icesat2_2018298_54hr.dtm87
# |  Run # 9     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 9     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.298.gz
# |
# + ————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 9          Running IIS
# Run # 9          No errors in IIS
# Run # 9 ---------End of IIS
#
# Run # 9          Running IIE
# Run # 9          Current Time = 00:51:20
# Run # 9          No errors in IIE
# Run # 9 ---------End of IIE
# Run # 9          Time of IIE:  519.353764295578 secs ( 8.655896071592966  mins)
# Run # 9          Current Time = 00:59:59
# Run # 9                Finished renaming files
# Run # 9                Finished copying files to outputdir
# Run # 10     Current Time =      01:00:03
# Run # 10
# Run # 10     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.299.bz2
# Epoch Start:  2018-10-25 21:00:00
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 10     IISSET Cleaned      tmp/.../cleaned_setup_2018299
# |  Run # 10     Density Model:      dtm87
# |  Run # 10     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 10     ARC run:            icesat2_2018299_54hr.dtm87
# |  Run # 10     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 10     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.299.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 10          Running IIS
# Run # 10          No errors in IIS
# Run # 10 ---------End of IIS
#
# Run # 10          Running IIE
# Run # 10          Current Time = 01:01:22
# Run # 10          No errors in IIE
# Run # 10 ---------End of IIE
# Run # 10          Time of IIE:  592.1684367656708 secs ( 9.869473946094512  mins)
# Run # 10          Current Time = 01:11:14
# Run # 10                Finished renaming files
# Run # 10                Finished copying files to outputdir
# Run # 11     Current Time =      01:11:19
# Run # 11
# Run # 11     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.300.bz2
# Epoch Start:  2018-10-26 21:00:00
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 11     IISSET Cleaned      tmp/.../cleaned_setup_2018300
# |  Run # 11     Density Model:      dtm87
# |  Run # 11     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 11     ARC run:            icesat2_2018300_54hr.dtm87
# |  Run # 11     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 11     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.300.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 11          Running IIS
# Run # 11          No errors in IIS
# Run # 11 ---------End of IIS
#
# Run # 11          Running IIE
# Run # 11          Current Time = 01:12:37
# Run # 11          No errors in IIE
# Run # 11 ---------End of IIE
# Run # 11          Time of IIE:  557.7758617401123 secs ( 9.296264362335204  mins)
# Run # 11          Current Time = 01:21:55
# Run # 11                Finished renaming files
# Run # 11                Finished copying files to outputdir
# Run # 12     Current Time =      01:21:59
# Run # 12
# Run # 12     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.303.bz2
# Epoch Start:  2018-10-29 21:00:00
# 2018-10-29 21:00:00 not found in file.  Leaving ELEMS as is.
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 12     IISSET Cleaned      tmp/.../cleaned_setup_2018303
# |  Run # 12     Density Model:      dtm87
# |  Run # 12     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 12     ARC run:            icesat2_2018303_54hr.dtm87
# |  Run # 12     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 12     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.303.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 12          Running IIS
# Run # 12          No errors in IIS
# Run # 12 ---------End of IIS
#
# Run # 12          Running IIE
# Run # 12          Current Time = 01:23:30
# Run # 12          No errors in IIE
# Run # 12 ---------End of IIE
# Run # 12          Time of IIE:  663.7588965892792 secs ( 11.062648276487986  mins)
# Run # 12          Current Time = 01:34:34
# Run # 12                Finished renaming files
# Run # 12                Finished copying files to outputdir
# Run # 13     Current Time =      01:34:39
# Run # 13
# Run # 13     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.304.bz2
# Epoch Start:  2018-10-30 21:00:00
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 13     IISSET Cleaned      tmp/.../cleaned_setup_2018304
# |  Run # 13     Density Model:      dtm87
# |  Run # 13     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 13     ARC run:            icesat2_2018304_54hr.dtm87
# |  Run # 13     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 13     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.304.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 13          Running IIS
# Run # 13          No errors in IIS
# Run # 13 ---------End of IIS
#
# Run # 13          Running IIE
# Run # 13          Current Time = 01:35:58
# Run # 13          No errors in IIE
# Run # 13 ---------End of IIE
# Run # 13          Time of IIE:  684.0338923931122 secs ( 11.400564873218537  mins)
# Run # 13          Current Time = 01:47:23
# Run # 13                Finished renaming files
# Run # 13                Finished copying files to outputdir
# Run # 14     Current Time =      01:47:27
# Run # 14
# Run # 14     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.305.bz2
# Epoch Start:  2018-10-31 21:00:00
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 14     IISSET Cleaned      tmp/.../cleaned_setup_2018305
# |  Run # 14     Density Model:      dtm87
# |  Run # 14     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 14     ARC run:            icesat2_2018305_54hr.dtm87
# |  Run # 14     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 14     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.305.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 14          Running IIS
# Run # 14          No errors in IIS
# Run # 14 ---------End of IIS
#
# Run # 14          Running IIE
# Run # 14          Current Time = 01:48:48
# Run # 14          No errors in IIE
# Run # 14 ---------End of IIE
# Run # 14          Time of IIE:  671.7480566501617 secs ( 11.195800944169362  mins)
# Run # 14          Current Time = 02:00:00
# Run # 14                Finished renaming files
# Run # 14                Finished copying files to outputdir
# Run # 15     Current Time =      02:00:05
# Run # 15
# Run # 15     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.306.bz2
# Epoch Start:  2018-11-01 21:00:00
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 15     IISSET Cleaned      tmp/.../cleaned_setup_2018306
# |  Run # 15     Density Model:      dtm87
# |  Run # 15     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 15     ARC run:            icesat2_2018306_54hr.dtm87
# |  Run # 15     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 15     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.306.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 15          Running IIS
# Run # 15          No errors in IIS
# Run # 15 ---------End of IIS
#
# Run # 15          Running IIE
# Run # 15          Current Time = 02:01:26
# Run # 15          No errors in IIE
# Run # 15 ---------End of IIE
# Run # 15          Time of IIE:  593.6978814601898 secs ( 9.894964691003164  mins)
# Run # 15          Current Time = 02:11:20
# Run # 15                Finished renaming files
# Run # 15                Finished copying files to outputdir
# Run # 16     Current Time =      02:11:24
# Run # 16
# Run # 16     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.307.bz2
# Epoch Start:  2018-11-02 21:00:00
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 16     IISSET Cleaned      tmp/.../cleaned_setup_2018307
# |  Run # 16     Density Model:      dtm87
# |  Run # 16     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 16     ARC run:            icesat2_2018307_54hr.dtm87
# |  Run # 16     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 16     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.307.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 16          Running IIS
# Run # 16          No errors in IIS
# Run # 16 ---------End of IIS
#
# Run # 16          Running IIE
# Run # 16          Current Time = 02:12:47
# Run # 16          No errors in IIE
# Run # 16 ---------End of IIE
# Run # 16          Time of IIE:  745.4735441207886 secs ( 12.424559068679809  mins)
# Run # 16          Current Time = 02:25:12
# Run # 16                Finished renaming files
# Run # 16                Finished copying files to outputdir
# Run # 17     Current Time =      02:25:17
# Run # 17
# Run # 17     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.308.bz2
# Epoch Start:  2018-11-03 21:00:00
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 17     IISSET Cleaned      tmp/.../cleaned_setup_2018308
# |  Run # 17     Density Model:      dtm87
# |  Run # 17     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 17     ARC run:            icesat2_2018308_54hr.dtm87
# |  Run # 17     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 17     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.308.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 17          Running IIS
# Run # 17          No errors in IIS
# Run # 17 ---------End of IIS
#
# Run # 17          Running IIE
# Run # 17          Current Time = 02:26:39
# Run # 17          No errors in IIE
# Run # 17 ---------End of IIE
# Run # 17          Time of IIE:  594.4275064468384 secs ( 9.907125107447307  mins)
# Run # 17          Current Time = 02:36:34
# Run # 17                Finished renaming files
# Run # 17                Finished copying files to outputdir
# Run # 18     Current Time =      02:36:38
# Run # 18
# Run # 18     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.309.bz2
# Epoch Start:  2018-11-04 21:00:00
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 18     IISSET Cleaned      tmp/.../cleaned_setup_2018309
# |  Run # 18     Density Model:      dtm87
# |  Run # 18     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 18     ARC run:            icesat2_2018309_54hr.dtm87
# |  Run # 18     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 18     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.309.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 18          Running IIS
# Run # 18          No errors in IIS
# Run # 18 ---------End of IIS
#
# Run # 18          Running IIE
# Run # 18          Current Time = 02:38:00
# Run # 18          No errors in IIE
# Run # 18 ---------End of IIE
# Run # 18          Time of IIE:  528.5917737483978 secs ( 8.80986289580663  mins)
# Run # 18          Current Time = 02:46:49
# Run # 18                Finished renaming files
# Run # 18                Finished copying files to outputdir
# Run # 19     Current Time =      02:46:54
# Run # 19
# Run # 19     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.312.bz2
# Epoch Start:  2018-11-07 21:00:00
# 2018-11-07 21:00:00 not found in file.  Leaving ELEMS as is.
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 19     IISSET Cleaned      tmp/.../cleaned_setup_2018312
# |  Run # 19     Density Model:      dtm87
# |  Run # 19     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 19     ARC run:            icesat2_2018312_54hr.dtm87
# |  Run # 19     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 19     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.312.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 19          Running IIS
# Run # 19          No errors in IIS
# Run # 19 ---------End of IIS
#
# Run # 19          Running IIE
# Run # 19          Current Time = 02:48:26
# Run # 19          No errors in IIE
# Run # 19 ---------End of IIE
# Run # 19          Time of IIE:  593.1954951286316 secs ( 9.886591585477193  mins)
# Run # 19          Current Time = 02:58:19
# Run # 19                Finished renaming files
# Run # 19                Finished copying files to outputdir
# Run # 20     Current Time =      02:58:24
# Run # 20
# Run # 20     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.313.bz2
# Epoch Start:  2018-11-08 21:00:00
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 20     IISSET Cleaned      tmp/.../cleaned_setup_2018313
# |  Run # 20     Density Model:      dtm87
# |  Run # 20     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 20     ARC run:            icesat2_2018313_54hr.dtm87
# |  Run # 20     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 20     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.313.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 20          Running IIS
# Run # 20          No errors in IIS
# Run # 20 ---------End of IIS
#
# Run # 20          Running IIE
# Run # 20          Current Time = 02:59:46
# Run # 20          No errors in IIE
# Run # 20 ---------End of IIE
# Run # 20          Time of IIE:  504.9148051738739 secs ( 8.415246752897898  mins)
# Run # 20          Current Time = 03:08:11
# Run # 20                Finished renaming files
# Run # 20                Finished copying files to outputdir
# Run # 21     Current Time =      03:08:16
# Run # 21
# Run # 21     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.314.bz2
# Epoch Start:  2018-11-09 21:00:00
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 21     IISSET Cleaned      tmp/.../cleaned_setup_2018314
# |  Run # 21     Density Model:      dtm87
# |  Run # 21     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 21     ARC run:            icesat2_2018314_54hr.dtm87
# |  Run # 21     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 21     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.314.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 21          Running IIS
# Run # 21          No errors in IIS
# Run # 21 ---------End of IIS
#
# Run # 21          Running IIE
# Run # 21          Current Time = 03:09:39
# Run # 21          No errors in IIE
# Run # 21 ---------End of IIE
# Run # 21          Time of IIE:  429.6708607673645 secs ( 7.161181012789409  mins)
# Run # 21          Current Time = 03:16:49
# Run # 21                Finished renaming files
# Run # 21                Finished copying files to outputdir
# Run # 22     Current Time =      03:16:54
# Run # 22
# Run # 22     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.315.bz2
# Epoch Start:  2018-11-10 21:00:00
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 22     IISSET Cleaned      tmp/.../cleaned_setup_2018315
# |  Run # 22     Density Model:      dtm87
# |  Run # 22     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 22     ARC run:            icesat2_2018315_54hr.dtm87
# |  Run # 22     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 22     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.315.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 22          Running IIS
# Run # 22          No errors in IIS
# Run # 22 ---------End of IIS
#
# Run # 22          Running IIE
# Run # 22          Current Time = 03:18:17
# Run # 22          No errors in IIE
# Run # 22 ---------End of IIE
# Run # 22          Time of IIE:  431.01773142814636 secs ( 7.183628857135773  mins)
# Run # 22          Current Time = 03:25:29
# Run # 22                Finished renaming files
# Run # 22                Finished copying files to outputdir
# Run # 23     Current Time =      03:25:33
# Run # 23
# Run # 23     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.316.bz2
# Epoch Start:  2018-11-11 21:00:00
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 23     IISSET Cleaned      tmp/.../cleaned_setup_2018316
# |  Run # 23     Density Model:      dtm87
# |  Run # 23     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 23     ARC run:            icesat2_2018316_54hr.dtm87
# |  Run # 23     Output directory:   /data/data_geodyn/results/icesat2/dtm87/dtm87_acceloff_TrajAnalysis
# |  Run # 23     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.316.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 23          Running IIS
# Run # 23          No errors in IIS
# Run # 23 ---------End of IIS
#
# Run # 23          Running IIE
# Run # 23          Current Time = 03:26:58

# %%
# %load_ext autoreload
# %autoreload 2

from PYGEODYN import Pygeodyn


#### ----------------------------------------------
####
#### ----------------- RUN JAACHIA ----------------- 
####
#### ----------------------------------------------

##### Use copy.deepcopy to copy all levels of dictionary and 
###       allow modification of new variable
run_params3 = copy.deepcopy(run_params)
run_params3['den_model']         =  'jaachia71'  


#### Run pyeodyn for the arcs in the above set.
Obj_Geodyn = Pygeodyn(run_params3)
Obj_Geodyn.RUN_GEODYN()
