# %%
import copy
import sys
import os.path
import numpy as np

# %%
path_to_binaryrvg   = '/data/data_geodyn/inputs/icesat2/pre_processing/traj_files_rvg'
years = [2018]     #,2019]
days = np.arange(0, 367)

files_list = []
count_noletter = 0
countA = 0
countB = 0

for iyear,year in enumerate(years):
    for iday,day in enumerate(days):
        filename = 'orbit.1807001.%d.%03d' % (year, day)
#         filename = '%d.%03d' % (year, day)
        __filename = path_to_binaryrvg+ '/'+filename
        arc = '%d.%03d' % (year, day)
        if os.path.exists(__filename):
            count_noletter+=1
            files_list.append(arc)
        if os.path.exists(__filename + 'A'):
            countA += 1
            pass
        if os.path.exists(__filename + 'B'):
            countB += 1
            pass
        if os.path.exists(__filename + '.gz'):
            count_noletter+=1
            files_list.append(arc + '')
        if os.path.exists(__filename + 'A.gz'):
            countA += 1
            pass
        if os.path.exists(__filename + 'B.gz'):
            countB += 1
            pass
        if os.path.exists(__filename + '.bz2'):
            count_noletter+=1
            files_list.append(arc + '')
        if os.path.exists(__filename + 'A.bz2'):
            countA += 1
            pass
        if os.path.exists(__filename + 'B.bz2'):
            countB += 1
            pass

# %%
# files_list #[48:]

# %%
# %load_ext autoreload
# %autoreload 2

# import sys
# sys.path.insert(0,'/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/util_preprocessing/')
# from PYGEODYN_Preprocess import PygeodynPreprocessing

# path_to_prep_directory = '/data/data_geodyn/inputs/icesat2/pre_processing'
# path_to_binaryrvg     = '/data/data_geodyn/inputs/icesat2/pre_processing/traj_files_rvg'

# # ##### Uncomment the below call to overwrite the G2B data by re-running the pre-processing code
# Obj = PygeodynPreprocessing(path_to_binaryrvg, path_to_prep_directory,  files_list)
# Obj.run_preprocess_PCE()

# %% [markdown]
# ## Step 1: Run GEODYN using Pygeodyn with the ICESat2 configuration
#
# As a reminder, PYGEODYN is called with the `PYGEODYN` class, but modifications to the ICESAT2 configuration are largely controlled through the `Satellite_ICESat2` class in the `PYGEODYN_Satellites.py` file.   Please refer to this file first for file structure setups and modifications to the Pygeodyn structure.
#
# ### Step 1.1:  Run with MSIS2

# %%
arc_list = files_list[1:]
arc_list
# Out:
# ['2018.288',
#  '2018.291',
#  '2018.292',
#  '2018.293',
#  '2018.294',
#  '2018.295',
#  '2018.296',
#  '2018.297',
#  '2018.298',
#  '2018.299',
#  '2018.300',
#  '2018.303',
#  '2018.304',
#  '2018.305',
#  '2018.306',
#  '2018.307',
#  '2018.308',
#  '2018.309',
#  '2018.312',
#  '2018.313',
#  '2018.314',
#  '2018.315',
#  '2018.316',
#  '2018.317',
#  '2018.318',
#  '2018.319',
#  '2018.320',
#  '2018.321',
#  '2018.322',
#  '2018.323',
#  '2018.324',
#  '2018.325',
#  '2018.326',
#  '2018.327',
#  '2018.328',
#  '2018.330',
#  '2018.331',
#  '2018.334',
#  '2018.335',
#  '2018.336',
#  '2018.337',
#  '2018.338',
#  '2018.341',
#  '2018.345',
#  '2018.348',
#  '2018.349',
#  '2018.350',
#  '2018.351',
#  '2018.352',
#  '2018.353',
#  '2018.355',
#  '2018.356',
#  '2018.357',
#  '2018.358',
#  '2018.359',
#  '2018.364',
#  '2018.365']

# %%
### Identify which arcs you want to run:


sys.path.insert(0, '/data/geodyn_proj/pygeodyn/pygeodyn_develop/')

#------ A dictionary containing the run parameters ------  
run_params = {} 
run_params['arc']              =   arc_list
run_params['satellite']        =  'icesat2'  
run_params['SpecialRun_name']  =  '_TrajAnalysis'  
run_params['verbose']          =  False
run_params['action']           =  'run'

# %%
# %load_ext autoreload
# %autoreload 2

# sys.path.insert(0, '/data/geodyn_proj/pygeodyn/pygeodyn_develop/')
# from PYGEODYN import Pygeodyn


# #### ---------------------------------------------
# ####
# #### ----------------- RUN MSIS2.0 --------------- 
# ####
# #### ---------------------------------------------

# ##### Use copy.deepcopy to copy all levels of dictionary and 
# ###       allow modification of new variable
# run_params1 = copy.deepcopy(run_params)
# run_params1['den_model'] =  'msis2'  

# ### Run pyeodyn for the arcs in the above set.
# Obj_Geodyn = Pygeodyn(run_params1)
# Obj_Geodyn.RUN_GEODYN()

# %%
# %load_ext autoreload
# %autoreload 2

# from PYGEODYN import Pygeodyn


# #### ---------------------------------------------
# ####
# #### ----------------- RUN MSIS00 --------------- 
# ####
# #### ---------------------------------------------

# ##### Use copy.deepcopy to copy all levels of dictionary and 
# ###       allow modification of new variable
# run_params2 = copy.deepcopy(run_params)
# run_params2['den_model'] =  'msis00'  

# ### Run pyeodyn for the arcs in the above set.
# Obj_Geodyn = Pygeodyn(run_params2)
# Obj_Geodyn.RUN_GEODYN()

# %%
arc_msis86 = arc_list[18:]
arc_msis86
# Out:
# ['2018.312',
#  '2018.313',
#  '2018.314',
#  '2018.315',
#  '2018.316',
#  '2018.317',
#  '2018.318',
#  '2018.319',
#  '2018.320',
#  '2018.321',
#  '2018.322',
#  '2018.323',
#  '2018.324',
#  '2018.325',
#  '2018.326',
#  '2018.327',
#  '2018.328',
#  '2018.330',
#  '2018.331',
#  '2018.334',
#  '2018.335',
#  '2018.336',
#  '2018.337',
#  '2018.338',
#  '2018.341',
#  '2018.345',
#  '2018.348',
#  '2018.349',
#  '2018.350',
#  '2018.351',
#  '2018.352',
#  '2018.353',
#  '2018.355',
#  '2018.356',
#  '2018.357',
#  '2018.358',
#  '2018.359',
#  '2018.364',
#  '2018.365']

# %%
# %load_ext autoreload
# %autoreload 2

from PYGEODYN import Pygeodyn


#### ---------------------------------------------
####
#### ----------------- RUN MSIS86 --------------- 
####
#### ---------------------------------------------

##### Use copy.deepcopy to copy all levels of dictionary and 
###       allow modification of new variable
run_params3 = copy.deepcopy(run_params)
run_params3['den_model'] =  'msis86'  
run_params3['arc'] =  arc_msis86  

### Run pyeodyn for the arcs in the above set.
Obj_Geodyn = Pygeodyn(run_params3)
Obj_Geodyn.RUN_GEODYN()
# Out:
#                       ......... RUNNING GEODYN
# Run # 1     Current Time =      15:34:07
# Run # 1
# Run # 1     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.312.bz2
# 2018-11-07 21:00:00 not found in file.  Leaving ELEMS as is.
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 1     IISSET Cleaned      tmp/cleaned_setup_2018312
# |  Run # 1     Density Model:      msis86
# |  Run # 1     GEODYN Version:     pygeodyn_MODS
# |  Run # 1     ARC run:            icesat2_2018312_54hr.msis86
# |  Run # 1     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 1     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.312.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 1          Running IIS
# Run # 1          No errors in IIS
# Run # 1 ---------End of IIS
#
# Run # 1          Running IIE
# Run # 1          Current Time = 15:35:42
# Run # 1          No errors in IIE
# Run # 1 ---------End of IIE
# Run # 1          Time of IIE:  517.9562964439392 secs ( 8.63260494073232  mins)
# Run # 1          Current Time = 15:44:20
# Run # 1                Finished renaming files
# Run # 1                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 2     Current Time =      15:44:24
# Run # 2
# Run # 2     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.313.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 2     IISSET Cleaned      tmp/cleaned_setup_2018313
# |  Run # 2     Density Model:      msis86
# |  Run # 2     GEODYN Version:     pygeodyn_MODS
# |  Run # 2     ARC run:            icesat2_2018313_54hr.msis86
# |  Run # 2     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 2     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.313.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 2          Running IIS
# Run # 2          No errors in IIS
# Run # 2 ---------End of IIS
#
# Run # 2          Running IIE
# Run # 2          Current Time = 15:45:55
# Run # 2          No errors in IIE
# Run # 2 ---------End of IIE
# Run # 2          Time of IIE:  454.0002760887146 secs ( 7.566671268145243  mins)
# Run # 2          Current Time = 15:53:30
# Run # 2                Finished renaming files
# Run # 2                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 3     Current Time =      15:53:34
# Run # 3
# Run # 3     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.314.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 3     IISSET Cleaned      tmp/cleaned_setup_2018314
# |  Run # 3     Density Model:      msis86
# |  Run # 3     GEODYN Version:     pygeodyn_MODS
# |  Run # 3     ARC run:            icesat2_2018314_54hr.msis86
# |  Run # 3     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 3     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.314.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 3          Running IIS
# Run # 3          No errors in IIS
# Run # 3 ---------End of IIS
#
# Run # 3          Running IIE
# Run # 3          Current Time = 15:54:55
# Run # 3          No errors in IIE
# Run # 3 ---------End of IIE
# Run # 3          Time of IIE:  651.0605583190918 secs ( 10.851009305318197  mins)
# Run # 3          Current Time = 16:05:46
# Run # 3                Finished renaming files
# Run # 3                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 4     Current Time =      16:05:50
# Run # 4
# Run # 4     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.315.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 4     IISSET Cleaned      tmp/cleaned_setup_2018315
# |  Run # 4     Density Model:      msis86
# |  Run # 4     GEODYN Version:     pygeodyn_MODS
# |  Run # 4     ARC run:            icesat2_2018315_54hr.msis86
# |  Run # 4     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 4     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.315.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 4          Running IIS
# Run # 4          No errors in IIS
# Run # 4 ---------End of IIS
#
# Run # 4          Running IIE
# Run # 4          Current Time = 16:07:15
# Run # 4          No errors in IIE
# Run # 4 ---------End of IIE
# Run # 4          Time of IIE:  519.8891835212708 secs ( 8.664819725354512  mins)
# Run # 4          Current Time = 16:15:55
# Run # 4                Finished renaming files
# Run # 4                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 5     Current Time =      16:15:59
# Run # 5
# Run # 5     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.316.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 5     IISSET Cleaned      tmp/cleaned_setup_2018316
# |  Run # 5     Density Model:      msis86
# |  Run # 5     GEODYN Version:     pygeodyn_MODS
# |  Run # 5     ARC run:            icesat2_2018316_54hr.msis86
# |  Run # 5     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 5     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.316.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 5          Running IIS
# Run # 5          No errors in IIS
# Run # 5 ---------End of IIS
#
# Run # 5          Running IIE
# Run # 5          Current Time = 16:17:27
# Run # 5          No errors in IIE
# Run # 5 ---------End of IIE
# Run # 5          Time of IIE:  521.486480474472 secs ( 8.6914413412412  mins)
# Run # 5          Current Time = 16:26:09
# Run # 5                Finished renaming files
# Run # 5                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 6     Current Time =      16:26:13
# Run # 6
# Run # 6     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.317.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 6     IISSET Cleaned      tmp/cleaned_setup_2018317
# |  Run # 6     Density Model:      msis86
# |  Run # 6     GEODYN Version:     pygeodyn_MODS
# |  Run # 6     ARC run:            icesat2_2018317_54hr.msis86
# |  Run # 6     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 6     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.317.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 6          Running IIS
# Run # 6          No errors in IIS
# Run # 6 ---------End of IIS
#
# Run # 6          Running IIE
# Run # 6          Current Time = 16:27:44
# Run # 6          No errors in IIE
# Run # 6 ---------End of IIE
# Run # 6          Time of IIE:  590.0708050727844 secs ( 9.83451341787974  mins)
# Run # 6          Current Time = 16:37:35
# Run # 6                Finished renaming files
# Run # 6                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 7     Current Time =      16:37:39
# Run # 7
# Run # 7     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.318.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 7     IISSET Cleaned      tmp/cleaned_setup_2018318
# |  Run # 7     Density Model:      msis86
# |  Run # 7     GEODYN Version:     pygeodyn_MODS
# |  Run # 7     ARC run:            icesat2_2018318_54hr.msis86
# |  Run # 7     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 7     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.318.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 7          Running IIS
# Run # 7          No errors in IIS
# Run # 7 ---------End of IIS
#
# Run # 7          Running IIE
# Run # 7          Current Time = 16:39:07
# Run # 7          No errors in IIE
# Run # 7 ---------End of IIE
# Run # 7          Time of IIE:  519.4847774505615 secs ( 8.658079624176025  mins)
# Run # 7          Current Time = 16:47:47
# Run # 7                Finished renaming files
# Run # 7                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 8     Current Time =      16:47:51
# Run # 8
# Run # 8     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.319.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 8     IISSET Cleaned      tmp/cleaned_setup_2018319
# |  Run # 8     Density Model:      msis86
# |  Run # 8     GEODYN Version:     pygeodyn_MODS
# |  Run # 8     ARC run:            icesat2_2018319_54hr.msis86
# |  Run # 8     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 8     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.319.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 8          Running IIS
# Run # 8          No errors in IIS
# Run # 8 ---------End of IIS
#
# Run # 8          Running IIE
# Run # 8          Current Time = 16:49:22
# Run # 8          No errors in IIE
# Run # 8 ---------End of IIE
# Run # 8          Time of IIE:  586.2193875312805 secs ( 9.770323125521342  mins)
# Run # 8          Current Time = 16:59:09
# Run # 8                Finished renaming files
# Run # 8                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 9     Current Time =      16:59:13
# Run # 9
# Run # 9     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.320.bz2
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 9     IISSET Cleaned      tmp/cleaned_setup_2018320
# |  Run # 9     Density Model:      msis86
# |  Run # 9     GEODYN Version:     pygeodyn_MODS
# |  Run # 9     ARC run:            icesat2_2018320_54hr.msis86
# |  Run # 9     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 9     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.320.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 9          Running IIS
# Run # 9          No errors in IIS
# Run # 9 ---------End of IIS
#
# Run # 9          Running IIE
# Run # 9          Current Time = 17:00:43
# Run # 9          No errors in IIE
# Run # 9 ---------End of IIE
# Run # 9          Time of IIE:  387.93743443489075 secs ( 6.465623907248179  mins)
# Run # 9          Current Time = 17:07:11
# Run # 9                Finished renaming files
# Run # 9                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 10     Current Time =      17:07:15
# Run # 10
# Run # 10     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.321.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 10     IISSET Cleaned      tmp/cleaned_setup_2018321
# |  Run # 10     Density Model:      msis86
# |  Run # 10     GEODYN Version:     pygeodyn_MODS
# |  Run # 10     ARC run:            icesat2_2018321_54hr.msis86
# |  Run # 10     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 10     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.321.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 10          Running IIS
# Run # 10          No errors in IIS
# Run # 10 ---------End of IIS
#
# Run # 10          Running IIE
# Run # 10          Current Time = 17:08:47
# Run # 10          No errors in IIE
# Run # 10 ---------End of IIE
# Run # 10          Time of IIE:  386.700736284256 secs ( 6.445012271404266  mins)
# Run # 10          Current Time = 17:15:14
# Run # 10                Finished renaming files
# Run # 10                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 11     Current Time =      17:15:18
# Run # 11
# Run # 11     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.322.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 11     IISSET Cleaned      tmp/cleaned_setup_2018322
# |  Run # 11     Density Model:      msis86
# |  Run # 11     GEODYN Version:     pygeodyn_MODS
# |  Run # 11     ARC run:            icesat2_2018322_54hr.msis86
# |  Run # 11     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 11     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.322.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 11          Running IIS
# Run # 11          No errors in IIS
# Run # 11 ---------End of IIS
#
# Run # 11          Running IIE
# Run # 11          Current Time = 17:16:52
# Run # 11          No errors in IIE
# Run # 11 ---------End of IIE
# Run # 11          Time of IIE:  450.8364374637604 secs ( 7.513940624396006  mins)
# Run # 11          Current Time = 17:24:23
# Run # 11                Finished renaming files
# Run # 11                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 12     Current Time =      17:24:27
# Run # 12
# Run # 12     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.323.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 12     IISSET Cleaned      tmp/cleaned_setup_2018323
# |  Run # 12     Density Model:      msis86
# |  Run # 12     GEODYN Version:     pygeodyn_MODS
# |  Run # 12     ARC run:            icesat2_2018323_54hr.msis86
# |  Run # 12     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 12     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.323.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 12          Running IIS
# Run # 12          No errors in IIS
# Run # 12 ---------End of IIS
#
# Run # 12          Running IIE
# Run # 12          Current Time = 17:25:59
# Run # 12          No errors in IIE
# Run # 12 ---------End of IIE
# Run # 12          Time of IIE:  907.0644562244415 secs ( 15.117740937074025  mins)
# Run # 12          Current Time = 17:41:06
# Run # 12                Finished renaming files
# Run # 12                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 13     Current Time =      17:41:11
# Run # 13
# Run # 13     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.324.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 13     IISSET Cleaned      tmp/cleaned_setup_2018324
# |  Run # 13     Density Model:      msis86
# |  Run # 13     GEODYN Version:     pygeodyn_MODS
# |  Run # 13     ARC run:            icesat2_2018324_54hr.msis86
# |  Run # 13     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 13     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.324.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 13          Running IIS
# Run # 13          No errors in IIS
# Run # 13 ---------End of IIS
#
# Run # 13          Running IIE
# Run # 13          Current Time = 17:42:45
# Run # 13          No errors in IIE
# Run # 13 ---------End of IIE
# Run # 13          Time of IIE:  517.1252093315125 secs ( 8.618753488858541  mins)
# Run # 13          Current Time = 17:51:22
# Run # 13                Finished renaming files
# Run # 13                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 14     Current Time =      17:51:26
# Run # 14
# Run # 14     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.325.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 14     IISSET Cleaned      tmp/cleaned_setup_2018325
# |  Run # 14     Density Model:      msis86
# |  Run # 14     GEODYN Version:     pygeodyn_MODS
# |  Run # 14     ARC run:            icesat2_2018325_54hr.msis86
# |  Run # 14     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 14     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.325.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 14          Running IIS
# Run # 14          No errors in IIS
# Run # 14 ---------End of IIS
#
# Run # 14          Running IIE
# Run # 14          Current Time = 17:53:02
# Run # 14          No errors in IIE
# Run # 14 ---------End of IIE
# Run # 14          Time of IIE:  907.6290471553802 secs ( 15.127150785923003  mins)
# Run # 14          Current Time = 18:08:09
# Run # 14                Finished renaming files
# Run # 14                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 15     Current Time =      18:08:14
# Run # 15
# Run # 15     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.326.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 15     IISSET Cleaned      tmp/cleaned_setup_2018326
# |  Run # 15     Density Model:      msis86
# |  Run # 15     GEODYN Version:     pygeodyn_MODS
# |  Run # 15     ARC run:            icesat2_2018326_54hr.msis86
# |  Run # 15     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 15     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.326.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 15          Running IIS
# Run # 15          No errors in IIS
# Run # 15 ---------End of IIS
#
# Run # 15          Running IIE
# Run # 15          Current Time = 18:09:50
# Run # 15          No errors in IIE
# Run # 15 ---------End of IIE
# Run # 15          Time of IIE:  450.19981622695923 secs ( 7.503330270449321  mins)
# Run # 15          Current Time = 18:17:20
# Run # 15                Finished renaming files
# Run # 15                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 16     Current Time =      18:17:25
# Run # 16
# Run # 16     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.327.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 16     IISSET Cleaned      tmp/cleaned_setup_2018327
# |  Run # 16     Density Model:      msis86
# |  Run # 16     GEODYN Version:     pygeodyn_MODS
# |  Run # 16     ARC run:            icesat2_2018327_54hr.msis86
# |  Run # 16     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 16     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.327.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 16          Running IIS
# Run # 16          No errors in IIS
# Run # 16 ---------End of IIS
#
# Run # 16          Running IIE
# Run # 16          Current Time = 18:19:01
# Run # 16          No errors in IIE
# Run # 16 ---------End of IIE
# Run # 16          Time of IIE:  385.7281663417816 secs ( 6.428802772363027  mins)
# Run # 16          Current Time = 18:25:27
# Run # 16                Finished renaming files
# Run # 16                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 17     Current Time =      18:25:31
# Run # 17
# Run # 17     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.328.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 17     IISSET Cleaned      tmp/cleaned_setup_2018328
# |  Run # 17     Density Model:      msis86
# |  Run # 17     GEODYN Version:     pygeodyn_MODS
# |  Run # 17     ARC run:            icesat2_2018328_54hr.msis86
# |  Run # 17     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 17     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.328.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 17          Running IIS
# Run # 17          No errors in IIS
# Run # 17 ---------End of IIS
#
# Run # 17          Running IIE
# Run # 17          Current Time = 18:27:10
# Run # 17          No errors in IIE
# Run # 17 ---------End of IIE
# Run # 17          Time of IIE:  366.3990042209625 secs ( 6.106650070349375  mins)
# Run # 17          Current Time = 18:33:17
# Run # 17                Finished renaming files
# Run # 17                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 18     Current Time =      18:33:21
# Run # 18
# Run # 18     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.330.bz2
# 2018-11-25 21:00:00 not found in file.  Leaving ELEMS as is.
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 18     IISSET Cleaned      tmp/cleaned_setup_2018330
# |  Run # 18     Density Model:      msis86
# |  Run # 18     GEODYN Version:     pygeodyn_MODS
# |  Run # 18     ARC run:            icesat2_2018330_54hr.msis86
# |  Run # 18     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 18     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.330.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 18          Running IIS
# Run # 18          No errors in IIS
# Run # 18 ---------End of IIS
#
# Run # 18          Running IIE
# Run # 18          Current Time = 18:35:02
# Run # 18          No errors in IIE
# Run # 18 ---------End of IIE
# Run # 18          Time of IIE:  711.1789495944977 secs ( 11.852982493241628  mins)
# Run # 18          Current Time = 18:46:53
# Run # 18                Finished renaming files
# Run # 18                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 19     Current Time =      18:46:58
# Run # 19
# Run # 19     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.331.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 19     IISSET Cleaned      tmp/cleaned_setup_2018331
# |  Run # 19     Density Model:      msis86
# |  Run # 19     GEODYN Version:     pygeodyn_MODS
# |  Run # 19     ARC run:            icesat2_2018331_54hr.msis86
# |  Run # 19     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 19     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.331.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 19          Running IIS
# Run # 19          No errors in IIS
# Run # 19 ---------End of IIS
#
# Run # 19          Running IIE
# Run # 19          Current Time = 18:48:40
# Run # 19          No errors in IIE
# Run # 19 ---------End of IIE
# Run # 19          Time of IIE:  366.49933767318726 secs ( 6.108322294553121  mins)
# Run # 19          Current Time = 18:54:46
# Run # 19                Finished renaming files
# Run # 19                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 20     Current Time =      18:54:51
# Run # 20
# Run # 20     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.334.bz2
# 2018-11-29 21:00:00 not found in file.  Leaving ELEMS as is.
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 20     IISSET Cleaned      tmp/cleaned_setup_2018334
# |  Run # 20     Density Model:      msis86
# |  Run # 20     GEODYN Version:     pygeodyn_MODS
# |  Run # 20     ARC run:            icesat2_2018334_54hr.msis86
# |  Run # 20     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 20     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.334.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 20          Running IIS
# Run # 20          No errors in IIS
# Run # 20 ---------End of IIS
#
# Run # 20          Running IIE
# Run # 20          Current Time = 18:56:32
# Run # 20          No errors in IIE
# Run # 20 ---------End of IIE
# Run # 20          Time of IIE:  516.9318103790283 secs ( 8.615530172983805  mins)
# Run # 20          Current Time = 19:05:09
# Run # 20                Finished renaming files
# Run # 20                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 21     Current Time =      19:05:14
# Run # 21
# Run # 21     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.335.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 21     IISSET Cleaned      tmp/cleaned_setup_2018335
# |  Run # 21     Density Model:      msis86
# |  Run # 21     GEODYN Version:     pygeodyn_MODS
# |  Run # 21     ARC run:            icesat2_2018335_54hr.msis86
# |  Run # 21     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 21     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.335.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 21          Running IIS
# Run # 21          No errors in IIS
# Run # 21 ---------End of IIS
#
# Run # 21          Running IIE
# Run # 21          Current Time = 19:06:55
# Run # 21          No errors in IIE
# Run # 21 ---------End of IIE
# Run # 21          Time of IIE:  389.2985270023346 secs ( 6.4883087833722435  mins)
# Run # 21          Current Time = 19:13:24
# Run # 21                Finished renaming files
# Run # 21                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 22     Current Time =      19:13:28
# Run # 22
# Run # 22     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.336.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 22     IISSET Cleaned      tmp/cleaned_setup_2018336
# |  Run # 22     Density Model:      msis86
# |  Run # 22     GEODYN Version:     pygeodyn_MODS
# |  Run # 22     ARC run:            icesat2_2018336_54hr.msis86
# |  Run # 22     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 22     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.336.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 22          Running IIS
# Run # 22          No errors in IIS
# Run # 22 ---------End of IIS
#
# Run # 22          Running IIE
# Run # 22          Current Time = 19:15:09
# Run # 22          No errors in IIE
# Run # 22 ---------End of IIE
# Run # 22          Time of IIE:  387.75123405456543 secs ( 6.462520567576091  mins)
# Run # 22          Current Time = 19:21:37
# Run # 22                Finished renaming files
# Run # 22                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 23     Current Time =      19:21:41
# Run # 23
# Run # 23     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.337.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 23     IISSET Cleaned      tmp/cleaned_setup_2018337
# |  Run # 23     Density Model:      msis86
# |  Run # 23     GEODYN Version:     pygeodyn_MODS
# |  Run # 23     ARC run:            icesat2_2018337_54hr.msis86
# |  Run # 23     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 23     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.337.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 23          Running IIS
# Run # 23          No errors in IIS
# Run # 23 ---------End of IIS
#
# Run # 23          Running IIE
# Run # 23          Current Time = 19:23:23
# Run # 23          No errors in IIE
# Run # 23 ---------End of IIE
# Run # 23          Time of IIE:  386.2141375541687 secs ( 6.436902292569479  mins)
# Run # 23          Current Time = 19:29:49
# Run # 23                Finished renaming files
# Run # 23                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 24     Current Time =      19:29:54
# Run # 24
# Run # 24     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.338.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 24     IISSET Cleaned      tmp/cleaned_setup_2018338
# |  Run # 24     Density Model:      msis86
# |  Run # 24     GEODYN Version:     pygeodyn_MODS
# |  Run # 24     ARC run:            icesat2_2018338_54hr.msis86
# |  Run # 24     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 24     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.338.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 24          Running IIS
# Run # 24          No errors in IIS
# Run # 24 ---------End of IIS
#
# Run # 24          Running IIE
# Run # 24          Current Time = 19:31:36
# Run # 24          No errors in IIE
# Run # 24 ---------End of IIE
# Run # 24          Time of IIE:  421.5394139289856 secs ( 7.025656898816426  mins)
# Run # 24          Current Time = 19:38:37
# Run # 24                Finished renaming files
# Run # 24                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 25     Current Time =      19:38:42
# Run # 25
# Run # 25     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.341.bz2
# 2018-12-06 21:00:00 not found in file.  Leaving ELEMS as is.
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 25     IISSET Cleaned      tmp/cleaned_setup_2018341
# |  Run # 25     Density Model:      msis86
# |  Run # 25     GEODYN Version:     pygeodyn_MODS
# |  Run # 25     ARC run:            icesat2_2018341_54hr.msis86
# |  Run # 25     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 25     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.341.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 25          Running IIS
# Run # 25          No errors in IIS
# Run # 25 ---------End of IIS
#
# Run # 25          Running IIE
# Run # 25          Current Time = 19:40:21
# Run # 25          No errors in IIE
# Run # 25 ---------End of IIE
# Run # 25          Time of IIE:  480.28650093078613 secs ( 8.004775015513102  mins)
# Run # 25          Current Time = 19:48:22
# Run # 25                Finished renaming files
# Run # 25                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 26     Current Time =      19:48:26
# Run # 26
# Run # 26     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.345.bz2
# 2018-12-10 21:00:00 not found in file.  Leaving ELEMS as is.
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 26     IISSET Cleaned      tmp/cleaned_setup_2018345
# |  Run # 26     Density Model:      msis86
# |  Run # 26     GEODYN Version:     pygeodyn_MODS
# |  Run # 26     ARC run:            icesat2_2018345_54hr.msis86
# |  Run # 26     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 26     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.345.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 26          Running IIS
# Run # 26          No errors in IIS
# Run # 26 ---------End of IIS
#
# Run # 26          Running IIE
# Run # 26          Current Time = 19:50:11
# Run # 26          No errors in IIE
# Run # 26 ---------End of IIE
# Run # 26          Time of IIE:  481.42589497566223 secs ( 8.023764916261037  mins)
# Run # 26          Current Time = 19:58:12
# Run # 26                Finished renaming files
# Run # 26                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 27     Current Time =      19:58:17
# Run # 27
# Run # 27     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.348.bz2
# 2018-12-13 21:00:00 not found in file.  Leaving ELEMS as is.
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 27     IISSET Cleaned      tmp/cleaned_setup_2018348
# |  Run # 27     Density Model:      msis86
# |  Run # 27     GEODYN Version:     pygeodyn_MODS
# |  Run # 27     ARC run:            icesat2_2018348_54hr.msis86
# |  Run # 27     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 27     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.348.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 27          Running IIS
# Run # 27          No errors in IIS
# Run # 27 ---------End of IIS
#
# Run # 27          Running IIE
# Run # 27          Current Time = 20:00:02
# Run # 27          No errors in IIE
# Run # 27 ---------End of IIE
# Run # 27          Time of IIE:  585.1833961009979 secs ( 9.7530566016833  mins)
# Run # 27          Current Time = 20:09:47
# Run # 27                Finished renaming files
# Run # 27                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 28     Current Time =      20:09:52
# Run # 28
# Run # 28     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.349.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 28     IISSET Cleaned      tmp/cleaned_setup_2018349
# |  Run # 28     Density Model:      msis86
# |  Run # 28     GEODYN Version:     pygeodyn_MODS
# |  Run # 28     ARC run:            icesat2_2018349_54hr.msis86
# |  Run # 28     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 28     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.349.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 28          Running IIS
# Run # 28          No errors in IIS
# Run # 28 ---------End of IIS
#
# Run # 28          Running IIE
# Run # 28          Current Time = 20:11:40
# Run # 28          No errors in IIE
# Run # 28 ---------End of IIE
# Run # 28          Time of IIE:  388.89141964912415 secs ( 6.481523660818736  mins)
# Run # 28          Current Time = 20:18:09
# Run # 28                Finished renaming files
# Run # 28                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 29     Current Time =      20:18:14
# Run # 29
# Run # 29     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.350.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 29     IISSET Cleaned      tmp/cleaned_setup_2018350
# |  Run # 29     Density Model:      msis86
# |  Run # 29     GEODYN Version:     pygeodyn_MODS
# |  Run # 29     ARC run:            icesat2_2018350_54hr.msis86
# |  Run # 29     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 29     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.350.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 29          Running IIS
# Run # 29          No errors in IIS
# Run # 29 ---------End of IIS
#
# Run # 29          Running IIE
# Run # 29          Current Time = 20:19:57
# Run # 29          No errors in IIE
# Run # 29 ---------End of IIE
# Run # 29          Time of IIE:  388.27656745910645 secs ( 6.4712761243184405  mins)
# Run # 29          Current Time = 20:26:25
# Run # 29                Finished renaming files
# Run # 29                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 30     Current Time =      20:26:30
# Run # 30
# Run # 30     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.351.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 30     IISSET Cleaned      tmp/cleaned_setup_2018351
# |  Run # 30     Density Model:      msis86
# |  Run # 30     GEODYN Version:     pygeodyn_MODS
# |  Run # 30     ARC run:            icesat2_2018351_54hr.msis86
# |  Run # 30     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 30     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.351.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# Run # 30          Running IIS
# Run # 30          No errors in IIS
# Run # 30 ---------End of IIS
#
# Run # 30          Running IIE
# Run # 30          Current Time = 20:28:13
# Run # 30          No errors in IIE
# Run # 30 ---------End of IIE
# Run # 30          Time of IIE:  387.3410234451294 secs ( 6.45568372408549  mins)
# Run # 30          Current Time = 20:34:41
# Run # 30                Finished renaming files
# Run # 30                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 31     Current Time =      20:34:46
# Run # 31
# Run # 31     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.352.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 31     IISSET Cleaned      tmp/cleaned_setup_2018352
# |  Run # 31     Density Model:      msis86
# |  Run # 31     GEODYN Version:     pygeodyn_MODS
# |  Run # 31     ARC run:            icesat2_2018352_54hr.msis86
# |  Run # 31     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 31     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.352.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 31          Running IIS
# Run # 31          No errors in IIS
# Run # 31 ---------End of IIS
#
# Run # 31          Running IIE
# Run # 31          Current Time = 20:36:30
# Run # 31          No errors in IIE
# Run # 31 ---------End of IIE
# Run # 31          Time of IIE:  926.590211391449 secs ( 15.443170189857483  mins)
# Run # 31          Current Time = 20:51:57
# Run # 31                Finished renaming files
# Run # 31                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 32     Current Time =      20:52:10
# Run # 32
# Run # 32     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.353.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 32     IISSET Cleaned      tmp/cleaned_setup_2018353
# |  Run # 32     Density Model:      msis86
# |  Run # 32     GEODYN Version:     pygeodyn_MODS
# |  Run # 32     ARC run:            icesat2_2018353_54hr.msis86
# |  Run # 32     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 32     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.353.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 32          Running IIS
# Run # 32          No errors in IIS
# Run # 32 ---------End of IIS
#
# Run # 32          Running IIE
# Run # 32          Current Time = 20:55:07
# Run # 32          No errors in IIE
# Run # 32 ---------End of IIE
# Run # 32          Time of IIE:  658.2777044773102 secs ( 10.971295074621837  mins)
# Run # 32          Current Time = 21:06:05
# Run # 32                Finished renaming files
# Run # 32                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 33     Current Time =      21:06:10
# Run # 33
# Run # 33     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.355.bz2
# 2018-12-20 21:00:00 not found in file.  Leaving ELEMS as is.
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 33     IISSET Cleaned      tmp/cleaned_setup_2018355
# |  Run # 33     Density Model:      msis86
# |  Run # 33     GEODYN Version:     pygeodyn_MODS
# |  Run # 33     ARC run:            icesat2_2018355_54hr.msis86
# |  Run # 33     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 33     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.355.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 33          Running IIS
# Run # 33          No errors in IIS
# Run # 33 ---------End of IIS
#
# Run # 33          Running IIE
# Run # 33          Current Time = 21:08:53
# Run # 33          No errors in IIE
# Run # 33 ---------End of IIE
# Run # 33          Time of IIE:  1009.7888507843018 secs ( 16.829814179738364  mins)
# Run # 33          Current Time = 21:25:43
# Run # 33                Finished renaming files
# Run # 33                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 34     Current Time =      21:25:48
# Run # 34
# Run # 34     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.356.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 34     IISSET Cleaned      tmp/cleaned_setup_2018356
# |  Run # 34     Density Model:      msis86
# |  Run # 34     GEODYN Version:     pygeodyn_MODS
# |  Run # 34     ARC run:            icesat2_2018356_54hr.msis86
# |  Run # 34     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 34     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.356.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 34          Running IIS
# Run # 34          No errors in IIS
# Run # 34 ---------End of IIS
#
# Run # 34          Running IIE
# Run # 34          Current Time = 21:28:16
# Run # 34          No errors in IIE
# Run # 34 ---------End of IIE
# Run # 34          Time of IIE:  1030.167356967926 secs ( 17.169455949465434  mins)
# Run # 34          Current Time = 21:45:27
# Run # 34                Finished renaming files
# Run # 34                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 35     Current Time =      21:45:32
# Run # 35
# Run # 35     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.357.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 35     IISSET Cleaned      tmp/cleaned_setup_2018357
# |  Run # 35     Density Model:      msis86
# |  Run # 35     GEODYN Version:     pygeodyn_MODS
# |  Run # 35     ARC run:            icesat2_2018357_54hr.msis86
# |  Run # 35     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 35     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.357.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 35          Running IIS
# Run # 35          No errors in IIS
# Run # 35 ---------End of IIS
#
# Run # 35          Running IIE
# Run # 35          Current Time = 21:47:38
# Run # 35          No errors in IIE
# Run # 35 ---------End of IIE
# Run # 35          Time of IIE:  779.8531856536865 secs ( 12.997553094228108  mins)
# Run # 35          Current Time = 22:00:38
# Run # 35                Finished renaming files
# Run # 35                Finished copying files to outputdir
#         Deleting:  msis86_acceloff_TrajAnalysis
# Run # 36     Current Time =      22:00:43
# Run # 36
# Run # 36     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.358.bz2
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 36     IISSET Cleaned      tmp/cleaned_setup_2018358
# |  Run # 36     Density Model:      msis86
# |  Run # 36     GEODYN Version:     pygeodyn_MODS
# |  Run # 36     ARC run:            icesat2_2018358_54hr.msis86
# |  Run # 36     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloff_TrajAnalysis
# |  Run # 36     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.358.gz
# |
# + ———————————————————————————————————————————————————————————————————————————————————————————————————————————
# Run # 36          Running IIS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f9420e3bffa4> in <module>
#      19 ### Run pyeodyn for the arcs in the above set.
#      20 Obj_Geodyn = Pygeodyn(run_params3)
# ---> 21 Obj_Geodyn.RUN_GEODYN()
#
# /data/geodyn_proj/pygeodyn/pygeodyn_develop/PYGEODYN_Control.py in RUN_GEODYN(self)
#     663             self.print_runparameters_to_notebook()
#     664             self.prepare_tmpdir_for_geodyn_run()
# --> 665             self.run_geodyn_in_tmpdir()
#     666             self.post_geodynrun_savefiles_and_cleanup()
#     667
#
# /data/geodyn_proj/pygeodyn/pygeodyn_develop/PYGEODYN_Control.py in run_geodyn_in_tmpdir(self)
#     409
#     410         command_IIS = self.G2SDIR+'/giis2002_gfortran > '+'iisout 2> '+'iiserr'
# --> 411         subprocess.run(command_IIS, shell = True)
#     412         time.sleep(1)
#     413
#
# /data/miniconda3/envs/pygeodyn/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493     with Popen(*popenargs, **kwargs) as process:
#     494         try:
# --> 495             stdout, stderr = process.communicate(input, timeout=timeout)
#     496         except TimeoutExpired as exc:
#     497             process.kill()
#
# /data/miniconda3/envs/pygeodyn/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1018                 stderr = self.stderr.read()
#    1019                 self.stderr.close()
# -> 1020             self.wait()
#    1021         else:
#    1022             if timeout is not None:
#
# /data/miniconda3/envs/pygeodyn/lib/python3.8/subprocess.py in wait(self, timeout)
#    1081             endtime = _time() + timeout
#    1082         try:
# -> 1083             return self._wait(timeout=timeout)
#    1084         except KeyboardInterrupt:
#    1085             # https://bugs.python.org/issue25942
#
# /data/miniconda3/envs/pygeodyn/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1806                         if self.returncode is not None:
#    1807                             break  # Another thread waited.
# -> 1808                         (pid, sts) = self._try_wait(0)
#    1809                         # Check the pid and loop as waitpid has been known to
#    1810                         # return 0 even without WNOHANG in odd situations.
#
# /data/miniconda3/envs/pygeodyn/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1764             """All callers to this function MUST hold self._waitpid_lock."""
#    1765             try:
# -> 1766                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1767             except ChildProcessError:
#    1768                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
# %load_ext autoreload
# %autoreload 2

from PYGEODYN import Pygeodyn

#### ---------------------------------------------
####
#### ------------------- RUN DTM ----------------- 
####
#### ---------------------------------------------


##### Use copy.deepcopy to copy all levels of dictionary and 
###       allow modification of new variable
run_params2 = copy.deepcopy(run_params)
run_params2['den_model']         =  'dtm87'  

### Run pyeodyn for the arcs in the above set.
Obj_Geodyn = Pygeodyn(run_params2)
Obj_Geodyn.RUN_GEODYN()

# %%
# %load_ext autoreload
# %autoreload 2

from PYGEODYN import Pygeodyn


#### ----------------------------------------------
####
#### ----------------- RUN JAACHIA ----------------- 
####
#### ----------------------------------------------

##### Use copy.deepcopy to copy all levels of dictionary and 
###       allow modification of new variable
run_params3 = copy.deepcopy(run_params)
run_params3['den_model']         =  'jaachia71'  


#### Run pyeodyn for the arcs in the above set.
Obj_Geodyn = Pygeodyn(run_params3)
Obj_Geodyn.RUN_GEODYN()
