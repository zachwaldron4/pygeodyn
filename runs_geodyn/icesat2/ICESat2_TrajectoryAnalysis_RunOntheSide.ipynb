# %%
import copy
import sys

# %%
# %load_ext autoreload
# %autoreload 2

# import sys
# sys.path.insert(0,'/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/util_preprocessing/')
# from PYGEODYN_Preprocess import PygeodynPreprocessing

# path_to_prep_directory = '/data/data_geodyn/inputs/icesat2/pre_processing'
# path_to_binaryrvg     = '/data/data_geodyn/inputs/icesat2/pre_processing/traj_files_rvg'

# arc1_files = [
#               'orbit.1807001.2018.312',
#               'orbit.1807001.2018.313',
#               'orbit.1807001.2018.314',
#               'orbit.1807001.2018.315',
#               'orbit.1807001.2018.316',
#               'orbit.1807001.2018.317',
#               'orbit.1807001.2018.318',
# #               'orbit.1807001.2018.319',
# #               'orbit.1807001.2018.320',
# #               'orbit.1807001.2018.321',
# #               'orbit.1807001.2018.322',
#              ]

# ##### Uncomment the below call to overwrite the G2B data by re-running the pre-processing code
# Obj = PygeodynPreprocessing(path_to_binaryrvg, path_to_prep_directory,  arc1_files)
# Obj.run_preprocess_PCE()

# %% [markdown]
# ## Step 1: Run GEODYN using Pygeodyn with the ICESat2 configuration
#
# As a reminder, PYGEODYN is called with the `PYGEODYN` class, but modifications to the ICESAT2 configuration are largely controlled through the `Satellite_ICESat2` class in the `PYGEODYN_Satellites.py` file.   Please refer to this file first for file structure setups and modifications to the Pygeodyn structure.
#
# ### Step 1.1:  Run with MSIS2

# %%
### Identify which arcs you want to run:
arcs_files = [ 
            '2018.313', # 1
            '2018.314', # 2
            '2018.315', # 3
            '2018.316', # 4
            '2018.317', # 5
#             '2018.318', # 6
#             '2018.319', # 7
#             '2018.320', # 8
#             '2018.321', # 9
#             '2018.322', # 10
             ]

#------ A dictionary containing the run parameters ------  
run_params = {} 
run_params['arc']              =   arcs_files
run_params['satellite']        =  'icesat2'  
# run_params['den_model']        =  '_TrajAnalysis_1'  
run_params['SpecialRun_name']  =  '_TrajAnalysis_1'  
run_params['verbose']          =  False
run_params['action']           =  'run'

# %%
# %load_ext autoreload
# %autoreload 2

# sys.path.insert(0, '/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/')
# from PYGEODYN import Pygeodyn


# #### ---------------------------------------------
# ####
# #### ----------------- RUN MSIS2.0 --------------- 
# ####
# #### ---------------------------------------------

# ##### Use copy.deepcopy to copy all levels of dictionary and 
# ###       allow modification of new variable
# run_params1 = copy.deepcopy(run_params)
# run_params1['den_model'] =  'msis2'  

# ### Run pyeodyn for the arcs in the above set.
# Obj_Geodyn = Pygeodyn(run_params1)
# Obj_Geodyn.RUN_GEODYN()

# %%
# %load_ext autoreload
# %autoreload 2

sys.path.insert(0, '/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/')
from PYGEODYN import Pygeodyn


#### ---------------------------------------------
####
#### ----------------- RUN MSIS00 --------------- 
####
#### ---------------------------------------------

##### Use copy.deepcopy to copy all levels of dictionary and 
###       allow modification of new variable
run_params2 = copy.deepcopy(run_params)
run_params2['den_model'] =  'msis00'  

### Run pyeodyn for the arcs in the above set.
Obj_Geodyn = Pygeodyn(run_params2)
Obj_Geodyn.RUN_GEODYN()
# Out:
# =================================================================
#    Initializing PYGEODYN to ...
#                             ... RUN GEODYN
# =================================================================
# Run # 1     Current Time =      15:39:21
# Run # 1
# Run # 1     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.313.bz2
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 1     IISSET Cleaned      tmp/cleaned_setup_2018313
# |  Run # 1     Density Model:      msis00
# |  Run # 1     GEODYN Version:     pygeodyn_MODS
# |  Run # 1     ARC run:            icesat2_2018313_54hr.msis00
# |  Run # 1     Output directory:   /data/data_geodyn/results/icesat2/msis00/msis00_acceloffdevelop_test
# |  Run # 1     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.313.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 1          Running IIS
# Run # 1          No errors in IIS
# Run # 1 ---------End of IIS
#
# Run # 1          Running IIE
# Run # 1          Current Time = 15:40:35
# Run # 1          No errors in IIE
# Run # 1 ---------End of IIE
# Run # 1          Time of IIE:  434.14172625541687 secs ( 7.235695437590281  mins)
# Run # 1          Current Time = 15:47:49
# Run # 1                Finished renaming files
# Run # 1                Finished copying files to outputdir
#         Deleting:  msis00_acceloffdevelop_test
# Run # 2     Current Time =      15:47:53
# Run # 2
# Run # 2     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.314.bz2
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 2     IISSET Cleaned      tmp/cleaned_setup_2018314
# |  Run # 2     Density Model:      msis00
# |  Run # 2     GEODYN Version:     pygeodyn_MODS
# |  Run # 2     ARC run:            icesat2_2018314_54hr.msis00
# |  Run # 2     Output directory:   /data/data_geodyn/results/icesat2/msis00/msis00_acceloffdevelop_test
# |  Run # 2     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.314.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 2          Running IIS
# Run # 2          No errors in IIS
# Run # 2 ---------End of IIS
#
# Run # 2          Running IIE
# Run # 2          Current Time = 15:49:09
# Run # 2          No errors in IIE
# Run # 2 ---------End of IIE
# Run # 2          Time of IIE:  948.0372426509857 secs ( 15.800620710849762  mins)
# Run # 2          Current Time = 16:04:57
# Run # 2                Finished renaming files
# Run # 2                Finished copying files to outputdir
#         Deleting:  msis00_acceloffdevelop_test
# Run # 3     Current Time =      16:05:01
# Run # 3
# Run # 3     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.315.bz2
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 3     IISSET Cleaned      tmp/cleaned_setup_2018315
# |  Run # 3     Density Model:      msis00
# |  Run # 3     GEODYN Version:     pygeodyn_MODS
# |  Run # 3     ARC run:            icesat2_2018315_54hr.msis00
# |  Run # 3     Output directory:   /data/data_geodyn/results/icesat2/msis00/msis00_acceloffdevelop_test
# |  Run # 3     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.315.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 3          Running IIS
# Run # 3          No errors in IIS
# Run # 3 ---------End of IIS
#
# Run # 3          Running IIE
# Run # 3          Current Time = 16:06:15
# Run # 3          No errors in IIE
# Run # 3 ---------End of IIE
# Run # 3          Time of IIE:  432.72362637519836 secs ( 7.212060439586639  mins)
# Run # 3          Current Time = 16:13:28
# Run # 3                Finished renaming files
# Run # 3                Finished copying files to outputdir
#         Deleting:  msis00_acceloffdevelop_test
# Run # 4     Current Time =      16:13:32
# Run # 4
# Run # 4     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.316.bz2
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 4     IISSET Cleaned      tmp/cleaned_setup_2018316
# |  Run # 4     Density Model:      msis00
# |  Run # 4     GEODYN Version:     pygeodyn_MODS
# |  Run # 4     ARC run:            icesat2_2018316_54hr.msis00
# |  Run # 4     Output directory:   /data/data_geodyn/results/icesat2/msis00/msis00_acceloffdevelop_test
# |  Run # 4     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.316.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 4          Running IIS
# Run # 4          No errors in IIS
# Run # 4 ---------End of IIS
#
# Run # 4          Running IIE
# Run # 4          Current Time = 16:14:46
# Run # 4          No errors in IIE
# Run # 4 ---------End of IIE
# Run # 4          Time of IIE:  507.3531074523926 secs ( 8.455885124206542  mins)
# Run # 4          Current Time = 16:23:13
# Run # 4                Finished renaming files
# Run # 4                Finished copying files to outputdir
#         Deleting:  msis00_acceloffdevelop_test
# Run # 5     Current Time =      16:23:17
# Run # 5
# Run # 5     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.317.bz2
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 5     IISSET Cleaned      tmp/cleaned_setup_2018317
# |  Run # 5     Density Model:      msis00
# |  Run # 5     GEODYN Version:     pygeodyn_MODS
# |  Run # 5     ARC run:            icesat2_2018317_54hr.msis00
# |  Run # 5     Output directory:   /data/data_geodyn/results/icesat2/msis00/msis00_acceloffdevelop_test
# |  Run # 5     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.317.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 5          Running IIS
# Run # 5          No errors in IIS
# Run # 5 ---------End of IIS
#
# Run # 5          Running IIE
# Run # 5          Current Time = 16:24:31
# Run # 5          No errors in IIE
# Run # 5 ---------End of IIE
# Run # 5          Time of IIE:  579.1312782764435 secs ( 9.652187971274058  mins)
# Run # 5          Current Time = 16:34:10
# Run # 5                Finished renaming files
# Run # 5                Finished copying files to outputdir
#         Deleting:  msis00_acceloffdevelop_test

# %%
# %load_ext autoreload
# %autoreload 2

sys.path.insert(0, '/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/')
from PYGEODYN import Pygeodyn


#### ---------------------------------------------
####
#### ----------------- RUN MSIS86 --------------- 
####
#### ---------------------------------------------

##### Use copy.deepcopy to copy all levels of dictionary and 
###       allow modification of new variable
run_params3 = copy.deepcopy(run_params)
run_params3['den_model'] =  'msis86'  

### Run pyeodyn for the arcs in the above set.
Obj_Geodyn = Pygeodyn(run_params3)
Obj_Geodyn.RUN_GEODYN()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# =================================================================
#    Initializing PYGEODYN to ...
#                             ... RUN GEODYN
# =================================================================
# Run # 1     Current Time =      16:34:14
# Run # 1
# Run # 1     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.313.bz2
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 1     IISSET Cleaned      tmp/cleaned_setup_2018313
# |  Run # 1     Density Model:      msis86
# |  Run # 1     GEODYN Version:     pygeodyn_MODS
# |  Run # 1     ARC run:            icesat2_2018313_54hr.msis86
# |  Run # 1     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloffdevelop_test
# |  Run # 1     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.313.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 1          Running IIS
# Run # 1          No errors in IIS
# Run # 1 ---------End of IIS
#
# Run # 1          Running IIE
# Run # 1          Current Time = 16:35:27
# Run # 1          No errors in IIE
# Run # 1 ---------End of IIE
# Run # 1          Time of IIE:  505.26706314086914 secs ( 8.421117719014486  mins)
# Run # 1          Current Time = 16:43:52
# Run # 1                Finished renaming files
# Run # 1                Finished copying files to outputdir
#         Deleting:  msis86_acceloffdevelop_test
# Run # 2     Current Time =      16:43:56
# Run # 2
# Run # 2     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.314.bz2
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 2     IISSET Cleaned      tmp/cleaned_setup_2018314
# |  Run # 2     Density Model:      msis86
# |  Run # 2     GEODYN Version:     pygeodyn_MODS
# |  Run # 2     ARC run:            icesat2_2018314_54hr.msis86
# |  Run # 2     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloffdevelop_test
# |  Run # 2     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.314.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 2          Running IIS
# Run # 2          No errors in IIS
# Run # 2 ---------End of IIS
#
# Run # 2          Running IIE
# Run # 2          Current Time = 16:45:09
# Run # 2          No errors in IIE
# Run # 2 ---------End of IIE
# Run # 2          Time of IIE:  724.8040881156921 secs ( 12.080068135261536  mins)
# Run # 2          Current Time = 16:57:14
# Run # 2                Finished renaming files
# Run # 2                Finished copying files to outputdir
#         Deleting:  msis86_acceloffdevelop_test
# Run # 3     Current Time =      16:57:18
# Run # 3
# Run # 3     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.315.bz2
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 3     IISSET Cleaned      tmp/cleaned_setup_2018315
# |  Run # 3     Density Model:      msis86
# |  Run # 3     GEODYN Version:     pygeodyn_MODS
# |  Run # 3     ARC run:            icesat2_2018315_54hr.msis86
# |  Run # 3     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloffdevelop_test
# |  Run # 3     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.315.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 3          Running IIS
# Run # 3          No errors in IIS
# Run # 3 ---------End of IIS
#
# Run # 3          Running IIE
# Run # 3          Current Time = 16:58:32
# Run # 3          No errors in IIE
# Run # 3 ---------End of IIE
# Run # 3          Time of IIE:  580.4671442508698 secs ( 9.674452404181162  mins)
# Run # 3          Current Time = 17:08:12
# Run # 3                Finished renaming files
# Run # 3                Finished copying files to outputdir
#         Deleting:  msis86_acceloffdevelop_test
# Run # 4     Current Time =      17:08:16
# Run # 4
# Run # 4     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.316.bz2
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 4     IISSET Cleaned      tmp/cleaned_setup_2018316
# |  Run # 4     Density Model:      msis86
# |  Run # 4     GEODYN Version:     pygeodyn_MODS
# |  Run # 4     ARC run:            icesat2_2018316_54hr.msis86
# |  Run # 4     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloffdevelop_test
# |  Run # 4     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.316.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 4          Running IIS
# Run # 4          No errors in IIS
# Run # 4 ---------End of IIS
#
# Run # 4          Running IIE
# Run # 4          Current Time = 17:09:34
# Run # 4          No errors in IIE
# Run # 4 ---------End of IIE
# Run # 4          Time of IIE:  580.2386112213135 secs ( 9.670643520355224  mins)
# Run # 4          Current Time = 17:19:14
# Run # 4                Finished renaming files
# Run # 4                Finished copying files to outputdir
#         Deleting:  msis86_acceloffdevelop_test
# Run # 5     Current Time =      17:19:18
# Run # 5
# Run # 5     Cleaning iisset... :    /data/data_geodyn/inputs/icesat2/setups/iisset.2018.317.bz2
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |  Run # 5     IISSET Cleaned      tmp/cleaned_setup_2018317
# |  Run # 5     Density Model:      msis86
# |  Run # 5     GEODYN Version:     pygeodyn_MODS
# |  Run # 5     ARC run:            icesat2_2018317_54hr.msis86
# |  Run # 5     Output directory:   /data/data_geodyn/results/icesat2/msis86/msis86_acceloffdevelop_test
# |  Run # 5     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.317.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 5          Running IIS
# Run # 5          No errors in IIS
# Run # 5 ---------End of IIS
#
# Run # 5          Running IIE
# Run # 5          Current Time = 17:21:15
# Run # 5          No errors in IIE
# Run # 5 ---------End of IIE
# Run # 5          Time of IIE:  695.050806760788 secs ( 11.5841801126798  mins)
# Run # 5          Current Time = 17:32:50
# Run # 5                Finished renaming files
# Run # 5                Finished copying files to outputdir
#         Deleting:  msis86_acceloffdevelop_test

# %% [markdown]
# ### Step  1.2: Run with DTM87 for comparison

# %%
# %load_ext autoreload
# %autoreload 2

# sys.path.insert(0, '/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/')
# from PYGEODYN import Pygeodyn

# #### ---------------------------------------------
# ####
# #### ------------------- RUN DTM ----------------- 
# ####
# #### ---------------------------------------------


# ##### Use copy.deepcopy to copy all levels of dictionary and 
# ###       allow modification of new variable
# run_params2 = copy.deepcopy(run_params)
# run_params2['den_model']         =  'dtm87'  

# ### Run pyeodyn for the arcs in the above set.
# Obj_Geodyn = Pygeodyn(run_params2)
# Obj_Geodyn.RUN_GEODYN()
# Out:
# [autoreload of PYGEODYN_Satellites failed: Traceback (most recent call last):
#   File "/data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 0
# ]
# [autoreload of PYGEODYN failed: Traceback (most recent call last):
#   File "/data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 0
# ]

# %% [markdown]
# ### Step  1.2: Run with Jaachia 71 Model for comparison

# %%
# %load_ext autoreload
# %autoreload 2

# sys.path.insert(0, '/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/')
# from PYGEODYN import Pygeodyn


# #### ----------------------------------------------
# ####
# #### ----------------- RUN JAACHIA ----------------- 
# ####
# #### ----------------------------------------------

# ##### Use copy.deepcopy to copy all levels of dictionary and 
# ###       allow modification of new variable
# run_params3 = copy.deepcopy(run_params)
# run_params3['den_model']         =  'jaachia71'  


# #### Run pyeodyn for the arcs in the above set.
# Obj_Geodyn = Pygeodyn(run_params3)
# Obj_Geodyn.RUN_GEODYN()

# %% [markdown]
# ## Read GEODYN Output using PygeodynRead functionality
#
# ### Get MSIS2 Data

# %%
# Clear the memory of the notebook because the saved variables get so large:
# %reset -f out

# %%
# %load_ext autoreload
# %autoreload 2

# import sys  
# sys.path.insert(0, '/data/geodyn_proj/pygeodyn/utils_pygeodyn_develop/')
# from PYGEODYN import Pygeodyn

# #------ A dictionary containing the run parameters ------  
# run_params1 = {} 
# run_params1['arc']               =  ['2018.313',
#                                      '2018.314',
#                                      '2018.315',
#                                      '2018.316',
#                                      '2018.317',
#                                     ] 
# run_params1['satellite']         =  'icesat2'  
# run_params1['den_model']         =  'msis2'  
# run_params1['SpecialRun_name']   =  '_TrajAnalysis'  
# run_params1['verbose']           =  False
# run_params1['action']            =  'read'

# Obj_Geodyn1 = Pygeodyn(run_params1)
# Obj_Geodyn1.getData()

# %% [markdown]
# ### Get DTM87 Data

# %%
# %load_ext autoreload
# %autoreload 2

# from PYGEODYN import Pygeodyn
# import copy


# run_params2 = copy.deepcopy(run_params1)

# run_params2['den_model']         =  'dtm87'  

# Obj_Geodyn2 = Pygeodyn(run_params2)
# Obj_Geodyn2.getData()

# %% [markdown]
# ### Get Jaachia 71 Data

# %%
# %load_ext autoreload
# %autoreload 2

# from PYGEODYN import Pygeodyn
# # import copy


# run_params3 = copy.deepcopy(run_params1)
# run_params3['den_model']         =  'jaachia71'  

# Obj_Geodyn3 = Pygeodyn(run_params3)
# Obj_Geodyn3.getData()
