# %%
# %load_ext autoreload
# %autoreload 2
import copy
import time
import sys  
sys.path.insert(0, '/data/geodyn_proj/pygeodyn/')
from pygeodyn_Control import pygeodyn_CONTROL

# %% [markdown]
# ## With DRHODZ Update:

# %%
# #### CHANGEABLE INPUTS

# base_params = {}
# base_params['run_ID']           =  None
# base_params['arc']              = None 

# base_params['satellite']        = 'starlette'
# base_params['den_model']        = 'msis00'
# base_params['empirical_accels'] =  False
# base_params['SpecialRun_name']  = ''
# base_params['options_in']       = {'DRHODZ_update':True} 
# base_params['verbose']          =  False

# %%
# params_arc1  = copy.deepcopy(base_params) 
# params_arc2  = copy.deepcopy(base_params) 
# params_arc3  = copy.deepcopy(base_params) 
# params_arc4  = copy.deepcopy(base_params) 
# params_arc5  = copy.deepcopy(base_params) 
# params_arc6  = copy.deepcopy(base_params) 
# params_arc7  = copy.deepcopy(base_params) 
# params_arc8  = copy.deepcopy(base_params) 

# params_arc1['arc']      = '030914_2wk' 
# params_arc1['run_ID']   = 'RUN-Arc1'

# params_arc2['arc']      = '030928_2wk' 
# params_arc2['run_ID']   = 'RUN-Arc2'

# params_arc3['arc']      = '031012_2wk' 
# params_arc3['run_ID']   = 'RUN-Arc3'

# params_arc4['arc']      = '031026_2wk' 
# params_arc4['run_ID']   = 'RUN-Arc4'

# params_arc5['arc']      = '031109_2wk' 
# params_arc5['run_ID']   = 'RUN-Arc5'

# params_arc6['arc']      = '031123_2wk' 
# params_arc6['run_ID']   = 'RUN-Arc6'

# params_arc7['arc']      = '031207_2wk' 
# params_arc7['run_ID']   = 'RUN-Arc7'

# params_arc8['arc']      = '031221_2wk' 
# params_arc8['run_ID']   = 'RUN-Arc8'

# %%
# ####Initialize the objects:
# run_geodyn_arc1 = pygeodyn_CONTROL(params_arc1)
# run_geodyn_arc2 = pygeodyn_CONTROL(params_arc2)
# run_geodyn_arc3 = pygeodyn_CONTROL(params_arc3)
# run_geodyn_arc4 = pygeodyn_CONTROL(params_arc4)
# run_geodyn_arc5 = pygeodyn_CONTROL(params_arc5)
# run_geodyn_arc6 = pygeodyn_CONTROL(params_arc6)
# run_geodyn_arc7 = pygeodyn_CONTROL(params_arc7)
# run_geodyn_arc8 = pygeodyn_CONTROL(params_arc8)


# ####  Run GEODYN for each run object
# start = time.time()

# run_geodyn_arc1.RUN_GEODYN()
# run_geodyn_arc2.RUN_GEODYN()
# run_geodyn_arc3.RUN_GEODYN()
# run_geodyn_arc4.RUN_GEODYN()
# run_geodyn_arc5.RUN_GEODYN()
# run_geodyn_arc6.RUN_GEODYN()
# run_geodyn_arc7.RUN_GEODYN()
# run_geodyn_arc8.RUN_GEODYN()


# elapsed = time.time() - start
# print(' ')
# print('Total time to run all arcs',' : ',elapsed,'secs | (',str(float(elapsed)/60),' mins)')
# print(           '(',     str(float(elapsed)/60/60),' hours)')

# %% [markdown]
# ## Without DrhoDz update

# %%
#### CHANGEABLE INPUTS

base_params = {}
base_params['run_ID']           =  None
base_params['arc']              = None 

base_params['satellite']        = 'starlette'
base_params['den_model']        = 'msis00'
base_params['empirical_accels'] =  False
base_params['SpecialRun_name']  = '_drhodzOrig'
base_params['options_in']       = {'DRHODZ_update':False} 
base_params['verbose']          =  False
 


params_arc1  = copy.deepcopy(base_params) 
params_arc2  = copy.deepcopy(base_params) 
params_arc3  = copy.deepcopy(base_params) 
params_arc4  = copy.deepcopy(base_params) 
params_arc5  = copy.deepcopy(base_params) 
params_arc6  = copy.deepcopy(base_params) 
params_arc7  = copy.deepcopy(base_params) 
params_arc8  = copy.deepcopy(base_params) 



params_arc1['arc']      = '030914_2wk' 
params_arc1['run_ID']   = 'RUN-Arc1'

params_arc2['arc']      = '030928_2wk' 
params_arc2['run_ID']   = 'RUN-Arc2'

params_arc3['arc']      = '031012_2wk' 
params_arc3['run_ID']   = 'RUN-Arc3'

params_arc4['arc']      = '031026_2wk' 
params_arc4['run_ID']   = 'RUN-Arc4'

params_arc5['arc']      = '031109_2wk' 
params_arc5['run_ID']   = 'RUN-Arc5'

params_arc6['arc']      = '031123_2wk' 
params_arc6['run_ID']   = 'RUN-Arc6'

params_arc7['arc']      = '031207_2wk' 
params_arc7['run_ID']   = 'RUN-Arc7'

params_arc8['arc']      = '031221_2wk' 
params_arc8['run_ID']   = 'RUN-Arc8'

# %%
####Initialize the objects:

run_geodyn_arc1 = pygeodyn_CONTROL(params_arc1)
run_geodyn_arc2 = pygeodyn_CONTROL(params_arc2)
run_geodyn_arc3 = pygeodyn_CONTROL(params_arc3)
run_geodyn_arc4 = pygeodyn_CONTROL(params_arc4)
run_geodyn_arc5 = pygeodyn_CONTROL(params_arc5)
run_geodyn_arc6 = pygeodyn_CONTROL(params_arc6)
run_geodyn_arc7 = pygeodyn_CONTROL(params_arc7)
run_geodyn_arc8 = pygeodyn_CONTROL(params_arc8)


####  Run GEODYN for each run object
start = time.time()

# run_geodyn_arc1.RUN_GEODYN()
# run_geodyn_arc2.RUN_GEODYN()
# run_geodyn_arc3.RUN_GEODYN()
# run_geodyn_arc4.RUN_GEODYN()
# run_geodyn_arc5.RUN_GEODYN()
run_geodyn_arc6.RUN_GEODYN()
run_geodyn_arc7.RUN_GEODYN()
run_geodyn_arc8.RUN_GEODYN()

elapsed = time.time() - start
print(' ')
print('Total time to run all arcs',' : ',elapsed,'secs | (',str(float(elapsed)/60),' mins)')
print(           '(',     str(float(elapsed)/60/60),' hours)')
# Out:
# RUN-Arc6     Current Time =      20:51:23
#
# RUN-Arc6     Density Model:      msis00
# RUN-Arc6     GEODYN Version:     pygeodyn_MODS
# RUN-Arc6     Estimate GenAccel:  acceloff
# RUN-Arc6     ARC run:            st031123_2wk
# RUN-Arc6     Output directory:   /data/data_geodyn/results/st/msis00/msis00_acceloff_drhodzOrig
# RUN-Arc6     Call Options:      {'DRHODZ_update': False}
#
# RUN-Arc6          Running IIS
# RUN-Arc6          No errors in IIS
# RUN-Arc6 ---------End of IIS
#
# RUN-Arc6          Running IIE
# RUN-Arc6          Current Time = 20:51:39
# RUN-Arc6          No errors in IIE
# RUN-Arc6 ---------End of IIE
# RUN-Arc6          Time of IIE:  1021.0956971645355 secs ( 17.018261619408925  mins)
# RUN-Arc6          Current Time = 21:08:40
# File is not in RUN-Arc6 : fort.71 -- emat
# File is not in RUN-Arc6 : fort.30 -- orbfil
# File is not in RUN-Arc6 : fort.98 -- msis_in_file
# File is not in RUN-Arc6 : fort.101 -- msis_out_file
# File is not in RUN-Arc6 : fort.103 -- msis_SWI_file
# RUN-Arc6                Finished renaming files
# RUN-Arc6                Finished copying files to outputdir
# RUN-Arc7     Current Time =      21:08:44
#
# RUN-Arc7     Density Model:      msis00
# RUN-Arc7     GEODYN Version:     pygeodyn_MODS
# RUN-Arc7     Estimate GenAccel:  acceloff
# RUN-Arc7     ARC run:            st031207_2wk
# RUN-Arc7     Output directory:   /data/data_geodyn/results/st/msis00/msis00_acceloff_drhodzOrig
# RUN-Arc7     Call Options:      {'DRHODZ_update': False}
#
# RUN-Arc7          Running IIS
# RUN-Arc7          No errors in IIS
# RUN-Arc7 ---------End of IIS
#
# RUN-Arc7          Running IIE
# RUN-Arc7          Current Time = 21:09:00
# RUN-Arc7          No errors in IIE
# RUN-Arc7 ---------End of IIE
# RUN-Arc7          Time of IIE:  1179.1713001728058 secs ( 19.652855002880095  mins)
# RUN-Arc7          Current Time = 21:28:39
# File is not in RUN-Arc7 : fort.71 -- emat
# File is not in RUN-Arc7 : fort.30 -- orbfil
# File is not in RUN-Arc7 : fort.98 -- msis_in_file
# File is not in RUN-Arc7 : fort.101 -- msis_out_file
# File is not in RUN-Arc7 : fort.103 -- msis_SWI_file
# RUN-Arc7                Finished renaming files
# RUN-Arc7                Finished copying files to outputdir
# RUN-Arc8     Current Time =      21:28:44
#
# RUN-Arc8     Density Model:      msis00
# RUN-Arc8     GEODYN Version:     pygeodyn_MODS
# RUN-Arc8     Estimate GenAccel:  acceloff
# RUN-Arc8     ARC run:            st031221_2wk
# RUN-Arc8     Output directory:   /data/data_geodyn/results/st/msis00/msis00_acceloff_drhodzOrig
# RUN-Arc8     Call Options:      {'DRHODZ_update': False}
#
# RUN-Arc8          Running IIS
# RUN-Arc8          No errors in IIS
# RUN-Arc8 ---------End of IIS
#
# RUN-Arc8          Running IIE
# RUN-Arc8          Current Time = 21:29:00
# RUN-Arc8          No errors in IIE
# RUN-Arc8 ---------End of IIE
# RUN-Arc8          Time of IIE:  1171.008374929428 secs ( 19.5168062488238  mins)
# RUN-Arc8          Current Time = 21:48:31
# File is not in RUN-Arc8 : fort.71 -- emat
# File is not in RUN-Arc8 : fort.30 -- orbfil
# File is not in RUN-Arc8 : fort.98 -- msis_in_file
# File is not in RUN-Arc8 : fort.101 -- msis_out_file
# File is not in RUN-Arc8 : fort.103 -- msis_SWI_file
# RUN-Arc8                Finished renaming files
# RUN-Arc8                Finished copying files to outputdir
#
# Total time to run all arcs  :  3433.422379255295 secs | ( 57.22370632092158  mins)
# ( 0.9537284386820263  hours)
