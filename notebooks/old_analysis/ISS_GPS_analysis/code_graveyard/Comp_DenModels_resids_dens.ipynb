# %% [markdown]
# This Notebook compares the different models that are in GEODYN II--- as of 2020-12-03.
# Author: Zach Waldron
# Date created: 2020-12-03
# Last modified:  2020-12-08
#
# <!-- ```python
# from datetime import date
# today = date.today()
# print("Last modifed:", today)
# ``` -->

# %% [markdown]
# # Start with a test of loading the data

# %% [markdown]
# ## Import relevant packages and identify the data location

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import datetime
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib as mpl
import os.path
import linecache

# %% [markdown]
# Identify data location:
#
#
# If the below indicates ``TRUE`` then the data path exists.

# %%
# import sys  
# sys.path.insert(0, '/content/drive/My Drive/GEODYN-KAMODO Project/')
# /content/drive/My Drive/GEODYN-KAMODO Project/RUNS/adding_resid_orbit_printout/iieout

runs_path = '/content/drive/My Drive/GEODYN-KAMODO Project/RUNS/ISS_GPS/MSIS86_run/'

ascii_xyz_file = runs_path + 'ascii_xyz'
ascii_kep_file = runs_path + 'ascii_kep'
iieout_file    = runs_path + 'iieout'
# print(ascii_xyz_file)
# print(ascii_kep_file)

print(os.path.isfile(ascii_xyz_file) )
print(os.path.isfile(ascii_kep_file) )
print(os.path.isfile(iieout_file) )
# Out:
# True
# True
# True

# %% [markdown]
# Change path to be the notebooks folder.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys  
sys.path.insert(0, '/content/drive/My Drive/GEODYN-KAMODO Project/notebooks')

import Read_GEODYN_output
import Visualize_GEODYN_output

# %% [markdown]
# #### Construct an array that contains the xyz trajectory data for a single satellite

# %%
isat = 5658125

read_ascii_xyz = Read_GEODYN_output.read_ascii_xyz(ascii_xyz_file, iieout_file , isat )
data_dict = read_ascii_xyz.get_single_sat_data()
# Out:
# Loop through and extract indiv date vals: 0.1952824592590332
# Fix decimals in the seconds column: 0.19571447372436523
# Put all dates in a single column: 0.19613385200500488
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['timeHHMM'] = timeHHMM
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:258: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['year']  = year
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['month'] = month
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['day']   = day
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['hours']  = hours
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:262: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['minutes'] = minutes
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:263: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['secs']  = secs
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_dict[isat]['Date'] = date_isat

# %% [markdown]
# #### Visualize the xyz trajectory over time period for single satellite

# %%
fig = Visualize_GEODYN_output.SingleSat_XYZ(isat, data_dict, read_ascii_xyz.iteration_number())
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
# %load_ext autoreload
# %autoreload 2
from Read_GEODYN_output import read_residuals_iieout

read_residuals_iieout = read_residuals_iieout(iieout_file, True)
SatIDs = read_residuals_iieout.find_Sat_IDs_resids()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# On iteration 6
# - then go through each satellite and collect the residuals chronologically
# - we can then plot out the residuals by satellite

# %%
# %load_ext autoreload
# %autoreload 2
from Read_GEODYN_output import read_residuals_iieout

read_residuals_iieout = read_residuals_iieout(iieout_file, True)
Resids_iter6 = read_residuals_iieout.read_observed_resids_by_sat( )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#   STATION-SATELLITE CONFIGURATION  DSS1WRNG           9806701           5044284           5553175                      (*NEW*)
#
# 5044284
# Elapsed time: 2.3928425312042236
# 0 / 8545

# %%
# %load_ext autoreload
# %autoreload 2
from Read_GEODYN_output import read_residuals_iieout

read_residuals_iieout = read_residuals_iieout(iieout_file, True)  # define class parameters
Resids_iter6 = read_residuals_iieout.read_observed_resids_all( )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Elapsed time after line search setup: 6.922943115234375
# Elapsed time after loop through then drop indecies: 43.28487801551819
# Elapsed time after dropping all bad indicies after last obs no.: 43.45698285102844
# Loop through and extract indiv date vals: 8.662431478500366
# Fix decimals in the seconds column: 8.833108186721802
# Put all dates in a single column: 9.339578628540039

# %%
# %load_ext autoreload
# %autoreload 2
import Visualize_GEODYN_output
fig = Visualize_GEODYN_output.Residuals_Observ_All( Resids_iter6, str(int(read_residuals_iieout.iteration_number())))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mpl.rcParams['lines.markersize'] = 6
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 1
plt.rcParams['grid.color'] = "#cccccc"
plt.rcParams.update({'font.size': 16})
rc('font',**{'family':'sans-serif','sans-serif':['Calibri']})
plt.rcParams['axes.titlesize']='large' 
plt.rcParams['axes.titlepad']= 3
rc('text', usetex=False)
plt.rcParams["legend.loc"] = 'best'


fig, ( ax1,ax2) = plt.subplots(2,1, figsize=(12,10), sharex=False)
ax1.set_title('IIEOUT Observation Residuals from Iteration '+str(int(read_residuals_iieout.iteration_number())) +' (First 1.75 minutes)')
ax1.plot(pd.to_datetime(Resids_iter6['Date'][:300]), Resids_iter6['Residual'].values.astype(float)[:300] ,'.', label = 'Residuals iter 6')
ax1.set(ylabel=  'resids')  
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles[::-1], labels[::-1],  loc='center left', bbox_to_anchor=(1,0.5), markerscale = 2 )

ax2.set_title('Ratio to sigma ')
ax2.set(ylabel=  'Ratio to sigma')  
ax2.plot(pd.to_datetime(Resids_iter6['Date'][:300]), Resids_iter6['Ratio_to_sigma_fixed'].values.astype(float)[:300] ,'.', label = 'ratio to sigma')

handles2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(handles2[::-1], labels2[::-1],  loc='center left', bbox_to_anchor=(1,0.5), markerscale = 2 )


# # ax2.set(xlabel= 'Modified Julian Date') 
# ax2.set(xlabel= 'Date') 

fig.tight_layout( pad=5.0)


for ax in fig.axes:
    plt.sca(ax)
    plt.xticks(rotation=45)

# images_dir = '/content/drive/MyDrive/GEODYN-KAMODO Project/RUNS/adding_resid_orbit_printout/plots'
# plt.savefig(f"{images_dir}/ObservationResidualsIter%d_shortTiem.png" % int(iteration) )
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# #### Plot modeled density along the orbit from fort.99 file
#
# The below code takes about 90 seconds to run

# %%
runs_path = '/content/drive/My Drive/GEODYN-KAMODO Project/RUNS/ISS_GPS/MSIS86_run/'
# %load_ext autoreload
# %autoreload 2

denfil_msis86 = runs_path + 'densityfil'
print(os.path.isfile(denfil_msis86) )
from Read_densityfil import read_density_file

denmsis86 = read_density_file(denfil_msis86)
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline


from Visualize_GEODYN_output import plot_density
fig = plot_density( denmsis86, 'MSIS-86','ISS' )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# True
# Loop through and extract indiv date vals: 96.2947325706482
# Put all dates in a single column: 96.32753825187683
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Compare GEODYN runs using different Atmospheric Models:

# %% [markdown]
# ##### Load Model Data sets:

# %%
msis86_path = '/content/drive/My Drive/GEODYN-KAMODO Project/RUNS/ISS_GPS/MSIS86_run/'

msis86_ascii_xyz_file = msis86_path + 'ascii_xyz'
msis86_ascii_kep_file = msis86_path + 'ascii_kep'
msis86_iieout_file    = msis86_path + 'iieout'
# print(ascii_xyz_file)
# print(ascii_kep_file)

print(os.path.isfile(msis86_ascii_xyz_file) )
print(os.path.isfile(msis86_ascii_kep_file) )
print(os.path.isfile(msis86_iieout_file) )

DTM_path = '/content/drive/My Drive/GEODYN-KAMODO Project/RUNS/ISS_GPS/DTM_run/'

DTM_ascii_xyz_file = DTM_path + 'ascii_xyz'
DTM_ascii_kep_file = DTM_path + 'ascii_kep'
DTM_iieout_file    = DTM_path + 'iieout'
# print(ascii_xyz_file)
# print(ascii_kep_file)

print(os.path.isfile(DTM_ascii_xyz_file) )
print(os.path.isfile(DTM_ascii_kep_file) )
print(os.path.isfile(DTM_iieout_file) )

jacchia_path = '/content/drive/My Drive/GEODYN-KAMODO Project/RUNS/ISS_GPS/Jacchia_run/'

jacchia_ascii_xyz_file = jacchia_path + 'ascii_xyz'
jacchia_ascii_kep_file = jacchia_path + 'ascii_kep'
jacchia_iieout_file    = jacchia_path + 'iieout'
# print(ascii_xyz_file)
# print(ascii_kep_file)

print(os.path.isfile(jacchia_ascii_xyz_file) )
print(os.path.isfile(jacchia_ascii_kep_file) )
print(os.path.isfile(jacchia_iieout_file) )
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## Plot Trajectory Comparison:

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys  
sys.path.insert(0, '/content/drive/My Drive/GEODYN-KAMODO Project/notebooks')

import Read_GEODYN_output
import Visualize_GEODYN_output

isat = 5658125
# 9806701
msis86_read_ascii_xyz = Read_GEODYN_output.read_ascii_xyz(msis86_ascii_xyz_file, msis86_iieout_file , isat )
msis86_data_dict = msis86_read_ascii_xyz.get_single_sat_data()


DTM_read_ascii_xyz = Read_GEODYN_output.read_ascii_xyz(DTM_ascii_xyz_file, DTM_iieout_file , isat )
DTM_data_dict = DTM_read_ascii_xyz.get_single_sat_data()


jacchia_read_ascii_xyz = Read_GEODYN_output.read_ascii_xyz(jacchia_ascii_xyz_file, jacchia_iieout_file , isat )
jacchia_data_dict = jacchia_read_ascii_xyz.get_single_sat_data()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['timeHHMM'] = timeHHMM
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:258: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['year']  = year
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['month'] = month
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['day']   = day
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['hours']  = hours
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:262: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['minutes'] = minutes
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:263: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['secs']  = secs
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_dict[isat]['Date'] = date_isat
# Loop through and extract indiv date vals: 0.024473190307617188
# Fix decimals in the seconds column: 0.024918317794799805
# Put all dates in a single column: 0.025325298309326172
# Loop through and extract indiv date vals: 0.013468265533447266
# Fix decimals in the seconds column: 0.013972759246826172
# Put all dates in a single column: 0.01439809799194336
# Loop through and extract indiv date vals: 0.013099908828735352
# Fix decimals in the seconds column: 0.013592243194580078
# Put all dates in a single column: 0.013997554779052734

# %%
jacchia_read_ascii_xyz = Read_GEODYN_output.read_ascii_xyz(jacchia_ascii_xyz_file, jacchia_iieout_file , isat )
jacchia_data_dict = jacchia_read_ascii_xyz.get_single_sat_data()
# Out:
# Loop through and extract indiv date vals: 0.016582250595092773
# Fix decimals in the seconds column: 0.01698017120361328
# Put all dates in a single column: 0.017659425735473633
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['timeHHMM'] = timeHHMM
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:258: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['year']  = year
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['month'] = month
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['day']   = day
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['hours']  = hours
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:262: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['minutes'] = minutes
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:263: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isat_data['secs']  = secs
# /content/drive/My Drive/GEODYN-KAMODO Project/notebooks/Read_GEODYN_output.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_dict[isat]['Date'] = date_isat

# %%
# %load_ext autoreload
# %autoreload 2
import Visualize_GEODYN_output

data_dict_list = {'MSIS86':msis86_data_dict, 'DTM 87':DTM_data_dict, 'Jacchia71':jacchia_data_dict}

fig = Visualize_GEODYN_output.SingleSat_XYZ_multiple_runs(isat,  msis86_read_ascii_xyz.iteration_number(), data_dict_list)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Compare Density Outputs

# %%
runs_path = '/content/drive/My Drive/GEODYN-KAMODO Project/RUNS/ISS_GPS/'


denfil_msis86 = runs_path + 'MSIS86_run/densityfil'
print(os.path.isfile(denfil_msis86) )

denfil_DTM = runs_path + 'DTM_run/densityfil'
print(os.path.isfile(denfil_DTM) )

denfil_jacchia = runs_path + 'Jacchia_run/densityfil'
print(os.path.isfile(denfil_jacchia) )
# Out:
# True
# True
# True

# %%
# %load_ext autoreload
# %autoreload 2
from Read_densityfil import read_density_file

denmsis86 = read_density_file(denfil_msis86)

denDTM = read_density_file(denfil_DTM)

# denjacchia= read_density_file(denfil_jacchia)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loop through and extract indiv date vals: 96.86319780349731
# Put all dates in a single column: 96.89616394042969
# Loop through and extract indiv date vals: 97.54057216644287
# Put all dates in a single column: 97.57516026496887

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from Visualize_GEODYN_output import plot_density
# fig = plot_density( denmsis86, 'MSIS-86','ISS' )
# fig = plot_density( denDTM, 'DTM-87','ISS' )
from Visualize_GEODYN_output import compare_multiple_density_models

dens_list = {'MSIS86':denmsis86, 'DTM 87':denDTM, }#'Jacchia 71':denjacchia}
choose_sat = 'ISS'
fig = compare_multiple_density_models(dens_list, choose_sat)


local_path = '/content/drive/MyDrive/GEODYN-KAMODO Project/notebooks/ISS_GPS_analysis/'
import os
images_dir = local_path +'plots'
if not os.path.exists(images_dir):
    os.makedirs(images_dir)
fig.savefig(f"{images_dir}/Density@orbit_comparison.png", bbox_inches='tight')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0 MSIS86
# 1 DTM 87

# %%
x = -1

mpl.rcParams['lines.markersize'] = 3
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 1
plt.rcParams['grid.color'] = "#cccccc"
plt.rcParams.update({'font.size': 16})
rc('font',**{'family':'sans-serif','sans-serif':['Calibri']})
plt.rcParams['axes.titlesize']='large' 
plt.rcParams['axes.titlepad']= 3
rc('text', usetex=False)
plt.rcParams["legend.loc"] = 'best'

color86 = 'tab:blue'
color71 = 'tab:red'
color87 = 'tab:green'

fig, ( ax1, ax2) = plt.subplots(2, 1, figsize=(12,10), sharex=False)

ax1.set_title(r''+choose_sat+' Orbit')
ax1.plot(denmsis86['Lon'][:x], denmsis86['Lat'][:x] ,'.', color = color86, label = 'MSIS')
ax1.plot(denDTM['Lon'][:x], denDTM['Lat'][:x] ,'.',color = color87,  label = 'DTM')
ax1.set(ylabel=  'Latitude')  
ax1.set(ylabel=  'Longitude')  
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(handles[::-1], labels[::-1],  loc='center left', bbox_to_anchor=(1,0.5), markerscale = 2 )

ax2.set_title(r'Ratios of Orbit Parameters')
ax2.plot(denmsis86['Date'][:x] , denmsis86['Lon'][:x] / denDTM['Lon'][:x] ,'.', label = 'ratio lons')
ax2.plot(denmsis86['Date'][:x] , denmsis86['Lat'][:x] / denDTM['Lat'][:x] ,'.', label = 'ratio lats')
ax2.plot(denmsis86['Date'][:x] , denmsis86['Height (meters)'][:x] / denDTM['Height (meters)'][:x] ,'.', label = 'ratio altitude')

# ax2.plot(,  ,'.', label = 'DTM')
ax2.set(ylabel=  'Latitude')  
ax2.set(ylabel=  'Longitude')  
handles, labels = ax2.get_legend_handles_labels()
ax2.legend(handles[::-1], labels[::-1],  loc='center left', bbox_to_anchor=(1,0.5), markerscale = 2 )



fig.tight_layout( pad=2.0)
for ax in fig.axes:
    plt.sca(ax)
    plt.xticks(rotation=45)

# %%
# np.size(denmsis86['Date'][:x])

# (denmsis86['Height (meters)'][:x] / denDTM['Height (meters)'][:x])

# %%
# %load_ext autoreload
# %autoreload 2
from Read_GEODYN_output import read_residuals_iieout

# msis86_read_ascii_xyz = Read_GEODYN_output.read_ascii_xyz(msis86_ascii_xyz_file, msis86_iieout_file , isat )
# msis86_data_dict = msis86_read_ascii_xyz.get_single_sat_data()
msis86_read_residuals_iieout = read_residuals_iieout(msis86_iieout_file, True)  # define class parameters
msis86_Resids_iter6 = msis86_read_residuals_iieout.read_observed_resids_all( )


DTM_read_residuals_iieout = read_residuals_iieout(DTM_iieout_file, True)  # define class parameters
DTM_Resids_iter6 = DTM_read_residuals_iieout.read_observed_resids_all( )


jacchia_read_residuals_iieout = read_residuals_iieout(jacchia_iieout_file, True)  # define class parameters
jacchia_Resids_iter6 = jacchia_read_residuals_iieout.read_observed_resids_all( )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Elapsed time after line search setup: 7.020339488983154
# Elapsed time after loop through then drop indecies: 43.61437225341797
# Elapsed time after dropping all bad indicies after last obs no.: 43.71664524078369
# Loop through and extract indiv date vals: 8.438780546188354
# Fix decimals in the seconds column: 8.602320671081543
# Put all dates in a single column: 9.102089166641235
# Elapsed time after line search setup: 6.860738277435303
# Elapsed time after loop through then drop indecies: 43.87263250350952
# Elapsed time after dropping all bad indicies after last obs no.: 43.971712589263916
# Loop through and extract indiv date vals: 11.714460611343384
# Fix decimals in the seconds column: 11.881816625595093
# Put all dates in a single column: 12.408411264419556
# Elapsed time after line search setup: 7.014729022979736
# Elapsed time after loop through then drop indecies: 43.653167963027954
# Elapsed time after dropping all bad indicies after last obs no.: 43.748631715774536
# Loop through and extract indiv date vals: 8.634639024734497
# Fix decimals in the seconds column: 8.799084186553955
# Put all dates in a single column: 9.314738750457764

# %%
resids_list = {'MSIS86':msis86_Resids_iter6, 'DTM 87':DTM_Resids_iter6, 'Jacchia71':jacchia_Resids_iter6}


mpl.rcParams['lines.markersize'] = 6
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 1
plt.rcParams['grid.color'] = "#cccccc"
plt.rcParams.update({'font.size': 16})
rc('font',**{'family':'sans-serif','sans-serif':['Calibri']})
plt.rcParams['axes.titlesize']='large' 
plt.rcParams['axes.titlepad']= 3
rc('text', usetex=False)
plt.rcParams["legend.loc"] = 'best'


fig, ( ax1,ax2) = plt.subplots(2,1, figsize=(12,10), sharex=False)
for i,val in enumerate(resids_list):

    ax1.set_title('Compare DEN Models: Residuals from Iteration '+str(int(msis86_read_ascii_xyz.iteration_number())) +' (First 1.75 minutes)')
    ax1.plot(pd.to_datetime(resids_list[val]['Date'][:]), resids_list[val]['Residual'].values.astype(float)[:] ,'.', label = val)
    ax1.set(ylabel=  'resids')  
    handles, labels = ax1.get_legend_handles_labels()
    ax1.legend(handles[::-1], labels[::-1],  loc='center left', bbox_to_anchor=(1,0.5), markerscale = 2 )

    ax2.set_title('Ratio to sigma ')
    ax2.set(ylabel=  'Ratio to sigma')  
    ax2.plot(pd.to_datetime(resids_list[val]['Date'][:]), resids_list[val]['Ratio_to_sigma_fixed'].values.astype(float)[:] ,'.', label = val)

    handles2, labels2 = ax2.get_legend_handles_labels()
    ax2.legend(handles2[::-1], labels2[::-1],  loc='center left', bbox_to_anchor=(1,0.5), markerscale = 2 )


    # # ax2.set(xlabel= 'Modified Julian Date') 
    # ax2.set(xlabel= 'Date') 

    fig.tight_layout( pad=5.0)


    for ax in fig.axes:
        plt.sca(ax)
        plt.xticks(rotation=45)

    # images_dir = '/content/drive/MyDrive/GEODYN-KAMODO Project/RUNS/adding_resid_orbit_printout/plots'
    # plt.savefig(f"{images_dir}/ObservationResidualsIter%d_shortTiem.png" % int(iteration) )

# %%
read_residuals_iieout = read_residuals_iieout(msis86_iieout_file, True)

# %%
# !pip install csv
import csv
import itertools

# %%
# with open(msis86_path  + 'all_sat_residsMSIS860', 'rb') as pickle_file:
#   dict_sats_resids = pickle.load(pickle_file)

# %%
if os.path.exists( msis86_path  + 'all_sat_residsMSIS86'):
  print('The file that contains the residuals for each GPS-config exists.')
  import pickle
  with open(msis86_path  + 'all_sat_residsMSIS86', 'rb') as pickle_file:
    dict_sats_resids = pickle.load(pickle_file)

else:
      
  iteration = '6'



  #-------------------------------------------------------------------------------
  #-------------------------------------------------------------------------------
  #-------------------------------------------------------------------------------
  #-------------------------------------------------------------------------------
  '''
    Now find all the instances of the OBSERVATION RESIDUALS 
    header at this iteration.  These are stored in a list.
  '''

  SatIDs = read_residuals_iieout.find_Sat_IDs_resids()

  # Loop through the file and save the line 
  # numbers of the observation residual headers
  lines_list = [] 
  text_obs_resid = 'OBSERVATION RESIDUALS FOR ARC  1 FOR INNER ITERATION  '+ str(int(iteration))
  with open(msis86_iieout_file, 'r') as f:
      for line_no, line in enumerate(f):
          if text_obs_resid in line:
              lines_list.append(line_no)

  import time
  start = time.time()

  # initialize the dataframe that the data will be stored into
  init_df = pd.DataFrame(data={'YYMMDD'   :[],
                          'HHMM'    :[],
                          'Sec-UTC-R' :[],
                          'Observation'       :[],
                          'Residual'       :[],
                          'Ratio to sigma'       :[],
                          'Elev1'    :[],
                          'Elev2'    :[],
                          'OBS No.'    :[],
                          'Block'     :[],})
  # Initialize a dictionary such that each 
  # index of the dict is the empty dataframe
  dict_sat = {}
  for i in SatIDs:
    dict_sat[i]= init_df

  # Loop through the stored headers at their line numbers
  for i,iline in enumerate(lines_list):
    header_line = linecache.getline(msis86_iieout_file, iline+1+1) #
    if header_line[35:43] == 'DSS1WRNG':  #TODO: need to double check what this is...
      sat_line = int(header_line[70:81])  
      # print()
      #   print(line)
      # print(sat_line)

      # end = time.time()
      # elapsed = end - start
      # print("1 Elapsed time:",elapsed)
      
      YYMMDD    = []
      HHMM      = []
      Sec_utc   = []
      Observation = []
      Residual  = []
      Ratio_to_sigma = []
      Elev1      = []
      Elev2      = []
      OBS      = []
      Block      = []
      
      with open(msis86_iieout_file) as csvfile:
        N0 = lines_list[0] + 6  # number of lines to skip
        N1 = lines_list[0] + 6 + int((lines_list[0 + 1]-6 - lines_list[0]-7) )  # where to stop reading lines
        for row in csv.DictReader( itertools.islice(csvfile, N0, N1) ):
          YYMMDD.append( float(row[None][0][1:8]))
          HHMM.append(        float(row[None][0][8:13]))
          Sec_utc.append(     float(row[None][0][14:23]))
          Observation.append( float(row[None][0][29:43]))
          Residual.append(    float(row[None][0][48:58]))
          Ratio_to_sigma = float(row[None][0][62:70])
          Elev1          = float(row[None][0][74:84])
          Elev2          = float(row[None][0][86:96])
          OBS            = float(row[None][0][110:117])
          Block          = float(row[None][0][119:125])
          # print(row)
          # print(YYMMDD)

      end = time.time()
      elapsed = end - start
      # print("2 Elapsed time:",elapsed)

      A = pd.DataFrame(data={'YYMMDD'   :YYMMDD,
                            'HHMM'    :  HHMM,
                            'Sec-UTC-R' :Sec_utc,
                            'Observation'       :Observation,
                            'Residual'       :Residual,
                            'Ratio to sigma' : Ratio_to_sigma,
                            'Elev1'    : Elev1,
                            'Elev2'    : Elev2,
                            'OBS No.'    : OBS,
                            'Block'     : Block,})
      B = dict_sat[sat_line]
      dict_sat[sat_line] =  pd.concat([ B, A])
      end = time.time()
      elapsed = end - start
      print("Elapsed time:",elapsed)
      print(iline, line)
      print(i ,'/', str(len(lines_list)))
      # return RESID_OBSERV
    else:
      continue

  model_choose = 'MSIS86'
  import pickle


  with open(msis86_path +'all_sat_resids' + model_choose, 'wb') as pickle_file:
    pickle.dump(dict_sat, pickle_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Streaming output truncated to the last 5000 lines.
# Elapsed time: 3542.0827219486237
# 2690382  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7140 / 8545
# Elapsed time: 3542.668192386627
# 2690435  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7141 / 8545
# Elapsed time: 3543.2653081417084
# 2690488  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7142 / 8545
# Elapsed time: 3543.818593263626
# 2690541  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7143 / 8545
# Elapsed time: 3544.3808677196503
# 2690594  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7144 / 8545
# Elapsed time: 3544.9426345825195
# 2690647  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7145 / 8545
# Elapsed time: 3545.5044910907745
# 2690700  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7146 / 8545
# Elapsed time: 3546.0764186382294
# 2690753  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7147 / 8545
# Elapsed time: 3546.6479353904724
# 2690806  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7148 / 8545
# Elapsed time: 3547.212033033371
# 2690859  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7149 / 8545
# Elapsed time: 3547.770669937134
# 2690912  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7150 / 8545
# Elapsed time: 3548.3191590309143
# 2690965  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7151 / 8545
# Elapsed time: 3548.8769652843475
# 2691016  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7152 / 8545
# Elapsed time: 3549.4416856765747
# 2691065  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7153 / 8545
# Elapsed time: 3550.0260303020477
# 2691114  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7154 / 8545
# Elapsed time: 3550.5927839279175
# 2691163  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7155 / 8545
# Elapsed time: 3551.17210149765
# 2691212  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7156 / 8545
# Elapsed time: 3551.73504281044
# 2691261  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7157 / 8545
# Elapsed time: 3552.298570871353
# 2691314  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7158 / 8545
# Elapsed time: 3552.845791578293
# 2691367  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7159 / 8545
# Elapsed time: 3553.4167053699493
# 2691420  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7160 / 8545
# Elapsed time: 3553.970419883728
# 2691473  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7161 / 8545
# Elapsed time: 3554.53067445755
# 2691526  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7162 / 8545
# Elapsed time: 3555.1018126010895
# 2691579  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7163 / 8545
# Elapsed time: 3555.6758201122284
# 2691632  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7164 / 8545
# Elapsed time: 3556.231300830841
# 2691687  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7165 / 8545
# Elapsed time: 3556.762501001358
# 2691736  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7166 / 8545
# Elapsed time: 3557.3455703258514
# 2691785  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7167 / 8545
# Elapsed time: 3557.8803284168243
# 2691834  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7168 / 8545
# Elapsed time: 3558.4417843818665
# 2691887  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7169 / 8545
# Elapsed time: 3559.0099856853485
# 2691936  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7170 / 8545
# Elapsed time: 3559.507367372513
# 2691989  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7171 / 8545
# Elapsed time: 3560.0605685710907
# 2692042  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7172 / 8545
# Elapsed time: 3560.581920862198
# 2692095  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7173 / 8545
# Elapsed time: 3561.1653707027435
# 2692145  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7174 / 8545
# Elapsed time: 3561.702692270279
# 2692194  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7175 / 8545
# Elapsed time: 3562.22323346138
# 2692247  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7176 / 8545
# Elapsed time: 3562.803778886795
# 2692723  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7186 / 8545
# Elapsed time: 3563.365663290024
# 2692772  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7187 / 8545
# Elapsed time: 3563.915542602539
# 2692821  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7188 / 8545
# Elapsed time: 3564.4851813316345
# 2692870  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7189 / 8545
# Elapsed time: 3565.0342803001404
# 2692919  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7190 / 8545
# Elapsed time: 3565.595826625824
# 2692972  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7191 / 8545
# Elapsed time: 3566.2055044174194
# 2693025  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7192 / 8545
# Elapsed time: 3566.760568857193
# 2693078  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7193 / 8545
# Elapsed time: 3567.3283920288086
# 2693131  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7194 / 8545
# Elapsed time: 3567.873508453369
# 2693184  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7195 / 8545
# Elapsed time: 3568.3956236839294
# 2693234  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7196 / 8545
# Elapsed time: 3568.9033098220825
# 2693283  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7197 / 8545
# Elapsed time: 3569.481819152832
# 2693332  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7198 / 8545
# Elapsed time: 3570.0640680789948
# 2693381  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7199 / 8545
# Elapsed time: 3570.6126577854156
# 2693430  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7200 / 8545
# Elapsed time: 3571.1469707489014
# 2693483  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7201 / 8545
# Elapsed time: 3571.709971189499
# 2693536  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7202 / 8545
# Elapsed time: 3572.2746710777283
# 2693587  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7203 / 8545
# Elapsed time: 3572.811365842819
# 2693642  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7204 / 8545
# Elapsed time: 3573.3707282543182
# 2693691  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7205 / 8545
# Elapsed time: 3573.937336921692
# 2693740  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7206 / 8545
# Elapsed time: 3574.5308299064636
# 2693789  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7207 / 8545
# Elapsed time: 3575.0794553756714
# 2693838  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7208 / 8545
# Elapsed time: 3575.6712918281555
# 2693887  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7209 / 8545
# Elapsed time: 3576.199712753296
# 2693940  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7210 / 8545
# Elapsed time: 3576.779574394226
# 2693993  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7211 / 8545
# Elapsed time: 3577.3376998901367
# 2694046  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7212 / 8545
# Elapsed time: 3577.8843326568604
# 2694099  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7213 / 8545
# Elapsed time: 3578.4309990406036
# 2694152  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7214 / 8545
# Elapsed time: 3578.9935100078583
# 2694205  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7215 / 8545
# Elapsed time: 3579.575383424759
# 2694258  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7216 / 8545
# Elapsed time: 3580.1330847740173
# 2694311  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7217 / 8545
# Elapsed time: 3580.673164129257
# 2694364  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7218 / 8545
# Elapsed time: 3581.238684654236
# 2694417  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7219 / 8545
# Elapsed time: 3581.818389415741
# 2694468  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7220 / 8545
# Elapsed time: 3582.3478498458862
# 2694517  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7221 / 8545
# Elapsed time: 3582.9024879932404
# 2694566  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7222 / 8545
# Elapsed time: 3583.456763267517
# 2694615  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7223 / 8545
# Elapsed time: 3584.002763032913
# 2694664  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7224 / 8545
# Elapsed time: 3584.566193342209
# 2694713  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7225 / 8545
# Elapsed time: 3585.124389886856
# 2694766  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7226 / 8545
# Elapsed time: 3585.672008037567
# 2694819  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7227 / 8545
# Elapsed time: 3586.2045845985413
# 2694872  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7228 / 8545
# Elapsed time: 3586.7885041236877
# 2694925  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7229 / 8545
# Elapsed time: 3587.350091934204
# 2694978  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7230 / 8545
# Elapsed time: 3587.901614189148
# 2695031  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7231 / 8545
# Elapsed time: 3588.442179441452
# 2695084  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7232 / 8545
# Elapsed time: 3588.9946451187134
# 2695137  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7233 / 8545
# Elapsed time: 3589.552306652069
# 2695190  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7234 / 8545
# Elapsed time: 3590.0977413654327
# 2695243  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7235 / 8545
# Elapsed time: 3590.6495628356934
# 2695296  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7236 / 8545
# Elapsed time: 3591.193254470825
# 2695349  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7237 / 8545
# Elapsed time: 3591.7407705783844
# 2695398  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7238 / 8545
# Elapsed time: 3592.269341945648
# 2695447  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7239 / 8545
# Elapsed time: 3592.8169655799866
# 2695500  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7240 / 8545
# Elapsed time: 3593.4032373428345
# 2695553  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7241 / 8545
# Elapsed time: 3593.952165365219
# 2695606  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7242 / 8545
# Elapsed time: 3594.51251578331
# 2695659  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7243 / 8545
# Elapsed time: 3595.0353326797485
# 2695712  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7244 / 8545
# Elapsed time: 3595.587560892105
# 2695765  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7245 / 8545
# Elapsed time: 3596.152386903763
# 2695818  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7246 / 8545
# Elapsed time: 3596.7173964977264
# 2695871  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7247 / 8545
# Elapsed time: 3597.2570340633392
# 2695924  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7248 / 8545
# Elapsed time: 3597.8376636505127
# 2695977  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7249 / 8545
# Elapsed time: 3598.423258304596
# 2696030  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7250 / 8545
# Elapsed time: 3598.975744485855
# 2696083  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7251 / 8545
# Elapsed time: 3599.5649149417877
# 2696136  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7252 / 8545
# Elapsed time: 3600.1424765586853
# 2696189  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7253 / 8545
# Elapsed time: 3600.712249517441
# 2696242  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7254 / 8545
# Elapsed time: 3601.2714326381683
# 2696295  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7255 / 8545
# Elapsed time: 3601.8092267513275
# 2696344  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7256 / 8545
# Elapsed time: 3602.364884853363
# 2696827  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7266 / 8545
# Elapsed time: 3602.9504537582397
# 2696876  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7267 / 8545
# Elapsed time: 3603.511501312256
# 2696925  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7268 / 8545
# Elapsed time: 3604.0525913238525
# 2696974  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7269 / 8545
# Elapsed time: 3604.6199958324432
# 2697023  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7270 / 8545
# Elapsed time: 3605.168397426605
# 2697076  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7271 / 8545
# Elapsed time: 3605.69046998024
# 2697129  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7272 / 8545
# Elapsed time: 3606.1832501888275
# 2697182  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7273 / 8545
# Elapsed time: 3606.796164035797
# 2697235  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7274 / 8545
# Elapsed time: 3607.307136774063
# 2697288  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7275 / 8545
# Elapsed time: 3607.828689813614
# 2697341  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7276 / 8545
# Elapsed time: 3608.3638195991516
# 2697394  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7277 / 8545
# Elapsed time: 3608.898886203766
# 2697447  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7278 / 8545
# Elapsed time: 3609.400246620178
# 2697500  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7279 / 8545
# Elapsed time: 3609.997665166855
# 2697553  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7280 / 8545
# Elapsed time: 3610.555353164673
# 2697606  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7281 / 8545
# Elapsed time: 3611.109431028366
# 2697659  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7282 / 8545
# Elapsed time: 3611.696486234665
# 2697712  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7283 / 8545
# Elapsed time: 3612.2338893413544
# 2697765  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7284 / 8545
# Elapsed time: 3612.776874780655
# 2697818  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7285 / 8545
# Elapsed time: 3613.328712463379
# 2697871  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7286 / 8545
# Elapsed time: 3613.881320476532
# 2697924  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7287 / 8545
# Elapsed time: 3614.434287548065
# 2697977  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7288 / 8545
# Elapsed time: 3614.9638962745667
# 2698030  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7289 / 8545
# Elapsed time: 3615.5178303718567
# 2698083  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7290 / 8545
# Elapsed time: 3616.115698337555
# 2698136  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7291 / 8545
# Elapsed time: 3616.690569162369
# 2698189  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7292 / 8545
# Elapsed time: 3617.300822019577
# 2698242  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7293 / 8545
# Elapsed time: 3617.8355259895325
# 2698295  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7294 / 8545
# Elapsed time: 3618.3601191043854
# 2698348  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7295 / 8545
# Elapsed time: 3618.9341673851013
# 2698401  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7296 / 8545
# Elapsed time: 3619.459794998169
# 2698454  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7297 / 8545
# Elapsed time: 3620.016330242157
# 2698507  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7298 / 8545
# Elapsed time: 3620.572176218033
# 2698560  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7299 / 8545
# Elapsed time: 3621.1065607070923
# 2698613  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7300 / 8545
# Elapsed time: 3621.6642010211945
# 2698662  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7301 / 8545
# Elapsed time: 3622.204226255417
# 2698711  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7302 / 8545
# Elapsed time: 3622.728661775589
# 2698760  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7303 / 8545
# Elapsed time: 3623.285060405731
# 2698813  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7304 / 8545
# Elapsed time: 3623.81547999382
# 2698866  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7305 / 8545
# Elapsed time: 3624.3694338798523
# 2698917  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7306 / 8545
# Elapsed time: 3624.8962309360504
# 2698966  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7307 / 8545
# Elapsed time: 3625.430851459503
# 2699015  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7308 / 8545
# Elapsed time: 3625.967649936676
# 2699064  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7309 / 8545
# Elapsed time: 3626.505837917328
# 2699117  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7310 / 8545
# Elapsed time: 3627.1026270389557
# 2699169  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7311 / 8545
# Elapsed time: 3627.6387956142426
# 2699218  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7312 / 8545
# Elapsed time: 3628.1585595607758
# 2699267  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7313 / 8545
# Elapsed time: 3628.7667112350464
# 2699316  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7314 / 8545
# Elapsed time: 3629.3280551433563
# 2699365  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7315 / 8545
# Elapsed time: 3629.878912448883
# 2699415  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7316 / 8545
# Elapsed time: 3630.410416841507
# 2699464  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7317 / 8545
# Elapsed time: 3630.9627723693848
# 2699513  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7318 / 8545
# Elapsed time: 3631.5434477329254
# 2699562  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7319 / 8545
# Elapsed time: 3632.166032552719
# 2699611  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7320 / 8545
# Elapsed time: 3632.7618136405945
# 2699664  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7321 / 8545
# Elapsed time: 3633.320921421051
# 2699717  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7322 / 8545
# Elapsed time: 3633.8618111610413
# 2699770  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7323 / 8545
# Elapsed time: 3634.3639998435974
# 2699823  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7324 / 8545
# Elapsed time: 3634.907434940338
# 2699876  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7325 / 8545
# Elapsed time: 3635.445789337158
# 2699929  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7326 / 8545
# Elapsed time: 3636.0032086372375
# 2699982  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7327 / 8545
# Elapsed time: 3636.5301501750946
# 2700035  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7328 / 8545
# Elapsed time: 3637.099004983902
# 2700088  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7329 / 8545
# Elapsed time: 3637.66202378273
# 2700141  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7330 / 8545
# Elapsed time: 3638.2227318286896
# 2700194  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7331 / 8545
# Elapsed time: 3638.802899837494
# 2700247  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7332 / 8545
# Elapsed time: 3639.3092515468597
# 2700300  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7333 / 8545
# Elapsed time: 3639.8216824531555
# 2700353  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7334 / 8545
# Elapsed time: 3640.3411450386047
# 2700406  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7335 / 8545
# Elapsed time: 3640.8956916332245
# 2700882  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7345 / 8545
# Elapsed time: 3641.4544157981873
# 2700931  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7346 / 8545
# Elapsed time: 3642.0298612117767
# 2700980  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7347 / 8545
# Elapsed time: 3642.6281707286835
# 2701029  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7348 / 8545
# Elapsed time: 3643.154397726059
# 2701078  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7349 / 8545
# Elapsed time: 3643.7276360988617
# 2701127  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7350 / 8545
# Elapsed time: 3644.279654979706
# 2701180  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7351 / 8545
# Elapsed time: 3644.8735568523407
# 2701233  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7352 / 8545
# Elapsed time: 3645.4069423675537
# 2701286  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7353 / 8545
# Elapsed time: 3645.9678218364716
# 2701339  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7354 / 8545
# Elapsed time: 3646.5188999176025
# 2701392  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7355 / 8545
# Elapsed time: 3647.08886218071
# 2701445  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7356 / 8545
# Elapsed time: 3647.7165184020996
# 2701498  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7357 / 8545
# Elapsed time: 3648.285847425461
# 2701551  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7358 / 8545
# Elapsed time: 3648.8506360054016
# 2701604  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7359 / 8545
# Elapsed time: 3649.4312357902527
# 2701657  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7360 / 8545
# Elapsed time: 3650.0083327293396
# 2701710  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7361 / 8545
# Elapsed time: 3650.5733597278595
# 2701763  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7362 / 8545
# Elapsed time: 3651.148840904236
# 2701816  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7363 / 8545
# Elapsed time: 3651.7481558322906
# 2701869  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7364 / 8545
# Elapsed time: 3652.3001980781555
# 2701922  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7365 / 8545
# Elapsed time: 3652.8845479488373
# 2701975  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7366 / 8545
# Elapsed time: 3653.4359307289124
# 2702028  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7367 / 8545
# Elapsed time: 3653.97195148468
# 2702081  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7368 / 8545
# Elapsed time: 3654.5182559490204
# 2702134  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7369 / 8545
# Elapsed time: 3655.0730879306793
# 2702183  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7370 / 8545
# Elapsed time: 3655.6177248954773
# 2702236  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7371 / 8545
# Elapsed time: 3656.1511421203613
# 2702289  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7372 / 8545
# Elapsed time: 3656.700752258301
# 2702342  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7373 / 8545
# Elapsed time: 3657.2541749477386
# 2702395  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7374 / 8545
# Elapsed time: 3657.8703689575195
# 2702448  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7375 / 8545
# Elapsed time: 3658.41432595253
# 2702500  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7376 / 8545
# Elapsed time: 3658.971682071686
# 2702547  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7377 / 8545
# Elapsed time: 3659.510271549225
# 2702981  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7386 / 8545
# Elapsed time: 3660.069266796112
# 2703030  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7387 / 8545
# Elapsed time: 3660.5949454307556
# 2703079  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7388 / 8545
# Elapsed time: 3661.1669087409973
# 2703128  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7389 / 8545
# Elapsed time: 3661.7143969535828
# 2703181  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7390 / 8545
# Elapsed time: 3662.2882936000824
# 2703234  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7391 / 8545
# Elapsed time: 3662.866418838501
# 2703287  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7392 / 8545
# Elapsed time: 3663.391712665558
# 2703340  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7393 / 8545
# Elapsed time: 3663.9217658042908
# 2703393  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7394 / 8545
# Elapsed time: 3664.4813561439514
# 2703446  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7395 / 8545
# Elapsed time: 3665.031830072403
# 2703499  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7396 / 8545
# Elapsed time: 3665.5989458560944
# 2703552  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7397 / 8545
# Elapsed time: 3666.147429227829
# 2703605  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7398 / 8545
# Elapsed time: 3666.6989855766296
# 2703658  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7399 / 8545
# Elapsed time: 3667.2599079608917
# 2703711  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7400 / 8545
# Elapsed time: 3667.834120988846
# 2703764  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7401 / 8545
# Elapsed time: 3668.3801708221436
# 2703817  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7402 / 8545
# Elapsed time: 3668.91184425354
# 2703870  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7403 / 8545
# Elapsed time: 3669.4603774547577
# 2703923  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7404 / 8545
# Elapsed time: 3670.032472848892
# 2703976  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7405 / 8545
# Elapsed time: 3670.6085822582245
# 2704029  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7406 / 8545
# Elapsed time: 3671.164246559143
# 2704082  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7407 / 8545
# Elapsed time: 3671.718784093857
# 2704135  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7408 / 8545
# Elapsed time: 3672.2767658233643
# 2704188  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7409 / 8545
# Elapsed time: 3672.8371884822845
# 2704241  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7410 / 8545
# Elapsed time: 3673.3880109786987
# 2704294  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7411 / 8545
# Elapsed time: 3673.9400889873505
# 2704347  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7412 / 8545
# Elapsed time: 3674.499153137207
# 2704400  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7413 / 8545
# Elapsed time: 3675.0301480293274
# 2704453  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7414 / 8545
# Elapsed time: 3675.566980600357
# 2704506  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7415 / 8545
# Elapsed time: 3676.1121575832367
# 2704559  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7416 / 8545
# Elapsed time: 3676.6936786174774
# 2704612  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7417 / 8545
# Elapsed time: 3677.2398924827576
# 2704665  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7418 / 8545
# Elapsed time: 3677.8097891807556
# 2704718  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7419 / 8545
# Elapsed time: 3678.3769636154175
# 2704771  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7420 / 8545
# Elapsed time: 3678.9183418750763
# 2704824  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7421 / 8545
# Elapsed time: 3679.4680292606354
# 2704877  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7422 / 8545
# Elapsed time: 3680.0115208625793
# 2704930  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7423 / 8545
# Elapsed time: 3680.5804047584534
# 2704983  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7424 / 8545
# Elapsed time: 3681.094593524933
# 2705036  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7425 / 8545
# Elapsed time: 3681.633781671524
# 2705089  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7426 / 8545
# Elapsed time: 3682.2049911022186
# 2705138  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7427 / 8545
# Elapsed time: 3682.75337934494
# 2705187  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7428 / 8545
# Elapsed time: 3683.2897095680237
# 2705236  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7429 / 8545
# Elapsed time: 3683.836580514908
# 2705285  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7430 / 8545
# Elapsed time: 3684.3539741039276
# 2705334  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7431 / 8545
# Elapsed time: 3684.863779783249
# 2705387  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7432 / 8545
# Elapsed time: 3685.3749594688416
# 2705440  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7433 / 8545
# Elapsed time: 3685.9080226421356
# 2705493  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7434 / 8545
# Elapsed time: 3686.4575741291046
# 2705546  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7435 / 8545
# Elapsed time: 3686.9839549064636
# 2705599  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7436 / 8545
# Elapsed time: 3687.5312662124634
# 2705652  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7437 / 8545
# Elapsed time: 3688.0968105793
# 2705705  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7438 / 8545
# Elapsed time: 3688.639361858368
# 2705758  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7439 / 8545
# Elapsed time: 3689.172637462616
# 2705811  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7440 / 8545
# Elapsed time: 3689.7289776802063
# 2705864  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7441 / 8545
# Elapsed time: 3690.2659006118774
# 2705912  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7442 / 8545
# Elapsed time: 3690.8246462345123
# 2705965  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7443 / 8545
# Elapsed time: 3691.366640329361
# 2706014  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7444 / 8545
# Elapsed time: 3691.8933067321777
# 2706063  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7445 / 8545
# Elapsed time: 3692.4445044994354
# 2706116  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7446 / 8545
# Elapsed time: 3693.0325582027435
# 2706169  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7447 / 8545
# Elapsed time: 3693.625172138214
# 2706222  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7448 / 8545
# Elapsed time: 3694.199274301529
# 2706275  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7449 / 8545
# Elapsed time: 3694.7208807468414
# 2706328  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7450 / 8545
# Elapsed time: 3695.2961428165436
# 2706381  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7451 / 8545
# Elapsed time: 3695.8527512550354
# 2706434  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7452 / 8545
# Elapsed time: 3696.394764184952
# 2706487  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7453 / 8545
# Elapsed time: 3696.955155849457
# 2706540  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7454 / 8545
# Elapsed time: 3697.502624988556
# 2706594  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7455 / 8545
# Elapsed time: 3698.0766348838806
# 2706643  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7456 / 8545
# Elapsed time: 3698.6171975135803
# 2706692  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7457 / 8545
# Elapsed time: 3699.150195121765
# 2706745  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7458 / 8545
# Elapsed time: 3699.6977183818817
# 2706798  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7459 / 8545
# Elapsed time: 3700.2433943748474
# 2706851  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7460 / 8545
# Elapsed time: 3700.7794914245605
# 2706904  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7461 / 8545
# Elapsed time: 3701.340662956238
# 2706957  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7462 / 8545
# Elapsed time: 3701.888880252838
# 2707010  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7463 / 8545
# Elapsed time: 3702.46076464653
# 2707063  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7464 / 8545
# Elapsed time: 3703.0572686195374
# 2707116  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7465 / 8545
# Elapsed time: 3703.626192331314
# 2707169  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7466 / 8545
# Elapsed time: 3704.1998240947723
# 2707222  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7467 / 8545
# Elapsed time: 3704.7497551441193
# 2707275  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7468 / 8545
# Elapsed time: 3705.2678306102753
# 2707328  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7469 / 8545
# Elapsed time: 3705.8049187660217
# 2707381  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7470 / 8545
# Elapsed time: 3706.3452422618866
# 2707434  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7471 / 8545
# Elapsed time: 3706.9062752723694
# 2707487  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7472 / 8545
# Elapsed time: 3707.4370470046997
# 2707540  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7473 / 8545
# Elapsed time: 3707.948397397995
# 2707593  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7474 / 8545
# Elapsed time: 3708.551213979721
# 2707646  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7475 / 8545
# Elapsed time: 3709.12193441391
# 2707699  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7476 / 8545
# Elapsed time: 3709.680566549301
# 2707752  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7477 / 8545
# Elapsed time: 3710.2095606327057
# 2708235  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7487 / 8545
# Elapsed time: 3710.7447748184204
# 2708284  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7488 / 8545
# Elapsed time: 3711.3177495002747
# 2708333  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7489 / 8545
# Elapsed time: 3711.8891355991364
# 2708382  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7490 / 8545
# Elapsed time: 3712.4646441936493
# 2708431  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7491 / 8545
# Elapsed time: 3713.096108675003
# 2708484  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7492 / 8545
# Elapsed time: 3713.6813213825226
# 2708537  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7493 / 8545
# Elapsed time: 3714.2984199523926
# 2708590  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7494 / 8545
# Elapsed time: 3714.856307029724
# 2708643  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7495 / 8545
# Elapsed time: 3715.4453296661377
# 2708690  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7496 / 8545
# Elapsed time: 3716.0819363594055
# 2708743  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7497 / 8545
# Elapsed time: 3716.6235449314117
# 2708796  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7498 / 8545
# Elapsed time: 3717.21856713295
# 2708849  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7499 / 8545
# Elapsed time: 3717.793061733246
# 2708902  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7500 / 8545
# Elapsed time: 3718.3998034000397
# 2708955  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7501 / 8545
# Elapsed time: 3718.9959094524384
# 2709008  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7502 / 8545
# Elapsed time: 3719.587062597275
# 2709061  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7503 / 8545
# Elapsed time: 3720.174019575119
# 2709114  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7504 / 8545
# Elapsed time: 3720.7804765701294
# 2709167  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7505 / 8545
# Elapsed time: 3721.3839268684387
# 2709220  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7506 / 8545
# Elapsed time: 3721.954526424408
# 2709273  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7507 / 8545
# Elapsed time: 3722.500879049301
# 2709326  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7508 / 8545
# Elapsed time: 3723.0527696609497
# 2709379  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7509 / 8545
# Elapsed time: 3723.613914489746
# 2709432  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7510 / 8545
# Elapsed time: 3724.209720849991
# 2709485  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7511 / 8545
# Elapsed time: 3724.7681431770325
# 2709538  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7512 / 8545
# Elapsed time: 3725.3257892131805
# 2709591  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7513 / 8545
# Elapsed time: 3725.877484560013
# 2709640  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7514 / 8545
# Elapsed time: 3726.4409353733063
# 2709689  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7515 / 8545
# Elapsed time: 3726.992855787277
# 2709738  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7516 / 8545
# Elapsed time: 3727.570958137512
# 2709792  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7517 / 8545
# Elapsed time: 3728.1266520023346
# 2709841  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7518 / 8545
# Elapsed time: 3728.698103427887
# 2709894  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7519 / 8545
# Elapsed time: 3729.2373690605164
# 2709944  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7520 / 8545
# Elapsed time: 3729.7564685344696
# 2709993  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7521 / 8545
# Elapsed time: 3730.2644288539886
# 2710042  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7522 / 8545
# Elapsed time: 3730.8058500289917
# 2710091  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7523 / 8545
# Elapsed time: 3731.3613317012787
# 2710140  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7524 / 8545
# Elapsed time: 3731.9031414985657
# 2710189  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7525 / 8545
# Elapsed time: 3732.4617109298706
# 2710242  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7526 / 8545
# Elapsed time: 3732.989769935608
# 2710295  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7527 / 8545
# Elapsed time: 3733.6045722961426
# 2710348  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7528 / 8545
# Elapsed time: 3734.1651577949524
# 2710401  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7529 / 8545
# Elapsed time: 3734.7084674835205
# 2710454  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7530 / 8545
# Elapsed time: 3735.2443532943726
# 2710507  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7531 / 8545
# Elapsed time: 3735.8219361305237
# 2710560  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7532 / 8545
# Elapsed time: 3736.390379667282
# 2710613  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7533 / 8545
# Elapsed time: 3736.939105272293
# 2710663  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7534 / 8545
# Elapsed time: 3737.5122487545013
# 2710712  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7535 / 8545
# Elapsed time: 3738.0872008800507
# 2710761  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7536 / 8545
# Elapsed time: 3738.6456575393677
# 2710810  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7537 / 8545
# Elapsed time: 3739.185786008835
# 2710859  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7538 / 8545
# Elapsed time: 3739.7760050296783
# 2710908  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7539 / 8545
# Elapsed time: 3740.3353431224823
# 2710961  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7540 / 8545
# Elapsed time: 3740.9016814231873
# 2711014  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7541 / 8545
# Elapsed time: 3741.4294860363007
# 2711067  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 7542 / 8545
# ...
#
# 8406 / 8545
# Elapsed time: 4179.343495845795
# 2755814  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8407 / 8545
# Elapsed time: 4179.9683747291565
# 2755867  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8408 / 8545
# Elapsed time: 4180.543539762497
# 2755920  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8409 / 8545
# Elapsed time: 4181.106494903564
# 2755973  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8410 / 8545
# Elapsed time: 4181.674928188324
# 2756026  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8411 / 8545
# Elapsed time: 4182.2268080711365
# 2756079  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8412 / 8545
# Elapsed time: 4182.831682443619
# 2756132  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8413 / 8545
# Elapsed time: 4183.415679693222
# 2756185  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8414 / 8545
# Elapsed time: 4183.970477342606
# 2756235  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8415 / 8545
# Elapsed time: 4184.496706485748
# 2756284  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8416 / 8545
# Elapsed time: 4185.055938482285
# 2756333  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8417 / 8545
# Elapsed time: 4185.572263240814
# 2756809  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8427 / 8545
# Elapsed time: 4186.1113340854645
# 2756858  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8428 / 8545
# Elapsed time: 4186.668829917908
# 2756907  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8429 / 8545
# Elapsed time: 4187.217356443405
# 2756956  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8430 / 8545
# Elapsed time: 4187.792647361755
# 2757005  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8431 / 8545
# Elapsed time: 4188.352332830429
# 2757054  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8432 / 8545
# Elapsed time: 4188.923936367035
# 2757103  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8433 / 8545
# Elapsed time: 4189.465436697006
# 2757156  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8434 / 8545
# Elapsed time: 4190.041117191315
# 2757209  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8435 / 8545
# Elapsed time: 4190.665745973587
# 2757262  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8436 / 8545
# Elapsed time: 4191.242868423462
# 2757311  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8437 / 8545
# Elapsed time: 4191.7914180755615
# 2757360  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8438 / 8545
# Elapsed time: 4192.332556247711
# 2757409  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8439 / 8545
# Elapsed time: 4192.87082362175
# 2757458  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8440 / 8545
# Elapsed time: 4193.403172969818
# 2757511  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8441 / 8545
# Elapsed time: 4193.967331171036
# 2757564  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8442 / 8545
# Elapsed time: 4194.503188610077
# 2757617  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8443 / 8545
# Elapsed time: 4195.096125841141
# 2757666  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8444 / 8545
# Elapsed time: 4195.665733098984
# 2757721  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8445 / 8545
# Elapsed time: 4196.219981431961
# 2757770  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8446 / 8545
# Elapsed time: 4196.8015377521515
# 2757821  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8447 / 8545
# Elapsed time: 4197.3498022556305
# 2757870  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8448 / 8545
# Elapsed time: 4197.904150485992
# 2757919  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8449 / 8545
# Elapsed time: 4198.437019109726
# 2757968  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8450 / 8545
# Elapsed time: 4198.955382347107
# 2758021  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8451 / 8545
# Elapsed time: 4199.535719633102
# 2758074  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8452 / 8545
# Elapsed time: 4200.148164987564
# 2758127  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8453 / 8545
# Elapsed time: 4200.733539819717
# 2758180  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8454 / 8545
# Elapsed time: 4201.2859308719635
# 2758233  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8455 / 8545
# Elapsed time: 4201.839547872543
# 2758286  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8456 / 8545
# Elapsed time: 4202.385824680328
# 2758339  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8457 / 8545
# Elapsed time: 4202.975110769272
# 2758392  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8458 / 8545
# Elapsed time: 4203.517366409302
# 2758445  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8459 / 8545
# Elapsed time: 4204.0742399692535
# 2758498  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8460 / 8545
# Elapsed time: 4204.636260986328
# 2758551  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8461 / 8545
# Elapsed time: 4205.202937602997
# 2758606  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8462 / 8545
# Elapsed time: 4205.782691240311
# 2758655  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8463 / 8545
# Elapsed time: 4206.338996648788
# 2758708  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8464 / 8545
# Elapsed time: 4206.882204532623
# 2758761  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8465 / 8545
# Elapsed time: 4207.432479381561
# 2758814  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8466 / 8545
# Elapsed time: 4207.955392360687
# 2758867  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8467 / 8545
# Elapsed time: 4208.528861284256
# 2758920  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8468 / 8545
# Elapsed time: 4209.063165187836
# 2758973  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8469 / 8545
# Elapsed time: 4209.649552822113
# 2759026  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8470 / 8545
# Elapsed time: 4210.227262973785
# 2759079  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8471 / 8545
# Elapsed time: 4210.80717587471
# 2759132  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8472 / 8545
# Elapsed time: 4211.363252162933
# 2759185  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8473 / 8545
# Elapsed time: 4211.927620410919
# 2759238  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8474 / 8545
# Elapsed time: 4212.509521007538
# 2759291  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8475 / 8545
# Elapsed time: 4213.051938533783
# 2759344  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8476 / 8545
# Elapsed time: 4213.588292360306
# 2759397  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8477 / 8545
# Elapsed time: 4214.13166809082
# 2759450  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8478 / 8545
# Elapsed time: 4214.647688627243
# 2759503  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8479 / 8545
# Elapsed time: 4215.167702436447
# 2759557  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8480 / 8545
# Elapsed time: 4215.737389326096
# 2759606  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8481 / 8545
# Elapsed time: 4216.307389259338
# 2759655  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8482 / 8545
# Elapsed time: 4216.856524944305
# 2759706  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8483 / 8545
# Elapsed time: 4217.396010160446
# 2759755  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8484 / 8545
# Elapsed time: 4217.911430835724
# 2759804  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8485 / 8545
# Elapsed time: 4218.485846757889
# 2759853  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8486 / 8545
# Elapsed time: 4219.0959413051605
# 2759902  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8487 / 8545
# Elapsed time: 4219.689066648483
# 2759955  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8488 / 8545
# Elapsed time: 4220.270701885223
# 2760008  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8489 / 8545
# Elapsed time: 4220.8329641819
# 2760061  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8490 / 8545
# Elapsed time: 4221.3798151016235
# 2760114  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8491 / 8545
# Elapsed time: 4221.9523911476135
# 2760167  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8492 / 8545
# Elapsed time: 4222.498372554779
# 2760220  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8493 / 8545
# Elapsed time: 4223.053470134735
# 2760273  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8494 / 8545
# Elapsed time: 4223.606336355209
# 2760756  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8504 / 8545
# Elapsed time: 4224.170747995377
# 2760805  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8505 / 8545
# Elapsed time: 4224.710980892181
# 2760854  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8506 / 8545
# Elapsed time: 4225.271687030792
# 2760903  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8507 / 8545
# Elapsed time: 4225.847779750824
# 2760952  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8508 / 8545
# Elapsed time: 4226.375522136688
# 2761005  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8509 / 8545
# Elapsed time: 4226.950719356537
# 2761058  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8510 / 8545
# Elapsed time: 4227.514464378357
# 2761111  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8511 / 8545
# Elapsed time: 4228.07180762291
# 2761164  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8512 / 8545
# Elapsed time: 4228.5911984443665
# 2761217  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8513 / 8545
# Elapsed time: 4229.1936378479
# 2761270  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8514 / 8545
# Elapsed time: 4229.778715848923
# 2761323  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8515 / 8545
# Elapsed time: 4230.303999423981
# 2761376  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8516 / 8545
# Elapsed time: 4230.858119249344
# 2761429  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8517 / 8545
# Elapsed time: 4231.41480922699
# 2761482  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8518 / 8545
# Elapsed time: 4231.955101966858
# 2761535  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8519 / 8545
# Elapsed time: 4232.512246131897
# 2761588  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8520 / 8545
# Elapsed time: 4233.060674667358
# 2761641  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8521 / 8545
# Elapsed time: 4233.626120090485
# 2761694  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8522 / 8545
# Elapsed time: 4234.182536840439
# 2761747  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8523 / 8545
# Elapsed time: 4234.75919175148
# 2761800  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8524 / 8545
# Elapsed time: 4235.3078145980835
# 2761853  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8525 / 8545
# Elapsed time: 4235.891174793243
# 2761906  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8526 / 8545
# Elapsed time: 4236.430096387863
# 2761959  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8527 / 8545
# Elapsed time: 4236.997198343277
# 2762012  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8528 / 8545
# Elapsed time: 4237.539372444153
# 2762065  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8529 / 8545
# Elapsed time: 4238.054526567459
# 2762118  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8530 / 8545
# Elapsed time: 4238.604369878769
# 2762171  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8531 / 8545
# Elapsed time: 4239.150721788406
# 2762224  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8532 / 8545
# Elapsed time: 4239.700189590454
# 2762277  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8533 / 8545
# Elapsed time: 4240.256388187408
# 2762330  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8534 / 8545
# Elapsed time: 4240.864537000656
# 2762383  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8535 / 8545
# Elapsed time: 4241.448890209198
# 2762436  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8536 / 8545
# Elapsed time: 4242.021372795105
# 2762485  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8537 / 8545
# Elapsed time: 4242.556267261505
# 2762534  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8538 / 8545
# Elapsed time: 4243.117663860321
# 2762583  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8539 / 8545
# Elapsed time: 4243.664928197861
# 2762637  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8540 / 8545
# Elapsed time: 4244.181753873825
# 2762686  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8541 / 8545
# Elapsed time: 4244.774755477905
# 2762735  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8542 / 8545
# Elapsed time: 4245.322905540466
# 2762784  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8543 / 8545
# Elapsed time: 4245.86925983429
# 2762833  THE TIME ON ALL IIE OUTPUT FILES REFER TO THE DEFAULT REFERENCE TIME 2430000.5
#
# 8544 / 8545

# %%
model_choose = 'MSIS86'
import pickle


with open(msis86_path +'all_sat_resids' + model_choose, 'wb') as pickle_file:
  pickle.dump(dict_sat, pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# dict_sat 

# with open('filename.pickle', 'rb') as handle:
#     b = pickle.load(handle)

# print a == b
