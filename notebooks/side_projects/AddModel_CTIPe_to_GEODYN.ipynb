# %%
# %load_ext autoreload
# %autoreload 2

import sys  
import pickle 
import gc

sys.path.insert(0, '/data/geodyn_proj/pygeodyn/pygeodyn_develop/')
from PYGEODYN import Pygeodyn

for i,val in enumerate(['ctipe_oc']):   
            
        run_settings = '/data/zach_work/side_projects/runsettings_ctipe.yaml'
        ### Load the data into an object
        RunObject = Pygeodyn(run_settings)
        RunObject.RUN_GEODYN()
        RunObject = 0
        gc.collect()
# sys.exit()
# Out:
# Run # 1     Current Time =      09:11:08  GMT-7
# Run # 1
# +=======================================================================
# |     Running GEODYN with Orbit Cloud Method
# |
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018313.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018313.01_24hr.msis2.bwdrag
# |     Constructing the OrbitCloud file:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018313.01.csv
# |          - icesat2_2018313.01_24hr.msis2.bwdrag
# |          - time 1: 0.00016828486695885658
# /data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/spacepy/time.py:2294: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
# |     Running data cube thru Kamodo... please hold.
# input_alt: 482.623 | converted alt: 489.2731952576173
#                   conversion is off by  6.650195257617327 km
# 77067 requested coordinates are out of range.
# 77067 requested coordinates are out of range.
# dict_keys(['utc_time', 'c1', 'c2', 'c3', 'net_idx', 'rho', 'T', 'N_O', 'N_O2', 'N_N2', 'max_height'])
# |     Kamodo Total Run Time: 209.61044430732727 seconds
# |     Kamodo Total Run Time: 3.4935074051221213 minutes
# |     Save OrbitCloud file run rime: 210.76653170585632 seconds
# |     Save OrbitCloud file run rime: 3.5127755284309385 minutes
# |          - time 2: 211.78472330002114
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018314.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018314.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018314.01.csv
# |          - icesat2_2018314.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018315.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018315.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018315.01.csv
# |          - icesat2_2018315.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018316.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018316.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018316.01.csv
# |          - icesat2_2018316.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018317.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018317.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018317.01.csv
# |          - icesat2_2018317.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018318.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018318.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018318.01.csv
# |          - icesat2_2018318.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018319.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018319.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018319.01.csv
# |          - icesat2_2018319.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018320.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018320.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018320.01.csv
# |          - icesat2_2018320.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018321.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018321.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018321.01.csv
# |          - icesat2_2018321.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018322.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018322.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018322.01.csv
# |          - icesat2_2018322.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018323.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018323.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018323.01.csv
# |          - icesat2_2018323.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018324.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018324.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018324.01.csv
# |          - icesat2_2018324.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018325.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018325.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018325.01.csv
# |          - icesat2_2018325.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018326.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018326.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018326.01.csv
# |          - icesat2_2018326.01_24hr.msis2.bwdrag
# msis2_file_path /data/zach_work/output_from_runs/msis2/msis2_BWDRAG/DENSITY/icesat2_2018327.01_24hr.msis2.bwdrag_msisin
# |     MSIS2 Density file already exists.
# |          - icesat2_2018327.01_24hr.msis2.bwdrag
# |     Already have OrbitCloud file for this arc:
# |          -/data/data_geodyn/atmos_models_data/ctipe/icesat2_oct2018_jan2019/OrbitCloud_Step10_2018327.01.csv
# |          - icesat2_2018327.01_24hr.msis2.bwdrag
# |     Running GEODYN with orbit cloud
# Run # 1     Current Time =      09:15:19  GMT-7
# Run # 1
# + ——————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 1     IISSET Cleaned      tmp/.../cleaned_setup_2018313.01
# |  Run # 1     Density Model:      ctipe_oc
# |  Run # 1     GEODYN Version:     CD_model_proj
# |  Run # 1     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 1     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.313.gz
# |
# |  Run # 1     Epoch Start:  2018-11-09 00:00:00
# |  Run # 1     Epoch End:    2018-11-10 00:00:00
# |  Run # 1     Step Size:    10.0
# |
# |  Run # 1     ARC run:      icesat2_2018313.01_24hr.ctipe_oc.bwdrag
# + ——————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 1          Running IIS
# Run # 1          No errors in IIS
# Run # 1 ---------End of IIS
#
# Run # 1          Running IIE
# Run # 1          Current Time = 09:16:21 GMT-7
# Run # 1          No errors in IIE
# Run # 1 ---------End of IIE
# Run # 1          Time of IIE:  399.138708114624 secs ( 6.6523118019104  mins)
# Run # 1          Current Time = 16:23:00
# Run # 1                Finished renaming files
# Run # 1                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 2     Current Time =      09:23:04  GMT-7
# Run # 2
# + ——————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 2     IISSET Cleaned      tmp/.../cleaned_setup_2018314.01
# |  Run # 2     Density Model:      ctipe_oc
# |  Run # 2     GEODYN Version:     CD_model_proj
# |  Run # 2     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 2     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.314.gz
# |
# |  Run # 2     Epoch Start:  2018-11-10 00:00:00
# |  Run # 2     Epoch End:    2018-11-11 00:00:00
# |  Run # 2     Step Size:    10.0
# |
# |  Run # 2     ARC run:      icesat2_2018314.01_24hr.ctipe_oc.bwdrag
# + ——————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 2          Running IIS
# Run # 2          No errors in IIS
# Run # 2 ---------End of IIS
#
# Run # 2          Running IIE
# Run # 2          Current Time = 09:24:04 GMT-7
# Run # 2          No errors in IIE
# Run # 2 ---------End of IIE
# Run # 2          Time of IIE:  287.5145523548126 secs ( 4.7919092059135435  mins)
# Run # 2          Current Time = 16:28:52
# Run # 2                Finished renaming files
# Run # 2                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 3     Current Time =      09:28:56  GMT-7
# Run # 3
# + ——————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 3     IISSET Cleaned      tmp/.../cleaned_setup_2018315.01
# |  Run # 3     Density Model:      ctipe_oc
# |  Run # 3     GEODYN Version:     CD_model_proj
# |  Run # 3     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 3     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.315.gz
# |
# |  Run # 3     Epoch Start:  2018-11-11 00:00:00
# |  Run # 3     Epoch End:    2018-11-12 00:00:00
# |  Run # 3     Step Size:    10.0
# |
# |  Run # 3     ARC run:      icesat2_2018315.01_24hr.ctipe_oc.bwdrag
# + ——————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 3          Running IIS
# Run # 3          No errors in IIS
# Run # 3 ---------End of IIS
#
# Run # 3          Running IIE
# Run # 3          Current Time = 09:29:57 GMT-7
# Run # 3          No errors in IIE
# Run # 3 ---------End of IIE
# Run # 3          Time of IIE:  345.08941984176636 secs ( 5.751490330696106  mins)
# Run # 3          Current Time = 16:35:43
# Run # 3                Finished renaming files
# Run # 3                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 4     Current Time =      09:35:46  GMT-7
# Run # 4
# + ——————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 4     IISSET Cleaned      tmp/.../cleaned_setup_2018316.01
# |  Run # 4     Density Model:      ctipe_oc
# |  Run # 4     GEODYN Version:     CD_model_proj
# |  Run # 4     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 4     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.316.gz
# |
# |  Run # 4     Epoch Start:  2018-11-12 00:00:00
# |  Run # 4     Epoch End:    2018-11-13 00:00:00
# |  Run # 4     Step Size:    10.0
# |
# |  Run # 4     ARC run:      icesat2_2018316.01_24hr.ctipe_oc.bwdrag
# + ——————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 4          Running IIS
# Run # 4          No errors in IIS
# Run # 4 ---------End of IIS
#
# Run # 4          Running IIE
# Run # 4          Current Time = 09:36:49 GMT-7
# Run # 4          No errors in IIE
# Run # 4 ---------End of IIE
# Run # 4          Time of IIE:  343.10704588890076 secs ( 5.718450764815013  mins)
# Run # 4          Current Time = 16:42:32
# Run # 4                Finished renaming files
# Run # 4                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 5     Current Time =      09:42:36  GMT-7
# Run # 5
# + ——————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 5     IISSET Cleaned      tmp/.../cleaned_setup_2018317.01
# |  Run # 5     Density Model:      ctipe_oc
# |  Run # 5     GEODYN Version:     CD_model_proj
# |  Run # 5     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 5     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.317.gz
# |
# |  Run # 5     Epoch Start:  2018-11-13 00:00:00
# |  Run # 5     Epoch End:    2018-11-14 00:00:00
# |  Run # 5     Step Size:    10.0
# |
# |  Run # 5     ARC run:      icesat2_2018317.01_24hr.ctipe_oc.bwdrag
# + ——————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 5          Running IIS
# Run # 5          No errors in IIS
# Run # 5 ---------End of IIS
#
# Run # 5          Running IIE
# Run # 5          Current Time = 09:43:38 GMT-7
# Run # 5          No errors in IIE
# Run # 5 ---------End of IIE
# Run # 5          Time of IIE:  341.97535729408264 secs ( 5.69958928823471  mins)
# Run # 5          Current Time = 16:49:20
# Run # 5                Finished renaming files
# Run # 5                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 6     Current Time =      09:49:24  GMT-7
# Run # 6
# + ——————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 6     IISSET Cleaned      tmp/.../cleaned_setup_2018318.01
# |  Run # 6     Density Model:      ctipe_oc
# |  Run # 6     GEODYN Version:     CD_model_proj
# |  Run # 6     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 6     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.318.gz
# |
# |  Run # 6     Epoch Start:  2018-11-14 00:00:00
# |  Run # 6     Epoch End:    2018-11-15 00:00:00
# |  Run # 6     Step Size:    10.0
# |
# |  Run # 6     ARC run:      icesat2_2018318.01_24hr.ctipe_oc.bwdrag
# + ——————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 6          Running IIS
# Run # 6          No errors in IIS
# Run # 6 ---------End of IIS
#
# Run # 6          Running IIE
# Run # 6          Current Time = 09:50:28 GMT-7
# Run # 6          No errors in IIE
# Run # 6 ---------End of IIE
# Run # 6          Time of IIE:  284.71392583847046 secs ( 4.745232097307841  mins)
# Run # 6          Current Time = 16:55:13
# Run # 6                Finished renaming files
# Run # 6                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 7     Current Time =      09:55:17  GMT-7
# Run # 7
# + ——————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 7     IISSET Cleaned      tmp/.../cleaned_setup_2018319.01
# |  Run # 7     Density Model:      ctipe_oc
# |  Run # 7     GEODYN Version:     CD_model_proj
# |  Run # 7     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 7     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.319.gz
# |
# |  Run # 7     Epoch Start:  2018-11-15 00:00:00
# |  Run # 7     Epoch End:    2018-11-16 00:00:00
# |  Run # 7     Step Size:    10.0
# |
# |  Run # 7     ARC run:      icesat2_2018319.01_24hr.ctipe_oc.bwdrag
# + ——————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 7          Running IIS
# Run # 7          No errors in IIS
# Run # 7 ---------End of IIS
#
# Run # 7          Running IIE
# Run # 7          Current Time = 09:56:25 GMT-7
# Run # 7          No errors in IIE
# Run # 7 ---------End of IIE
# Run # 7          Time of IIE:  345.59980630874634 secs ( 5.759996771812439  mins)
# Run # 7          Current Time = 17:02:11
# Run # 7                Finished renaming files
# Run # 7                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 8     Current Time =      10:02:15  GMT-7
# Run # 8
# + ——————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 8     IISSET Cleaned      tmp/.../cleaned_setup_2018320.01
# |  Run # 8     Density Model:      ctipe_oc
# |  Run # 8     GEODYN Version:     CD_model_proj
# |  Run # 8     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 8     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.320.gz
# |
# |  Run # 8     Epoch Start:  2018-11-16 00:00:00
# |  Run # 8     Epoch End:    2018-11-17 00:00:00
# |  Run # 8     Step Size:    10.0
# |
# |  Run # 8     ARC run:      icesat2_2018320.01_24hr.ctipe_oc.bwdrag
# + ——————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 8          Running IIS
# Run # 8          No errors in IIS
# Run # 8 ---------End of IIS
#
# Run # 8          Running IIE
# Run # 8          Current Time = 10:03:21 GMT-7
# Run # 8          No errors in IIE
# Run # 8 ---------End of IIE
# Run # 8          Time of IIE:  396.2389874458313 secs ( 6.603983124097188  mins)
# Run # 8          Current Time = 17:09:57
# Run # 8                Finished renaming files
# Run # 8                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 9     Current Time =      10:10:01  GMT-7
# Run # 9
# + ——————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 9     IISSET Cleaned      tmp/.../cleaned_setup_2018321.01
# |  Run # 9     Density Model:      ctipe_oc
# |  Run # 9     GEODYN Version:     CD_model_proj
# |  Run # 9     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 9     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.321.gz
# |
# |  Run # 9     Epoch Start:  2018-11-17 00:00:00
# |  Run # 9     Epoch End:    2018-11-18 00:00:00
# |  Run # 9     Step Size:    10.0
# |
# |  Run # 9     ARC run:      icesat2_2018321.01_24hr.ctipe_oc.bwdrag
# + ——————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 9          Running IIS
# Run # 9          No errors in IIS
# Run # 9 ---------End of IIS
#
# Run # 9          Running IIE
# Run # 9          Current Time = 10:11:09 GMT-7
# Run # 9          No errors in IIE
# Run # 9 ---------End of IIE
# Run # 9          Time of IIE:  342.2543623447418 secs ( 5.7042393724123635  mins)
# Run # 9          Current Time = 17:16:52
# Run # 9                Finished renaming files
# Run # 9                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 10     Current Time =      10:16:56  GMT-7
# Run # 10
# + ———————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 10     IISSET Cleaned      tmp/.../cleaned_setup_2018322.01
# |  Run # 10     Density Model:      ctipe_oc
# |  Run # 10     GEODYN Version:     CD_model_proj
# |  Run # 10     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 10     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.322.gz
# |
# |  Run # 10     Epoch Start:  2018-11-18 00:00:00
# |  Run # 10     Epoch End:    2018-11-19 00:00:00
# |  Run # 10     Step Size:    10.0
# |
# |  Run # 10     ARC run:      icesat2_2018322.01_24hr.ctipe_oc.bwdrag
# + ———————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 10          Running IIS
# Run # 10          No errors in IIS
# Run # 10 ---------End of IIS
#
# Run # 10          Running IIE
# Run # 10          Current Time = 10:18:04 GMT-7
# Run # 10          No errors in IIE
# Run # 10 ---------End of IIE
# Run # 10          Time of IIE:  343.07939434051514 secs ( 5.717989905675252  mins)
# Run # 10          Current Time = 17:23:47
# Run # 10                Finished renaming files
# Run # 10                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 11     Current Time =      10:23:51  GMT-7
# Run # 11
# + ———————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 11     IISSET Cleaned      tmp/.../cleaned_setup_2018323.01
# |  Run # 11     Density Model:      ctipe_oc
# |  Run # 11     GEODYN Version:     CD_model_proj
# |  Run # 11     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 11     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.323.gz
# |
# |  Run # 11     Epoch Start:  2018-11-19 00:00:00
# |  Run # 11     Epoch End:    2018-11-20 00:00:00
# |  Run # 11     Step Size:    10.0
# |
# |  Run # 11     ARC run:      icesat2_2018323.01_24hr.ctipe_oc.bwdrag
# + ———————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 11          Running IIS
# Run # 11          No errors in IIS
# Run # 11 ---------End of IIS
#
# Run # 11          Running IIE
# Run # 11          Current Time = 10:25:00 GMT-7
# Run # 11          No errors in IIE
# Run # 11 ---------End of IIE
# Run # 11          Time of IIE:  340.788556098938 secs ( 5.679809268315633  mins)
# Run # 11          Current Time = 17:30:41
# Run # 11                Finished renaming files
# Run # 11                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 12     Current Time =      10:30:45  GMT-7
# Run # 12
# + ———————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 12     IISSET Cleaned      tmp/.../cleaned_setup_2018324.01
# |  Run # 12     Density Model:      ctipe_oc
# |  Run # 12     GEODYN Version:     CD_model_proj
# |  Run # 12     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 12     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.324.gz
# |
# |  Run # 12     Epoch Start:  2018-11-20 00:00:00
# |  Run # 12     Epoch End:    2018-11-21 00:00:00
# |  Run # 12     Step Size:    10.0
# |
# |  Run # 12     ARC run:      icesat2_2018324.01_24hr.ctipe_oc.bwdrag
# + ———————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 12          Running IIS
# Run # 12          No errors in IIS
# Run # 12 ---------End of IIS
#
# Run # 12          Running IIE
# Run # 12          Current Time = 10:31:55 GMT-7
# Run # 12          No errors in IIE
# Run # 12 ---------End of IIE
# Run # 12          Time of IIE:  340.51987767219543 secs ( 5.675331294536591  mins)
# Run # 12          Current Time = 17:37:36
# Run # 12                Finished renaming files
# Run # 12                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 13     Current Time =      10:37:40  GMT-7
# Run # 13
# + ———————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 13     IISSET Cleaned      tmp/.../cleaned_setup_2018325.01
# |  Run # 13     Density Model:      ctipe_oc
# |  Run # 13     GEODYN Version:     CD_model_proj
# |  Run # 13     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 13     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.325.gz
# |
# |  Run # 13     Epoch Start:  2018-11-21 00:00:00
# |  Run # 13     Epoch End:    2018-11-22 00:00:00
# |  Run # 13     Step Size:    10.0
# |
# |  Run # 13     ARC run:      icesat2_2018325.01_24hr.ctipe_oc.bwdrag
# + ———————————————————————————————————————————————————————————————————————————————————————————————
# Run # 13          Running IIS
# Run # 13          No errors in IIS
# Run # 13 ---------End of IIS
#
# Run # 13          Running IIE
# Run # 13          Current Time = 10:38:50 GMT-7
# Run # 13          No errors in IIE
# Run # 13 ---------End of IIE
# Run # 13          Time of IIE:  285.03733086586 secs ( 4.7506221810976665  mins)
# Run # 13          Current Time = 17:43:36
# Run # 13                Finished renaming files
# Run # 13                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 14     Current Time =      10:43:40  GMT-7
# Run # 14
# + ———————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 14     IISSET Cleaned      tmp/.../cleaned_setup_2018326.01
# |  Run # 14     Density Model:      ctipe_oc
# |  Run # 14     GEODYN Version:     CD_model_proj
# |  Run # 14     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 14     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.326.gz
# |
# |  Run # 14     Epoch Start:  2018-11-22 00:00:00
# |  Run # 14     Epoch End:    2018-11-23 00:00:00
# |  Run # 14     Step Size:    10.0
# |
# |  Run # 14     ARC run:      icesat2_2018326.01_24hr.ctipe_oc.bwdrag
# + ———————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 14          Running IIS
# Run # 14          No errors in IIS
# Run # 14 ---------End of IIS
#
# Run # 14          Running IIE
# Run # 14          Current Time = 10:44:51 GMT-7
# Run # 14          No errors in IIE
# Run # 14 ---------End of IIE
# Run # 14          Time of IIE:  288.6747741699219 secs ( 4.811246236165364  mins)
# Run # 14          Current Time = 17:49:39
# Run # 14                Finished renaming files
# Run # 14                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
# |     Running GEODYN with orbit cloud
# Run # 15     Current Time =      10:49:44  GMT-7
# Run # 15
# + ———————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- RUN PARAMETERS  ----------------------
# |
# |  Run # 15     IISSET Cleaned      tmp/.../cleaned_setup_2018327.01
# |  Run # 15     Density Model:      ctipe_oc
# |  Run # 15     GEODYN Version:     CD_model_proj
# |  Run # 15     Output directory:   /data/zach_work/output_from_runs/ctipe_oc/ctipe_oc_BWDRAG
# |  Run # 15     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.327.gz
# |
# |  Run # 15     Epoch Start:  2018-11-23 00:00:00
# |  Run # 15     Epoch End:    2018-11-24 00:00:00
# |  Run # 15     Step Size:    10.0
# |
# |  Run # 15     ARC run:      icesat2_2018327.01_24hr.ctipe_oc.bwdrag
# + ———————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 15          Running IIS
# Run # 15          No errors in IIS
# Run # 15 ---------End of IIS
#
# Run # 15          Running IIE
# Run # 15          Current Time = 10:50:55 GMT-7
# Run # 15          No errors in IIE
# Run # 15 ---------End of IIE
# Run # 15          Time of IIE:  340.87907695770264 secs ( 5.681317949295044  mins)
# Run # 15          Current Time = 17:56:36
# Run # 15                Finished renaming files
# Run # 15                Finished copying files to outputdir
#         Deleting tmp/:  ctipe_oc_BWDRAG
