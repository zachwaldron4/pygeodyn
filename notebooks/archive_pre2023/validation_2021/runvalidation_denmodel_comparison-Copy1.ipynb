# %% [markdown]
# # Compare Runs of GEODYN with diff Density Models
#  - single arc length (36 hours)
#  - no Cd Adjustment

# %%
models_list = ['tiegcm_oc' ]

# %%
# %load_ext autoreload
# %autoreload 2

# import sys  
# import pickle 
# sys.path.insert(0, '/data/geodyn_proj/pygeodyn/pygeodyn_develop/')
# from PYGEODYN import Pygeodyn

# for i,val in enumerate( ['msis2','msis86','msis00', 'dtm87', 'jaachia71' ]):
#     template     = '/data/geodyn_proj/validation/NoCD_Arc24_AllDensModels_settings/NoCdArc24_msis2.yaml'
# #     run_settings = '/data/geodyn_proj/validation/NoCD_Arc36_AllDensModels_settings/NoCdArc36_'+val+'.yaml'
#     run_settings = '/data/geodyn_proj/validation/NoCD_Arc24_AllDensModels_settings/NoCdArc24_'+val+'.yaml'
    
#     ##### MODIFY THE SETTINGS FILE
#     #### Read the file.
#     with open(template, "r") as f:
#         lines_all = f.readlines()
#     ### Re-write the file line-by-line with your changes
#     with open(run_settings, "w") as f:
#         for line_num, line in enumerate(lines_all):
#             if 'den_model' in line:
#                 f.write("    den_model        : '"+val+"'  ,"+'\n')
#             else:
#                 f.write(line)

# %% [markdown]
# ### Run GEODYN if needed

# %%
# %load_ext autoreload
# %autoreload 2

import sys  
import pickle 
sys.path.insert(0, '/data/geodyn_proj/pygeodyn/pygeodyn_develop/')
from PYGEODYN import Pygeodyn


run = {}
for i,val in enumerate( models_list ): 
#     run_settings = '/data/geodyn_proj/validation/NoCD_Arc24_AllDensModels_settings/NoCdArc24_TESTOrbStep_'+val+'.yaml'
    run_settings = '/data/geodyn_proj/validation/NoCD_Arc24_AllDensModels_settings/NoCdArc24_'+val+'.yaml'

    ### Load the data into an object
    run[val] = Pygeodyn(run_settings)
    run[val].RUN_GEODYN()
# Out:
#      Loading ... icesat2_2018313_24hr.tiegcm_oc.NoCD_Arc24
# Run # 1     Current Time =      11:17:24  GMT-7
# Run # 1
# Epoch Start:  2018-11-09 00:00:00
# Epoch End:    2018-11-10 00:00:00
# Running without DRAG time dependence
# 1-  2018.313
#      Loading ... icesat2_2018313_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.313
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018313_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.313
#      Loading ... icesat2_2018313_24hr.msis2.NoCD_Arc24
# import time: 2.258321168133989
# Running thru Kamodo
#      Loading ... icesat2_2018314_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.314
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018314_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.314
#      Loading ... icesat2_2018314_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018315_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.315
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018315_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.315
#      Loading ... icesat2_2018315_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018316_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.316
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018316_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.316
#      Loading ... icesat2_2018316_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018317_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.317
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018317_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.317
#      Loading ... icesat2_2018317_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018318_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.318
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018318_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.318
#      Loading ... icesat2_2018318_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018319_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.319
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018319_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.319
#      Loading ... icesat2_2018319_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018320_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.320
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018320_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.320
#      Loading ... icesat2_2018320_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018321_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.321
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018321_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.321
#      Loading ... icesat2_2018321_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018322_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.322
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018322_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.322
#      Loading ... icesat2_2018322_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018323_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.323
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018323_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.323
#      Loading ... icesat2_2018323_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018324_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.324
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018324_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.324
#      Loading ... icesat2_2018324_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018325_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.325
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018325_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.325
#      Loading ... icesat2_2018325_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018326_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.326
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018326_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.326
#      Loading ... icesat2_2018326_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
#      Loading ... icesat2_2018327_24hr.msis2.NoCD_Arc24
# 2- MSIS2 2018.327
# file_exists (msis2 density file): /data/data_geodyn/results/icesat2/msis2/msis2_acceloff_valid_ctrlrun/DENSITY/icesat2_2018327_24hr.msis2.NoCD_Arc24_msisin
# 2.5 check-  True
# 3- tiegcm construct orbit cloud 2018.327
#      Loading ... icesat2_2018327_24hr.msis2.NoCD_Arc24
# Running thru Kamodo
# 5 running GEODYN 2018.313
#      Loading ... icesat2_2018313_24hr.tiegcm_oc.NoCD_Arc24
# 6 running GEODYN 2018.313
#      Loading ... icesat2_2018313_24hr.tiegcm_oc.NoCD_Arc24
# 7 running GEODYN 2018.313
# Run # 1     Current Time =      14:24:39  GMT-7
# Run # 1
# Epoch Start:  2018-11-09 00:00:00
# Epoch End:    2018-11-10 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 1     IISSET Cleaned      tmp/.../cleaned_setup_2018313
# |  Run # 1     Density Model:      tiegcm_oc
# |  Run # 1     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 1     ARC run:            icesat2_2018313_24hr.tiegcm_oc.NoCD_Arc24
# |  Run # 1     Output directory:   /data/data_geodyn/results/icesat2/tiegcm_oc/tiegcm_oc_acceloff_valid_ctrlrun
# |  Run # 1     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.313.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 1          Running IIS
# Run # 1          No errors in IIS
# Run # 1 ---------End of IIS
#
# Run # 1          Running IIE
# Run # 1          Current Time = 14:26:09 GMT-7
# Run # 1          No errors in IIE
# Run # 1 ---------End of IIE
# Run # 1          Time of IIE:  1433.6042785644531 secs ( 23.893404642740887  mins)
# Run # 1          Current Time = 21:50:03
# Run # 1                Finished renaming files
# Run # 1                Finished copying files to outputdir
#         Deleting tmp/:  tiegcm_oc_acceloff_valid_ctrlrun
# 5 running GEODYN 2018.314
#      Loading ... icesat2_2018314_24hr.tiegcm_oc.NoCD_Arc24
# 6 running GEODYN 2018.314
#      Loading ... icesat2_2018314_24hr.tiegcm_oc.NoCD_Arc24
# 7 running GEODYN 2018.314
# Run # 2     Current Time =      14:50:07  GMT-7
# Run # 2
# Epoch Start:  2018-11-10 00:00:00
# Epoch End:    2018-11-11 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 2     IISSET Cleaned      tmp/.../cleaned_setup_2018314
# |  Run # 2     Density Model:      tiegcm_oc
# |  Run # 2     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 2     ARC run:            icesat2_2018314_24hr.tiegcm_oc.NoCD_Arc24
# |  Run # 2     Output directory:   /data/data_geodyn/results/icesat2/tiegcm_oc/tiegcm_oc_acceloff_valid_ctrlrun
# |  Run # 2     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.314.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# Run # 2          Running IIS
# Run # 2          No errors in IIS
# Run # 2 ---------End of IIS
#
# Run # 2          Running IIE
# Run # 2          Current Time = 14:51:34 GMT-7
# Run # 2          No errors in IIE
# Run # 2 ---------End of IIE
# Run # 2          Time of IIE:  349.4560785293579 secs ( 5.824267975489298  mins)
# Run # 2          Current Time = 21:57:23
# Run # 2                Finished renaming files
# Run # 2                Finished copying files to outputdir
#         Deleting tmp/:  tiegcm_oc_acceloff_valid_ctrlrun
# 5 running GEODYN 2018.315
#      Loading ... icesat2_2018315_24hr.tiegcm_oc.NoCD_Arc24
# 6 running GEODYN 2018.315
#      Loading ... icesat2_2018315_24hr.tiegcm_oc.NoCD_Arc24
# 7 running GEODYN 2018.315
# Run # 3     Current Time =      14:57:28  GMT-7
# Run # 3
# Epoch Start:  2018-11-11 00:00:00
# Epoch End:    2018-11-12 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 3     IISSET Cleaned      tmp/.../cleaned_setup_2018315
# |  Run # 3     Density Model:      tiegcm_oc
# |  Run # 3     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 3     ARC run:            icesat2_2018315_24hr.tiegcm_oc.NoCD_Arc24
# |  Run # 3     Output directory:   /data/data_geodyn/results/icesat2/tiegcm_oc/tiegcm_oc_acceloff_valid_ctrlrun
# |  Run # 3     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.315.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 3          Running IIS
# Run # 3          No errors in IIS
# Run # 3 ---------End of IIS
#
# Run # 3          Running IIE
# Run # 3          Current Time = 14:58:55 GMT-7
# Run # 3          No errors in IIE
# Run # 3 ---------End of IIE
# Run # 3          Time of IIE:  765.0955092906952 secs ( 12.751591821511587  mins)
# Run # 3          Current Time = 22:11:40
# Run # 3                Finished renaming files
# Run # 3                Finished copying files to outputdir
#         Deleting tmp/:  tiegcm_oc_acceloff_valid_ctrlrun
# 5 running GEODYN 2018.316
#      Loading ... icesat2_2018316_24hr.tiegcm_oc.NoCD_Arc24
# 6 running GEODYN 2018.316
#      Loading ... icesat2_2018316_24hr.tiegcm_oc.NoCD_Arc24
# 7 running GEODYN 2018.316
# Run # 4     Current Time =      15:11:45  GMT-7
# Run # 4
# Epoch Start:  2018-11-12 00:00:00
# Epoch End:    2018-11-13 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 4     IISSET Cleaned      tmp/.../cleaned_setup_2018316
# |  Run # 4     Density Model:      tiegcm_oc
# |  Run # 4     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 4     ARC run:            icesat2_2018316_24hr.tiegcm_oc.NoCD_Arc24
# |  Run # 4     Output directory:   /data/data_geodyn/results/icesat2/tiegcm_oc/tiegcm_oc_acceloff_valid_ctrlrun
# |  Run # 4     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.316.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 4          Running IIS
# Run # 4          No errors in IIS
# Run # 4 ---------End of IIS
#
# Run # 4          Running IIE
# Run # 4          Current Time = 15:13:16 GMT-7
# Run # 4          No errors in IIE
# Run # 4 ---------End of IIE
# Run # 4          Time of IIE:  350.67099022865295 secs ( 5.844516503810882  mins)
# Run # 4          Current Time = 22:19:07
# Run # 4                Finished renaming files
# Run # 4                Finished copying files to outputdir
#         Deleting tmp/:  tiegcm_oc_acceloff_valid_ctrlrun
# 5 running GEODYN 2018.317
#      Loading ... icesat2_2018317_24hr.tiegcm_oc.NoCD_Arc24
# 6 running GEODYN 2018.317
#      Loading ... icesat2_2018317_24hr.tiegcm_oc.NoCD_Arc24
# 7 running GEODYN 2018.317
# Run # 5     Current Time =      15:19:11  GMT-7
# Run # 5
# Epoch Start:  2018-11-13 00:00:00
# Epoch End:    2018-11-14 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 5     IISSET Cleaned      tmp/.../cleaned_setup_2018317
# |  Run # 5     Density Model:      tiegcm_oc
# |  Run # 5     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 5     ARC run:            icesat2_2018317_24hr.tiegcm_oc.NoCD_Arc24
# |  Run # 5     Output directory:   /data/data_geodyn/results/icesat2/tiegcm_oc/tiegcm_oc_acceloff_valid_ctrlrun
# |  Run # 5     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.317.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 5          Running IIS
# Run # 5          No errors in IIS
# Run # 5 ---------End of IIS
#
# Run # 5          Running IIE
# Run # 5          Current Time = 15:20:41 GMT-7
# Run # 5          No errors in IIE
# Run # 5 ---------End of IIE
# Run # 5          Time of IIE:  676.8029329776764 secs ( 11.280048882961273  mins)
# Run # 5          Current Time = 22:31:58
# Run # 5                Finished renaming files
# Run # 5                Finished copying files to outputdir
#         Deleting tmp/:  tiegcm_oc_acceloff_valid_ctrlrun
# 5 running GEODYN 2018.318
#      Loading ... icesat2_2018318_24hr.tiegcm_oc.NoCD_Arc24
# 6 running GEODYN 2018.318
#      Loading ... icesat2_2018318_24hr.tiegcm_oc.NoCD_Arc24
# 7 running GEODYN 2018.318
# Run # 6     Current Time =      15:32:02  GMT-7
# Run # 6
# Epoch Start:  2018-11-14 00:00:00
# Epoch End:    2018-11-15 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 6     IISSET Cleaned      tmp/.../cleaned_setup_2018318
# |  Run # 6     Density Model:      tiegcm_oc
# |  Run # 6     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 6     ARC run:            icesat2_2018318_24hr.tiegcm_oc.NoCD_Arc24
# |  Run # 6     Output directory:   /data/data_geodyn/results/icesat2/tiegcm_oc/tiegcm_oc_acceloff_valid_ctrlrun
# |  Run # 6     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.318.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 6          Running IIS
# Run # 6          No errors in IIS
# Run # 6 ---------End of IIS
#
# Run # 6          Running IIE
# Run # 6          Current Time = 15:33:33 GMT-7
# Run # 6          No errors in IIE
# Run # 6 ---------End of IIE
# Run # 6          Time of IIE:  405.01805782318115 secs ( 6.750300963719686  mins)
# Run # 6          Current Time = 22:40:18
# Run # 6                Finished renaming files
# Run # 6                Finished copying files to outputdir
#         Deleting tmp/:  tiegcm_oc_acceloff_valid_ctrlrun
# 5 running GEODYN 2018.319
#      Loading ... icesat2_2018319_24hr.tiegcm_oc.NoCD_Arc24
# 6 running GEODYN 2018.319
#      Loading ... icesat2_2018319_24hr.tiegcm_oc.NoCD_Arc24
# 7 running GEODYN 2018.319
# Run # 7     Current Time =      15:40:22  GMT-7
# Run # 7
# Epoch Start:  2018-11-15 00:00:00
# Epoch End:    2018-11-16 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 7     IISSET Cleaned      tmp/.../cleaned_setup_2018319
# |  Run # 7     Density Model:      tiegcm_oc
# |  Run # 7     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 7     ARC run:            icesat2_2018319_24hr.tiegcm_oc.NoCD_Arc24
# |  Run # 7     Output directory:   /data/data_geodyn/results/icesat2/tiegcm_oc/tiegcm_oc_acceloff_valid_ctrlrun
# |  Run # 7     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.319.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# Run # 7          Running IIS
# Run # 7          No errors in IIS
# Run # 7 ---------End of IIS
#
# Run # 7          Running IIE
# Run # 7          Current Time = 15:41:52 GMT-7
# Run # 7          No errors in IIE
# Run # 7 ---------End of IIE
# Run # 7          Time of IIE:  418.43483781814575 secs ( 6.973913963635763  mins)
# Run # 7          Current Time = 22:48:50
# Run # 7                Finished renaming files
# Run # 7                Finished copying files to outputdir
#         Deleting tmp/:  tiegcm_oc_acceloff_valid_ctrlrun
# 5 running GEODYN 2018.320
#      Loading ... icesat2_2018320_24hr.tiegcm_oc.NoCD_Arc24
# 6 running GEODYN 2018.320
#      Loading ... icesat2_2018320_24hr.tiegcm_oc.NoCD_Arc24
# 7 running GEODYN 2018.320
# Run # 8     Current Time =      15:48:55  GMT-7
# Run # 8
# Epoch Start:  2018-11-16 00:00:00
# Epoch End:    2018-11-17 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 8     IISSET Cleaned      tmp/.../cleaned_setup_2018320
# |  Run # 8     Density Model:      tiegcm_oc
# |  Run # 8     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 8     ARC run:            icesat2_2018320_24hr.tiegcm_oc.NoCD_Arc24
# |  Run # 8     Output directory:   /data/data_geodyn/results/icesat2/tiegcm_oc/tiegcm_oc_acceloff_valid_ctrlrun
# |  Run # 8     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.320.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 8          Running IIS
# Run # 8          No errors in IIS
# Run # 8 ---------End of IIS
#
# Run # 8          Running IIE
# Run # 8          Current Time = 15:50:27 GMT-7
# Run # 8          No errors in IIE
# Run # 8 ---------End of IIE
# Run # 8          Time of IIE:  418.66128373146057 secs ( 6.977688062191009  mins)
# Run # 8          Current Time = 22:57:26
# Run # 8                Finished renaming files
# Run # 8                Finished copying files to outputdir
#         Deleting tmp/:  tiegcm_oc_acceloff_valid_ctrlrun
# 5 running GEODYN 2018.321
#      Loading ... icesat2_2018321_24hr.tiegcm_oc.NoCD_Arc24
# 6 running GEODYN 2018.321
#      Loading ... icesat2_2018321_24hr.tiegcm_oc.NoCD_Arc24
# 7 running GEODYN 2018.321
# Run # 9     Current Time =      15:57:31  GMT-7
# Run # 9
# Epoch Start:  2018-11-17 00:00:00
# Epoch End:    2018-11-18 00:00:00
# Running without DRAG time dependence
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 9     IISSET Cleaned      tmp/.../cleaned_setup_2018321
# |  Run # 9     Density Model:      tiegcm_oc
# |  Run # 9     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 9     ARC run:            icesat2_2018321_24hr.tiegcm_oc.NoCD_Arc24
# |  Run # 9     Output directory:   /data/data_geodyn/results/icesat2/tiegcm_oc/tiegcm_oc_acceloff_valid_ctrlrun
# |  Run # 9     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.321.gz
# |
# + —————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 9          Running IIS
# Run # 9          No errors in IIS
# Run # 9 ---------End of IIS
#
# Run # 9          Running IIE
# Run # 9          Current Time = 15:59:03 GMT-7
# Run # 9          No errors in IIE
# Run # 9 ---------End of IIE
# Run # 9          Time of IIE:  421.68232464790344 secs ( 7.028038744131724  mins)
# Run # 9          Current Time = 23:06:05
# Run # 9                Finished renaming files
# Run # 9                Finished copying files to outputdir
#         Deleting tmp/:  tiegcm_oc_acceloff_valid_ctrlrun
# 5 running GEODYN 2018.322
#      Loading ... icesat2_2018322_24hr.tiegcm_oc.NoCD_Arc24
# 6 running GEODYN 2018.322
#      Loading ... icesat2_2018322_24hr.tiegcm_oc.NoCD_Arc24
# 7 running GEODYN 2018.322
# Run # 10     Current Time =      16:06:09  GMT-7
# Run # 10
# Epoch Start:  2018-11-18 00:00:00
# Epoch End:    2018-11-19 00:00:00
# Running without DRAG time dependence
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 10     IISSET Cleaned      tmp/.../cleaned_setup_2018322
# |  Run # 10     Density Model:      tiegcm_oc
# |  Run # 10     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 10     ARC run:            icesat2_2018322_24hr.tiegcm_oc.NoCD_Arc24
# |  Run # 10     Output directory:   /data/data_geodyn/results/icesat2/tiegcm_oc/tiegcm_oc_acceloff_valid_ctrlrun
# |  Run # 10     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.322.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 10          Running IIS
# Run # 10          No errors in IIS
# Run # 10 ---------End of IIS
#
# Run # 10          Running IIE
# Run # 10          Current Time = 16:07:42 GMT-7
# Run # 10          No errors in IIE
# Run # 10 ---------End of IIE
# Run # 10          Time of IIE:  486.55560755729675 secs ( 8.109260125954945  mins)
# Run # 10          Current Time = 23:15:49
# Run # 10                Finished renaming files
# Run # 10                Finished copying files to outputdir
#         Deleting tmp/:  tiegcm_oc_acceloff_valid_ctrlrun
# 5 running GEODYN 2018.323
#      Loading ... icesat2_2018323_24hr.tiegcm_oc.NoCD_Arc24
# 6 running GEODYN 2018.323
#      Loading ... icesat2_2018323_24hr.tiegcm_oc.NoCD_Arc24
# 7 running GEODYN 2018.323
# Run # 11     Current Time =      16:15:53  GMT-7
# Run # 11
# Epoch Start:  2018-11-19 00:00:00
# Epoch End:    2018-11-20 00:00:00
# Running without DRAG time dependence
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# |
# | ---------------------- Some run information ----------------------
# |
# |  Run # 11     IISSET Cleaned      tmp/.../cleaned_setup_2018323
# |  Run # 11     Density Model:      tiegcm_oc
# |  Run # 11     GEODYN Version:     Kamodo_pygeodyn_MODS
# |  Run # 11     ARC run:            icesat2_2018323_24hr.tiegcm_oc.NoCD_Arc24
# |  Run # 11     Output directory:   /data/data_geodyn/results/icesat2/tiegcm_oc/tiegcm_oc_acceloff_valid_ctrlrun
# |  Run # 11     EXAT File:          /data/data_geodyn/inputs/icesat2/external_attitude/EXAT01.2018.323.gz
# |
# + ——————————————————————————————————————————————————————————————————————————————————————————————————————————————————
#
# Run # 11          Running IIS
# Run # 11          No errors in IIS
# Run # 11 ---------End of IIS
#
# Run # 11          Running IIE
# Run # 11          Current Time = 16:17:27 GMT-7
# ERRORS FOUND IN IIE: /data/data_geodyn/tmp/tiegcm_oc_acceloff_valid_ctrlrun/icesat2_2018323_24hr.tiegcm_oc.NoCD_Arc24/iieerr
# Run # 11          Time of IIE:  137.05923891067505 secs ( 2.2843206485112506  mins)
# STOP 16
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Ending program... Errors found in iieout file.

# %%
print('End of Notebook')

# %% [markdown]
# #####
