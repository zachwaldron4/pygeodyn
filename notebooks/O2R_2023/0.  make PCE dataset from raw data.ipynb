# %% [markdown]
# # Make the PCE Files
#
# The PCE/PSO files takes two forms in our framework:
#   1. The G2B binary file to be ingested into GEODYN
#   2. A text file containing the PSO which will be used as initial conditions AND as the true dataset against which to compare the orbit fits.

# %%
from pygeodyn.PYGEODYN import Pygeodyn


run_list = [
                'msis2',
           ]

dir_modeldat='/data/SatDragModelValidation/data/inputs/atmos_models'
run_dict={}
for i in run_list:
    if i =='msis2':
        run_dict[i]={}
        run_dict[i]['num'] = 5
        run_dict[i]['model_path'] = None
    if i =='dtm2020_o':
        run_dict[i]={}
        run_dict[i]['num'] = 3
        run_dict[i]['model_path'] = None
    if i =='jb2008':
        run_dict[i]={}
        run_dict[i]['num'] = 1
        run_dict[i]['model_path'] = None
        
print(run_dict)
# Out:
# {'msis2': {'num': 5, 'model_path': None}}

# %% [markdown]
# Run once for the new time period (starting two days before and ending two days after).
#  - run once with `overwrite_ICtext=True`.  This loads the data from binary files into a text file.
#  - if kernel dies, run again with `overwrite_ICtext=False` to construct the binary g2b file.

# %%
# %load_ext autoreload
# %autoreload 2
from gc import collect as gc_collect
import pickle 
import os

file_raw_ICs = f"/data/SatDragModelValidation/data/inputs/sat_icesat2/g2b/"\
          +"ICESat2_RawEphem_2018_11.txt"
# file_raw_ICs = f"/data/SatDragModelValidation/data/inputs/sat_icesat2/g2b/"\
#           +"ICESat2_RawEphem_2018_10.txt"



obj = {}
for i,den in enumerate(run_list):
    
    settings_icesat2= {# Basic input settings
                 'satellite'      : {'input': 'icesat2'},
                 'den_model'      : {'input': den},
                 'run_type'       : {'input': 'DataReduction_PCE'},
                 'run_specifier'  : {'input': '_fixedCD'},
                 'cd_model'       : {'input': 'BWDRAG'},
                 'file_string'    : {'input': 'CD_2p5'},
                 'model_data_path' : {'input': run_dict[den]['model_path']},
                 # Force Model settings
                  'cd_type'               : {'input':"Fixed_CD"},
                  'cd_value'              : {'input':2.500000},
                  'scaling_factor'        : {'input':False},
#                   'hours_between_cd_adj'  : {'input':24},
                  #### Comment for unadjusted run:
                  'cd_adjustment_boolean' : {'input':False },
                  #### ---------------------------------------
                 # Run
                  'arc_type'       : {'input':'Nominal30hr_and_AB'},      
                  'step'           : {'input': 60.},
                  'orbfil_step'    : {'input': 120.},
                  'which_ICfile'   : {'input':file_raw_ICs},
                  'arc'            : {'input':[
                                               '2018.300',
#                                                '2018.301A',
#                                                '2018.301B',
                                              ]},
                  'epoch_start'    : {'input': [
                                                "2018-10-26 21:00:00",
#                                                 "2018-10-27 21:00:00",
#                                                 "2018-10-28 17:36:00",
                                              ]},
                   #
                  'epoch_stop'     : {'input':[ 
                                                "2018-10-28 03:00:00",
#                                                 "2018-10-28 16:00:00",
#                                                 "2018-10-29 03:00:00",
                                              ]},  
                   #                                
                  'global_options' : {'input':'pso_2018'},
                 # Request read on raw outputs
                  'request_data'   : {'input': ['Trajectory_orbfil', 
                                               'Density', 
                                               'Residuals_summary',
                                               'DragFile',
                                               'AdjustedParams'
                                               ]},
              #end dict
              }
    
#     sat = Pygeodyn(settings_icesat2, use_file=False)
# #     sat.run_arcs()
#     obj[den] =  sat.getData_BigData_lowmemory()
#     gc_collect()

    
#     # -----------------------------------------------------
startdate = "2019-03-30"
enddate   = "2019-05-02"  
sat = Pygeodyn(settings_icesat2, use_file=False)
sat.initialize_timeperiod_stage1(startdate, enddate,
                                 overwrite_exat=False, 
                                 overwrite_ICtext=True)
import sys
sys.exit(0)
# Out:
# Using the ICESat-2 Class
# ----------------------------------------------------------------------------
# Initializing the time period from 2019-03-30 00:00:00 to 2019-05-03 00:00:00
#      overwriting the epoch start and stop to match
# ----------------------------------------------------------------------------
#
# self.prms['arc'] ['2019.089', '2019.090', '2019.091A', '2019.092A', '2019.093', '2019.094', '2019.095', '2019.096', '2019.097', '2019.098', '2019.099', '2019.100', '2019.101', '2019.102', '2019.103', '2019.104', '2019.105', '2019.106A', '2019.107A', '2019.108', '2019.109', '2019.110']
# Using the ICESat-2 Class
# Step 0: Make directory structure for satellite input data
# Directory Exists:  /data/SatDragModelValidation/data/inputs/sat_icesat2
# Directory Exists:  /data/SatDragModelValidation/data/inputs/sat_icesat2/setups
# Directory Exists:  /data/SatDragModelValidation/data/inputs/sat_icesat2/external_attitude
# Directory Exists:  /data/SatDragModelValidation/data/inputs/sat_icesat2/g2b
# Do not update EXAT files for ICESat-2
#
# Step 2: Construct/Find a PCE file
#    Making PCE g2b file: /data/SatDragModelValidation/data/inputs/sat_icesat2/g2b/pce_icesat2_pso_20190330_20190420
#         - Initialize Raw Satellite Ephemerides as UTC, Cartesian-ECI-J2000
# satellite icesat2
#         - ICESAT-2
#         - processing raw satellite ephemerides from files.
#         - for dates: DatetimeIndex(['2019-03-30', '2019-03-31', '2019-04-01', '2019-04-02',
#                '2019-04-03', '2019-04-04', '2019-04-05', '2019-04-06',
#                '2019-04-07', '2019-04-08', '2019-04-09', '2019-04-10',
#                '2019-04-11', '2019-04-12', '2019-04-13', '2019-04-14',
#                '2019-04-15', '2019-04-16', '2019-04-17', '2019-04-18',
#                '2019-04-19', '2019-04-20'],
#               dtype='datetime64[ns]', freq='D')
#       Running through the pre-processing procedure...
#       =======================================================
#       STEP 1: Convert RVG binary files to pandas DataFrame...
#       =======================================================
#       Loading and processing 22 files will take approx. 19.98 minutes.
#             Not including unzipping/zipping times
#
#       --- File 1 / 22
#       ----- Loading  2019.089
#       ----- End of file
#
#       --- File 2 / 22
#       ----- Loading  2019.090
#       ----- End of file
#
#       --- File 3 / 22
#       ----- Loading  2019.091A
#       ----- End of file
#
#       --- File 4 / 22
#       ----- Loading  2019.092A
#       ----- End of file
#
#       --- File 5 / 22
#       ----- Loading  2019.093
#       ----- End of file
#
#       --- File 6 / 22
#       ----- Loading  2019.094
#       ----- End of file
#
#       --- File 7 / 22
#       ----- Loading  2019.095
#       ----- End of file
#
#       --- File 8 / 22
#       ----- Loading  2019.096
#       ----- End of file
#
#       --- File 9 / 22
#       ----- Loading  2019.097
#       ----- End of file
#
#       --- File 10 / 22
#       ----- Loading  2019.098
#       ----- End of file
#
#       --- File 11 / 22
#       ----- Loading  2019.099
#       ----- End of file
#
#       --- File 12 / 22
#       ----- Loading  2019.100
#       ----- End of file
#
#       --- File 13 / 22
#       ----- Loading  2019.101
#       ----- End of file
#
#       --- File 14 / 22
#       ----- Loading  2019.102
#       ----- End of file
#
#       --- File 15 / 22
#       ----- Loading  2019.103
#       ----- End of file
#
#       --- File 16 / 22
#       ----- Loading  2019.104
#       ----- End of file
#
#       --- File 17 / 22
#       ----- Loading  2019.105
#       ----- End of file
#
#       --- File 18 / 22
#       ----- Loading  2019.106A
#       ----- End of file
#
#       --- File 19 / 22
#       ----- Loading  2019.107A
#       ----- End of file
#
#       --- File 20 / 22
#       ----- Loading  2019.108
#       ----- End of file
#
#       --- File 21 / 22
#       ----- Loading  2019.109
#       ----- End of file
#
#       --- File 22 / 22
#       ----- Loading  2019.110
#       ----- End of file
#
#           saving satellite ephemeris to single file.
# (1906563,)
#
#        Processed file in :  259.98991 secs (4.333165166666666 minutes)
#         - Convert UTC to GPS and convert to MJDS
#                 - done with conversion
#                 - done with the above
#         - Put data in a DataFrame
#         - Save prepped PCE as TRAJ.txt
#         - Free up some memory
#         - pce_fortran.f compiled
#         - Run fortran PCE converter
#         - pce_fortran.f executed
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /data/miniconda3/envs/pygeodyn/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
